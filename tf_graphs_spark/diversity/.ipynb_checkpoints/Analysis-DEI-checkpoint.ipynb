# %%
import networkx as nx
import numpy as np
import pickle
import matplotlib.pyplot as plt
import scipy
from collections import deque
import seaborn as sns
import pandas as pd

# %%
lambdas = [0, 0.5, 2, 3, 4, 5, 10]
lambdasToString = [str(l) for l in lambdas]
input_file = f'./DEI.pickle'

# %%
def project_term(x):
    # Requires definition of lambda_
    res = 0
    # project preference term
    for u in nodes:
        for p in projects:
            if (u, p) in c and (u, p) in x:
                res += c[(u, p)] * x[(u, p)]
    res *= lambda_
    return res

def conflict_term(x):
    res = 0
    for e in edges:
        u, v = e
        inner_sum = 0
        for p in projects:
            if (u, p) in x and (v, p) in x:
                inner_sum += x[(u, p)] * x[(v, p)]
        res += w[(u, v)] * (1 - inner_sum)
    return res
    
def f(x):
    # Requires definition of lambda_
    return project_term(x) + conflict_term(x)

# %%
with open(input_file, 'rb') as file:
    projects = pickle.load(file)
    capacities = pickle.load(file)
    numOfProjects = len(capacities)
    c = pickle.load(file)
    w = pickle.load(file)
    edges = pickle.load(file)
    nodes = pickle.load(file)
    wE = sum([w[e] for e in w])
    assignment = pickle.load(file)
    
G = nx.Graph()
G.add_edges_from(edges)
nodes = list(G.nodes)
n = len(nodes)
len(edges)
# Out:
# 10166

# %%
proj_popularity = dict()
for p in projects:
    proj_popularity[p] = 0
    
for u in nodes:
    for p in projects:
        if (u, p) in c:
            proj_popularity[p] += c[(u, p)]
            
xs = projects
ys = proj_popularity.values()

plt.bar(xs, ys)
plt.xlabel('Project')
plt.xticks(rotation = 60)
plt.ylabel('Popularity')
plt.title(f'Project popularity')

plt.show()

print(f'number of (conflict) edges = {len(edges)}')
# nx.draw(G, pos=nx.spring_layout(G, k=0.2, iterations=20), with_labels=True)
# plt.title(f'Conflict graph')
# plt.show()
# Out:
# number of (conflict) edges = 10166

# %%
settings = dict()
results = dict()
times = dict()

for l in lambdasToString:
    results_file = f'results/DEI_lambda{l}.pickle'
    with open(results_file, 'rb') as file:
        settings[l] = pickle.load(file)
        results[l] = pickle.load(file)
        times[l] = pickle.load(file)
        file.close()

# %%
results['0.5'].keys()
# Out:
# dict_keys(['quad_sol', 'rounded_sol34', 'rounded_sol12', 'random_sol', 'greedy_sol'])

# %%
obj_opt = dict()
obj_round12 = dict()
obj_round34 = dict()
obj_random = dict()
obj_greedy = dict()

x_round12 = dict()
x_round34 = dict()
x_opt = dict()
x_random = dict()
x_greedy = dict()

approx_ratio12 = dict()
approx_ratio34 = dict()
approx_ratio_random = dict()
approx_ratio_greedy = dict()

for i in range(len(lambdas)):
    l = lambdasToString[i]
    lambda_ = lambdas[i] * wE/ n
    res = results[l]
    
    
    x_opt[l] = res["quad_sol"]
    x_round12[l] = res["rounded_sol12"]
    x_round34[l] = res["rounded_sol34"]    
    x_random[l] = res['random_sol']
    x_greedy[l] = res["greedy_sol"]
    
    obj_opt[l] = f(x_opt[l])
    obj_round12[l] = f(x_round12[l])
    obj_round34[l] = f(x_round34[l])
    obj_random[l] = f(x_random[l])
    obj_greedy[l] = f(x_greedy[l])
    

    approx_ratio12[l] = obj_round12[l] / obj_opt[l]
    approx_ratio34[l] = obj_round34[l] / obj_opt[l]
    
    approx_ratio_random[l] = obj_random[l] / obj_opt[l]
    approx_ratio_greedy[l] = obj_greedy[l] / obj_opt[l]
    
    print(f'\n======= lambda = {lambdas[i]} ==========')   
    print(f'approx ratio (1/2 approx) = {approx_ratio12[l]}')
    print(f'approx ratio (3/4 approx) = {approx_ratio34[l]}')
    print(f'approx ratio (random) = {approx_ratio_random[l]}')
    print(f'approx ratio (greedy) = {approx_ratio_greedy[l]}')
    
#     ind = ["obj_opt", "obj_round12", "obj_round34", "obj_project", "obj_conflict"]
#     xs = [x_opt[l], x_round12[l], x_round34[l], x_random[l], x_greedy[l]]
    
#     a = np.array([project_term(x) for x in xs])
#     b = np.array([conflict_term(x) for x in xs])

#     p1 = plt.bar(ind, a, color='green', label="project")
#     p2 = plt.bar(ind, b, color='#FF0000', bottom=sum([a]), label="conflict")
    
#     plt.legend()
#     plt.show()
# Out:
# ======= lambda = 0 ==========
# approx ratio (1/2 approx) = 0.7770596080845388
# approx ratio (3/4 approx) = 0.7814712219144352
# approx ratio (random) = 0.7639273622653124
# approx ratio (greedy) = 0.8895044629116651
#
# ======= lambda = 0.5 ==========
# approx ratio (1/2 approx) = 0.8464689598303687
# approx ratio (3/4 approx) = 0.8493550477087997
# approx ratio (random) = 0.682800290572113
# approx ratio (greedy) = 0.9730347115875447
#
# ======= lambda = 2 ==========
# approx ratio (1/2 approx) = 1.0
# approx ratio (3/4 approx) = 1.0
# approx ratio (random) = 0.4727138377041266
# approx ratio (greedy) = 0.9932405248674194
#
# ======= lambda = 3 ==========
# approx ratio (1/2 approx) = 1.0
# approx ratio (3/4 approx) = 1.0
# approx ratio (random) = 0.4183627034303384
# approx ratio (greedy) = 0.9880427422169622
#
# ======= lambda = 4 ==========
# approx ratio (1/2 approx) = 1.0
# approx ratio (3/4 approx) = 1.0
# approx ratio (random) = 0.3886524564433911
# approx ratio (greedy) = 0.9867521306627022
#
# ======= lambda = 5 ==========
# approx ratio (1/2 approx) = 1.0
# approx ratio (3/4 approx) = 1.0
# approx ratio (random) = 0.3694557421730337
# approx ratio (greedy) = 0.9863293064036269
#
# ======= lambda = 10 ==========
# approx ratio (1/2 approx) = 1.0
# approx ratio (3/4 approx) = 1.0
# approx ratio (random) = 0.3270505250032293
# approx ratio (greedy) = 0.9853952947661023

# %%
print(f'w(E) = {wE}')
for l, lstr in zip(lambdas, lambdasToString):
    lambda_ = l * wE / n
    projectsVal = project_term(x_round34[lstr])
    print(f'\n===== lambda = {l} ======')
    print(f'projects term value = {projectsVal}')
    print(f'a = {projectsVal - wE}')
# Out:
# w(E) = 10166
#
# ===== lambda = 0 ======
# projects term value = 0.0
# a = -10166.0
#
# ===== lambda = 0.5 ======
# projects term value = 3147.923566878981
# a = -7018.076433121019
#
# ===== lambda = 2 ======
# projects term value = 19704.407643312104
# a = 9538.407643312104
#
# ===== lambda = 3 ======
# projects term value = 30438.229299363058
# a = 20272.229299363058
#
# ===== lambda = 4 ======
# projects term value = 40664.0
# a = 30498.0
#
# ===== lambda = 5 ======
# projects term value = 50830.0
# a = 40664.0
#
# ===== lambda = 10 ======
# projects term value = 101660.0
# a = 91494.0

# %% [markdown]
# ### Diversity analysis (fixed $\lambda$)

# %%
l = lambdasToString[0]
l
# Out:
# '0'

# %% [markdown]
# x = x_opt[l]
#
# dfs = dict()
# dfs_merged = dict()
# for l in lambdasToString:
#     divisions = deque()
#     ids = deque()
#     for k, v in x.items():
#         if v == 1:
#             ids.append(k[0])
#             divisions.append(k[1])
#
#     data = zip(ids, divisions)
#     df_sol = pd.DataFrame(data, columns=['Id', 'Division'])
#     dfs[l] = df_sol
#
# df1 = dfs['0']
# df2 = dfs['3']
# df

# %%
df_old = pd.read_csv('DEI.csv')
# df_old = df[['Id', 'Division', 'Gender']]
df_old['Division'].unique()
# Out:
# array(['PR', 'IT', 'Sales', 'HR'], dtype=object)

# %%
for l in lambdasToString:
    dfs_merged[l] = pd.merge(dfs[l], df_old, on="Id")

# %%
def calc_percentage(l, department, setting='new'):
    df_merged = dfs_merged[l]
    if setting == 'new':
        IT_df = df_merged[df_merged['Division_x'] == department]
    else:
        IT_df = df_merged[df_merged['Division_y'] == department]
    IT_total = len(IT_df)
    IT_male = IT_df[IT_df['Gender'] == 'Male']
    IT_female = IT_df[IT_df['Gender'] == 'Female']
    values = [len(v) for v in [IT_male, IT_female]]
    return values

# %%
for l in lambdasToString:
    print(f'Plots for lambda = {l}')
    IT_new, IT_old = calc_percentage(l, 'IT'), calc_percentage(l, 'IT', 'old')
    HR_new, HR_old = calc_percentage(l, 'HR'), calc_percentage(l, 'HR', 'old')
    PR_new, PR_old = calc_percentage(l, 'PR'), calc_percentage(l, 'PR', 'old')
    Sales_new, Sales_old = calc_percentage(l, 'Sales'), calc_percentage(l, 'Sales', 'old')
    keys = ['Male', 'Female']

    fig, axs = plt.subplots(2, 4)
    fig.subplots_adjust(hspace=-0.1)

    axs[0, 0].pie(IT_old, autopct='%1.0f%%', normalize=True)
    axs[0, 0].set_title('IT')
    axs[1, 0].pie(IT_new, autopct='%1.0f%%', normalize=True)

    axs[0, 1].pie(Sales_old, autopct='%1.0f%%', normalize=True)
    axs[0, 1].set_title('Sales')
    axs[1, 1].pie(Sales_new, autopct='%1.0f%%', normalize=True)

    axs[0, 2].pie(HR_old, autopct='%1.0f%%', normalize=True)
    axs[0, 2].set_title('HR')
    axs[1, 2].pie(HR_new, autopct='%1.0f%%', normalize=True)

    axs[0, 3].pie(PR_old, autopct='%1.0f%%', normalize=True)
    axs[0, 3].set_title('PR')
    axs[1, 3].pie(PR_new, autopct='%1.0f%%', normalize=True)

    common_legend = fig.legend(keys, loc='upper left')

    plt.tight_layout()
    plt.savefig('diversity_before_after.png', bbox_inches='tight')
    plt.show()
# Out:
# Plots for lambda = 0
# Plots for lambda = 0.5
# Plots for lambda = 2
# Plots for lambda = 3
# Plots for lambda = 4
# Plots for lambda = 5
# Plots for lambda = 10

# %%
for l in lambdasToString:
    df_merged = dfs_merged[l]
    df_stayed = df_merged[df_merged['Division_x'] == df_merged['Division_y']]
    print(f'lambda = {l} - Percentage of people who changed department = {1 - len(df_stayed) / 4000}')
# Out:
# lambda = 0 - Percentage of people who changed department = 0.05225000000000002
# lambda = 0.5 - Percentage of people who changed department = 0.05225000000000002
# lambda = 2 - Percentage of people who changed department = 0.05225000000000002
# lambda = 3 - Percentage of people who changed department = 0.05225000000000002
# lambda = 4 - Percentage of people who changed department = 0.05225000000000002
# lambda = 5 - Percentage of people who changed department = 0.05225000000000002
# lambda = 10 - Percentage of people who changed department = 0.05225000000000002
