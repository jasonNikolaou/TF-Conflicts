# %%
import gurobipy as gp
from gurobipy import GRB
import networkx as nx
from networkx.algorithms import bipartite
import numpy as np
from collections import deque
from math import isclose
import random
import pickle
from time import time
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Input paramters

# %%
# input_file = f'./inputs/graph_n{n}_{conflictGraphType}_{mainProjectDist}_{secondaryProjectDist}.pickle'
# output_file = f'./results/graph_n{n}_lambda{lambdaToString}_{conflictGraphType}_{mainProjectDist}_{secondaryProjectDist}.pickle'
input_file = './bu_spark_2022/csDS506.pickle'
lambda_mul = 10

# Read graph
with open(input_file, 'rb') as file:
    projects = pickle.load(file)
    capacities = pickle.load(file)
    numOfProjects = len(capacities)
    c = pickle.load(file)
    w = pickle.load(file)
    edges = pickle.load(file)
    assignment = pickle.load(file)
    representatives = pickle.load(file)

G = nx.Graph()
G.add_edges_from(edges)
nodes = list(G.nodes)
n = len(nodes)
P =  # max number of "active" projects
min_capacities = dict()
for p in projects:
    min_capacities[p] = 4
    
lambda_ = lambda_mul * sum(w.values()) / n

G_c = nx.complement(G) # friends graph
nx.draw(G_c, pos=nx.spring_layout(G_c, k=0.2, iterations=20), with_labels=True)
plt.title(f'Friends graph')
plt.show()


print(f'number of students: {n}')
print(f'number of conflict edges: {len(edges)}')
print(f'number of friend edges: {len(G_c.edges)}')
print(f'number of projects: {numOfProjects}')
# Out:
# number of students: 26
# number of conflict edges: 311
# number of friend edges: 14
# number of projects: 6

# %% [markdown]
# ## Problem definition
# The objective function is the following: \
# $$
# \max F(\mathbf{x}) =
#     \lambda \sum_{v \in V} \sum_{t=1}^k c_{vt} x_{vt}
#     + \sum_{(u, v) \in E} w_{uv} (1 - \sum_{t=1}^k x_{ut}x_{vt})
# $$
# Constraints:
# - $\sum_{t=1}^k y_t x_{ut} = 1$, for all $u \in V$
# - $y_t q_t \leq y_t \sum_{u \in V} x_{ut} \leq p_t$, for all $t \in [k]$
# - $ \sum_{u \in V} z_u y_t x_{ut} \geq y_t$, for all $t \in [k]$
# - $ \sum_{t} y_t \leq P$
# - $x_{ut} \in \{0, 1\}$
# - $y_{t} \in \{0, 1\}$

# %%
# Create a new model
m = gp.Model("quadratic")
m.Params.timeLimit = 120
m.Params.NonConvex = 2

# Create variables
X = dict()
Y = dict()
Z = dict()
for u in nodes:
    for p in projects:
        X[(u, p)] = m.addVar(vtype=GRB.BINARY, name=f"X({u},{p})")
        
for p in projects:
    Y[p] = m.addVar(vtype=GRB.BINARY, name=f"Y_{p})")
    
for u in nodes:
    Z[u] = m.addVar(vtype=GRB.BINARY, name=f"Z_{u})")

    
# Linear (project preference) term
F1 = gp.LinExpr()
for u in nodes:
    for p in projects:
        if (u, p) in c:
            F1 += c[(u, p)] * X[(u, p)]
F1 *= lambda_
 
# max-cut term
F3 = dict()
F2 = gp.QuadExpr()
for e in edges:
    u = e[0]; v = e[1]
    F3[e] = gp.QuadExpr()
    for p in projects:
        F3[e] -=  X[(u, p)] * X[(v, p)]
    F3[e] += 1
    F3[e] *= w[(u, v)]
for e in edges:
    F2 += F3[e]
    
F = gp.QuadExpr()
F = F1 + F2
m.setObjective(F, GRB.MAXIMIZE)
    
# Add constraints

# Each student assigned to exactly one project
for u in nodes:
    expr = gp.QuadExpr()
    expr = sum([Y[p] * X[(u, p)] for p in projects])
    m.addConstr(expr == 1)
    
# Project max capacity constraints
for p in projects:
    expr = gp.QuadExpr()
    expr = Y[p] * sum(X[(u, p)] for u in nodes)
    m.addConstr(expr <= capacities[p])
    m.addConstr(expr >= min_capacities[p] * Y[p])

# Number of "active" projects
expr = gp.LinExpr()
expr = sum([Y[p] for p in projects])
m.addConstr(expr <= P)

# Each "active" project should have a representative
expr = gp.QuadExpr()
for p in projects:
    expr = sum([representatives[u] * Y[p] * X[(u, p)] for u in nodes])
    m.addConstr(expr >= Y[p])
# Out:
# Set parameter GURO_PAR_SPECIAL
# Set parameter TokenServer to value "sccsvc"
# Set parameter TimeLimit to value 120
# Set parameter NonConvex to value 2

# %%
projects
# Out:
# ['922a5', 'e4dfc', 'f1b27', 'db42f', 'cfa1d', '99fb8']

# %%
start = time()
# Optimize model
m.optimize()

# Convert solution to dictionary format
x_opt = dict()
for u in nodes:
    for p in projects:
        x_opt[(u, p)] = X[(u, p)].X
        
print(f'Obj quadratic: {m.ObjVal}')
# Out:
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) Gold 6132 CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 28 physical cores, 28 logical processors, using up to 28 threads
#
# Optimize a model with 1 rows, 188 columns and 6 nonzeros
# Model fingerprint: 0x09185b1e
# Model has 1866 quadratic objective terms
# Model has 44 quadratic constraints
# Variable types: 0 continuous, 188 integer (188 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 3e+00]
#   Objective range  [2e+01, 1e+02]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [7e+00, 7e+00]
#   QRHS range       [1e+00, 6e+00]
# Presolve added 17 rows and 0 columns
# Presolve removed 0 rows and 26 columns
# Presolve time: 0.00s
# Presolved: 2378 rows, 2184 columns, 7320 nonzeros
# Variable types: 0 continuous, 2184 integer (2184 binary)
# Found heuristic solution: objective 1599.7371795
#
# Root relaxation: objective 5.968644e+03, 475 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5968.64371    0  884 1599.73718 5968.64371   273%     -    0s
#      0     0 2787.92308    0   36 1599.73718 2787.92308  74.3%     -    0s
# H    0     0                    2578.5833333 2787.92308  8.12%     -    0s
# H    0     0                    2746.0512821 2787.92308  1.52%     -    0s
# H    0     0                    2748.0384615 2787.92308  1.45%     -    0s
#      0     0 2786.42308    0   62 2748.03846 2786.42308  1.40%     -    0s
#      0     0 2786.42308    0   24 2748.03846 2786.42308  1.40%     -    0s
# H    0     0                    2781.9230769 2786.42308  0.16%     -    0s
# H    0     0                    2782.9230769 2786.42308  0.13%     -    0s
# H    0     0                    2784.9230769 2786.42308  0.05%     -    0s
#      0     0 2785.92308    0   28 2784.92308 2785.92308  0.04%     -    0s
#
# Cutting planes:
#   Zero half: 6
#   RLT: 7
#   BQP: 9
#
# Explored 1 nodes (2918 simplex iterations) in 0.39 seconds (0.18 work units)
# Thread count was 28 (of 28 available processors)
#
# Solution count 7: 2784.92 2782.92 2781.92 ... 1599.74
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.784923076923e+03, best bound 2.784923076923e+03, gap 0.0000%
# Obj quadratic: 2784.9230769230767

# %% [markdown]
# ### Save results

# %%
results = dict()
results["quad_sol"] = x_opt
results["quad_val"] = m.ObjVal

settings = dict()
settings["nodes"] = nodes
settings["edges"] = edges
settings["w"] = w
settings["c"] = c
settings["capacities"] = capacities
settings["projects"] = projects
settings["lambda_mul"] = lambda_mul
settings["lambda_"] = lambda_

# %%
# with open(output_file, 'wb') as file:
#     pickle.dump(settings, file)
#     pickle.dump(edges, file) # conflict edges
#     pickle.dump(results, file)
#     file.close()

# %% [markdown]
# ### Teams

# %%
def construct_teams(x):
    teams = dict()
    for p in projects:
        teams[p] = []

    for e in x:
        u, p = e
        if x[e] == 1:
            u, p = e
            teams[p].append(u)
            
    for p in projects:
        teams[p].sort()
        
    return teams

x = dict()
for u in nodes:
    for p in projects:
        x[(u, p)] = X[(u, p)].X

# %%
teams = construct_teams(x)
teams
# Out:
# {'922a5': ['07ba3', '8b401', '97c9a', 'cfc5f'],
#  'e4dfc': ['133c7', '83784', 'a3004', 'd7530'],
#  'f1b27': ['57a36', 'a7e74', 'eef1d', 'f6abd'],
#  'db42f': ['7b1b9', '7e351', '88177', 'ac44e', 'e116c', 'e4cdc'],
#  'cfa1d': ['1336f', '1a1ba', '7fd51', 'f72f3'],
#  '99fb8': ['a7efa', 'db1a9', 'dbeb4', 'ebf2d']}

# %% [markdown]
# ### Analysis

# %%
def min_friends(teams):
    minFriends = n
    for team in teams.values():
        for u in team:
            friends = sum([1 for v in team if u != v and (u, v) not in w and (v, u) not in w])
            minFriends = min(friends, minFriends)
    return minFriends
            
def max_friends(teams):
    maxFriends = 0
    for team in teams.values():
        for u in team:
            friends = sum([1 for v in team if u != v and (u, v) not in w and (v, u) not in w])
            maxFriends = max(friends, maxFriends)
    return maxFriends

def avg_friends(teams):
    friends = 0
    for team in teams.values():
        friends += sum([1 for u in team for v in team if u != v and (u, v) not in w and (v, u) not in w])
    return friends / n
        
def min_preference(teams):
    ans = 1
    for t in teams:
        team = teams[t]
        for u in team:
            ans = min(ans, 1 / c[(u, t)])      
    return ans
            
def max_preference(teams):
    ans = -1
    for t in teams:
        team = teams[t]
        for u in team:
            ans = max(ans, 1 / c[(u, t)])      
    return ans

def avg_preference(teams):
    pref = 0
    for t in teams:
        team = teams[t]
        pref += sum([1 / c[(u, t)] for u in team])
    return pref / n

def friends_distribution(teams):
    dist = deque()
    for team in teams.values():
        for u in team:
            friends = sum([1 for v in team if u != v and (u, v) not in w and (v, u) not in w])
            dist.append(friends)
    return dist

def find_friends(student, teams):
    if student not in nodes:
        return "Not a valid student"
    friends = []
    for team in teams.values():
        for u in team:
            if u == student:
                friends = [v for v in team if u != v and (u, v) not in w and (v, u) not in w]
                return friends
    return []

def find_preference(student, teams):
    if student not in nodes:
        return "Not a valid student"
    for t in teams:
        team = teams[t]
        for u in team:
            if u == student:
                return 1 / c[(u, t)] 
    return -1

# %%
print(f'(optimal assignment) avg number of friends {avg_friends(teams)}')
print(f'(optimal assignment) min number of friends {min_friends(teams)}')
print(f'(optimal assignment) max number of friends {max_friends(teams)}')

print(f'(optimal assignment) avg preference {avg_preference(teams)}')
print(f'(optimal assignment) min preference {min_preference(teams)}')
print(f'(optimal assignment) max preference {max_preference(teams)}')
# Out:
# (optimal assignment) avg number of friends 0.5384615384615384
# (optimal assignment) min number of friends 0
# (optimal assignment) max number of friends 2
# (optimal assignment) avg preference 1.6153846153846154
# (optimal assignment) min preference 1
# (optimal assignment) max preference 6.0

# %%
for u in nodes:
    print(f"--- student {u} ---")
    opt_pref = find_preference(u, teams)
    opt_friends = find_friends(u, teams)
    print(f"friends = {opt_friends}, preference = {opt_pref}")
# Out:
# --- student 7b1b9 ---
# friends = ['7e351'], preference = 1.0
# --- student cfc5f ---
# friends = ['8b401'], preference = 3.0
# --- student 8b401 ---
# friends = ['cfc5f'], preference = 3.0
# --- student f6abd ---
# friends = ['eef1d'], preference = 1.0
# --- student eef1d ---
# friends = ['f6abd'], preference = 1.0
# --- student 7fd51 ---
# friends = ['f72f3'], preference = 1.0
# --- student f72f3 ---
# friends = ['1336f', '7fd51'], preference = 1.0
# --- student 1336f ---
# friends = ['f72f3'], preference = 1.0
# --- student ac44e ---
# friends = [], preference = 2.0
# --- student a3004 ---
# friends = [], preference = 3.0
# --- student ebf2d ---
# friends = [], preference = 1.0
# --- student 97c9a ---
# friends = [], preference = 3.0
# --- student e4cdc ---
# friends = ['88177'], preference = 1.0
# --- student 88177 ---
# friends = ['e4cdc'], preference = 1.0
# --- student 07ba3 ---
# friends = [], preference = 2.0
# --- student 1a1ba ---
# friends = [], preference = 1.0
# --- student 83784 ---
# friends = [], preference = 1.0
# --- student dbeb4 ---
# friends = ['db1a9'], preference = 1.0
# --- student db1a9 ---
# friends = ['dbeb4'], preference = 1.0
# --- student e116c ---
# friends = [], preference = 1.0
# --- student d7530 ---
# friends = [], preference = 2.0
# --- student 57a36 ---
# friends = [], preference = 1.0
# --- student a7e74 ---
# friends = [], preference = 1.0
# --- student a7efa ---
# friends = [], preference = 1.0
# --- student 133c7 ---
# friends = [], preference = 6.0
# --- student 7e351 ---
# friends = ['7b1b9'], preference = 1.0

# %%
pos=nx.spring_layout(G_c, k=0.2, iterations=20)
def draw_graph_with_teams(teams, title):
    colors = sns.color_palette("tab10", len(teams))
    colors_dict = dict(zip(sorted(teams.keys()), colors))

    color_map = []
    for node in G:
        for team in teams:
            if node in teams[team]:
                color_map.append(colors_dict[team])
                break
                
    nx.draw(G_c, node_color=color_map, pos=pos, with_labels=True)
    for node in G:
        if representatives[node]:
            x, y = pos[node]
            plt.text(x + 0.09, y + 0.01, '*', fontsize=12, color='black', ha='center', va='center')
    plt.title(title)
    legend_handles = [plt.Line2D([0], [0], marker='o', color='w', label=label, markersize=10, markerfacecolor=color, markeredgecolor=color) for color, label in zip(colors, colors_dict.keys())]
    plt.legend(handles=legend_handles)
    plt.show()

# %%
draw_graph_with_teams(teams, 'Friends and team assignment')
