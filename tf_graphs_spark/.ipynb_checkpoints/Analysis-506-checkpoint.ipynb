# %%
import networkx as nx
import numpy as np
import pickle
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
import scipy
from collections import deque
import seaborn as sns

# %%
lambdas = [10]
lambdasToString = [str(l) for l in lambdas]
# conflictGraphType = "friends"
# mainProjectDist = "uniform"
# secondaryProjectDist = "trunc_gaussian"
# input_file = f'./inputs/graph_n{n}_{conflictGraphType}_{mainProjectDist}_{secondaryProjectDist}.pickle'
# results_file = f'./results/graph_n{n}_lambda{l}_{conflictGraphType}_{mainProjectDist}_{secondaryProjectDist}.pickle'
input_file = f'./bu_spark_2022/csDS506.pickle'

# %% [markdown]
# ## Input analysis

# %%
def project_term(x):
    # Requires definition of lambda_
    res = 0
    # project preference term
    for u in nodes:
        for p in projects:
            if (u, p) in c:
                res += c[(u, p)] * x[(u, p)]
    res *= lambda_
    return res

def conflict_term(x):
    res = 0
    for e in edges:
        u, v = e
        inner_sum = 0
        for p in projects:
            inner_sum += x[(u, p)] * x[(v, p)]
        res += w[(u, v)] * (1 - inner_sum)
    return res
    
def f(x):
    # Requires definition of lambda_
    return project_term(x) + conflict_term(x)

# %%
with open(input_file, 'rb') as file:
    projects = pickle.load(file)
    capacities = pickle.load(file)
    numOfProjects = len(capacities)
    c = pickle.load(file)
    w = pickle.load(file)
    edges = pickle.load(file)
    wE = sum([w[e] for e in w])
    assignment = pickle.load(file)
    representatives = pickle.load(file)
    
G = nx.Graph()
G.add_edges_from(edges)
nodes = list(G.nodes)
n = len(nodes)
G_c = nx.complement(G)

# %%
proj_popularity = dict()
for p in projects:
    proj_popularity[p] = 0
    
for u in nodes:
    for p in projects:
        if (u, p) in c:
            proj_popularity[p] += c[(u, p)]
            
xs = [p[1: 20] for p in projects]
ys = proj_popularity.values()

plt.bar(xs, ys)
plt.xlabel('Project')
plt.xticks(rotation = 60)
plt.ylabel('Popularity')
plt.title(f'Project popularity')

plt.show()

# %%
G_c = nx.complement(G)
    
print(f'number of (conflict) edges = {len(edges)}')
nx.draw(G_c, pos=nx.spring_layout(G_c, k=0.2, iterations=20), with_labels=True)
plt.title(f'Friends graph')
plt.show()
# Out:
# number of (conflict) edges = 13952

# %% [markdown]
# ## Results analysis

# %%
settings = dict()
results = dict()
times = dict()

for l in lambdasToString:
#     results_file = f'./results/graph_n{n}_lambda{l}_{conflictGraphType}_{mainProjectDist}_{secondaryProjectDist}.pickle'
    results_file = f'./bu_spark_results/csDS506_lambda{l}.pickle'
    with open(results_file, 'rb') as file:
        settings[l] = pickle.load(file)
        edges = pickle.load(file)
        results[l] = pickle.load(file)
        times[l] = pickle.load(file)
        file.close()

# %%
obj_opt = dict()
obj_round12 = dict()
obj_round34 = dict()
obj_project = dict()
obj_conflict = dict()

x_frac12 = dict()
x_frac34 = dict()
x_round12 = dict()
x_round34 = dict()
x_opt = dict()
x_project = dict()
x_conflict = dict()

approx_ratio12 = dict()
approx_ratio34 = dict()

for i in range(len(lambdas)):
    l = lambdasToString[i]
    lambda_ = lambdas[i] * wE/ n
    res = results[l]
    obj_opt[l] = res["quad_val"]
    obj_round12[l] = res["rounded_val12"]
    obj_round34[l] = res["rounded_val34"]
    obj_project[l] = res["project_val"]
    obj_conflict[l] = res["conflict_val"]
    
    x_frac12[l] = res["frac_sol12"]
    x_frac34[l] = res["frac_sol34"]
    x_opt[l] = res["quad_sol"]
    x_round12[l] = res["rounded_sol12"]
    x_round34[l] = res["rounded_sol34"]
    x_project[l] = res["project_sol"]
    x_conflict[l] = res["conflict_sol"]
    
    approx_ratio12[l] = obj_round12[l] / obj_opt[l]
    approx_ratio34[l] = obj_round34[l] / obj_opt[l]
    

    print(f'\n======= lambda = {lambdas[i]} ==========')
    print(f'obj_round12 = {obj_round12[l]}, proj = {project_term(x_round12[l])}, conflict = {conflict_term(x_round12[l])}')
    print(f'obj_round34 = {obj_round34[l]}, proj = {project_term(x_round34[l])}, conflict = {conflict_term(x_round34[l])}')
    print(f'obj_opt = {obj_opt[l]}, proj = {project_term(x_opt[l])}, conflict = {conflict_term(x_opt[l])}')
    print(f'obj_project = {obj_project[l]}, proj = {project_term(x_project[l])}, conflict = {conflict_term(x_project[l])}')
    print(f'obj_conflict = {obj_conflict[l]}, proj = {project_term(x_conflict[l])}, conflict = {conflict_term(x_conflict[l])}')
    print(f'approx ratio (1/2 approx) = {obj_round12[l] / obj_opt[l]}')
    print(f'approx ratio (3/4 approx) = {obj_round34[l] / obj_opt[l]}')
    
    ind = ["obj_opt", "obj_round12", "obj_round34", "obj_project", "obj_conflict"]
    xs = [x_opt[l], x_round12[l], x_round34[l], x_project[l], x_conflict[l]]
    
    a = np.array([project_term(x) for x in xs])
    b = np.array([conflict_term(x) for x in xs])

    p1 = plt.bar(ind, a, color='green', label="project")
    p2 = plt.bar(ind, b, color='#FF0000', bottom=sum([a]), label="conflict")
    
    plt.legend()
    plt.show()
# Out:
# ======= lambda = 10 ==========
# obj_round12 = 129954.94493035306, proj = 116229.94493035306, conflict = 13725
# obj_round34 = 130062.46429543247, proj = 116368.35762876572, conflict = 13694.106666666648
# obj_opt = 130110.35762876576, proj = 116368.35762876576, conflict = 13742.0
# obj_project = 130021.35762876572, proj = 116368.35762876572, conflict = 13653.0
# obj_conflict = 49405.04247830781, proj = 35599.04247830781, conflict = 13806.0
# approx ratio (1/2 approx) = 0.9988055316944394
# approx ratio (3/4 approx) = 0.9996319022235728

# %% [markdown]
# ### Reconstruct optimal teams

# %%
def construct_teams(x):
    teams = dict()
    for p in projects:
        teams[p] = []

    for e in x:
        u, p = e
        if x[e] == 1:
            u, p = e
            teams[p].append(u)
            
    for p in projects:
        teams[p].sort()
        
    return teams
            
teams_opt = dict()
for l in lambdasToString:    
    teams_opt[l] = construct_teams(x_opt[l])
    l_val = l.replace('p', '.')
    print(f'\n======== lambda {l_val} ==========')
    print(teams_opt[l])
# Out:
# ======== lambda 10 ==========
# {'b09c1A': ['28bbe', '7e5b4', '808cb', 'cba6a', 'd729a'], '6c0f1A': ['4437f', '4f711', 'c8292', 'e2a40', 'f0c14'], 'f10d5A': ['0d24a', '2684a', '34706', '4b146', 'd51a0'], 'f0a5eA': ['6aff8', '995a5', 'b6861', 'd8c36', 'ff8ac'], 'a23d9A': ['0fa99', '79052', '9e1a4', 'd225d', 'fffe2'], '4a15fA': ['01653', '47d11'], 'eb50dA': ['285b3', '2a591', '6be1f'], 'be328A': ['cb944', 'ede24'], '7f7c0A': ['0fa51', '3f9ea'], '20ef0A': ['174fe', '277e2', 'e2f32'], 'acaecA': ['03dae', '7e05a', 'da8fa'], 'bd1f8A': ['3882e', '38e2a', '88177', 'c1783', 'd61b1'], '697f1A': ['07ba3', '0ac0b', '0bb20', '10718', '8cc4a'], '02088A': ['5c7bb', '6024e', '69695', '99fdf', 'ec344'], 'b09c1B': ['4bb9b', '90c36', 'a31f8', 'cd65d', 'dbeb4'], 'b09c1C': ['36bf2', '89b1b', '95506', 'ad98a', 'c0f80'], 'b09c1D': ['027b3', '2137a', '2cdf6', '371ec', '49f94'], 'b09c1E': ['05dc1', '0e191', 'ae1b8', 'aefc9', 'ca78f'], '4a15fB': ['98075'], '4a15fC': ['1003a', 'ddcf1'], '4a15fD': ['239b0', 'a3004'], '4a15fE': ['02ed3', '3e725', '59b09'], 'eb50dB': ['09ee0', 'f8117', 'fbda7'], 'eb50dC': ['48133', '58c1e', 'aae49'], 'eb50dD': ['3b6af', '8b401', 'dacea'], 'eb50dE': ['4576d', 'b31ec'], 'be328B': ['b5a51'], 'be328C': ['2c684'], 'be328D': ['3e878'], 'be328E': ['72cc1'], '7f7c0B': ['27f54', 'f2d45'], '7f7c0C': ['62de3', '6beb5'], '7f7c0D': ['eaac3'], '7f7c0E': ['fc95d'], '02088B': ['0e9fb', '100c3', '36fd2', '4c684', 'aeb8e'], '02088C': ['08e18', '0aa44', 'a3a06', 'dc9e1', 'fdb53'], '02088D': ['38b25', '45293', '4b771', '626e6', 'e7903'], '02088E': ['2e912', '48253', '99ba4', 'f3d21', 'f5e99'], '20ef0B': ['712d2', '7301f'], '20ef0C': ['15a0f', '30225', 'c3f2e'], 'acaecB': ['5485c', '6ace2'], 'acaecC': ['05b07', '1c2a8'], 'bd1f8B': ['202e8', '4f9dd', '5d597', 'c7939', 'd8dc3'], 'bd1f8C': ['52881', '725e9', 'c35e4', 'f65f7', 'fa523'], '6c0f1B': ['09e60', '3c948', '48726', '6fd10', 'f61b2'], 'f10d5B': ['5cf3a', '7fd51', '8d841', 'a9fbb', 'f73ff'], 'a23d9B': ['44114', '6f08d', 'c2def', 'f0e0b', 'fbfa2'], '697f1B': ['10cde', '7fd17', '86b6e', 'e1376', 'fccf2'], 'f0a5eB': ['3126f', 'e4d94', 'e6564', 'f73c1', 'ff084']}

# %% [markdown]
# ### Reconstruct teams (1/2 approx-algorithm)

# %%
teams_round12 = dict()
for l in lambdasToString:    
    teams_round12[l] = construct_teams(x_round12[l])
    l_val = l.replace('p', '.')
    print(f'\n======== lambda {l_val} ==========')
    print(teams_round12[l])
# Out:
# ======== lambda 10 ==========
# {'b09c1A': ['4bb9b', '89b1b', 'a31f8', 'aefc9', 'cba6a'], '6c0f1A': ['38b25', '4437f', '48726', 'c8292', 'e2a40'], 'f10d5A': ['34706', '5cf3a', '7fd51', '8d841', 'f73ff'], 'f0a5eA': ['3126f', '4576d', '995a5', 'f73c1', 'ff084'], 'a23d9A': ['0fa99', '9e1a4', 'c2def', 'f0e0b', 'fffe2'], '4a15fA': ['01653', '47d11'], 'eb50dA': ['285b3', '6be1f'], 'be328A': ['72cc1'], '7f7c0A': ['6beb5'], '20ef0A': ['15a0f', '277e2', 'c3f2e'], 'acaecA': ['03dae', '1c2a8', '7e05a'], 'bd1f8A': ['38e2a', '4f9dd', '88177', 'd8dc3', 'f65f7'], '697f1A': ['07ba3', '0ac0b', '0bb20', '10718', '8cc4a'], '02088A': ['0e9fb', '36fd2', '5c7bb', '6024e', '69695'], 'b09c1B': ['0e191', '36bf2', '90c36', 'cd65d', 'dbeb4'], 'b09c1C': ['05dc1', '2137a', '371ec', 'ad98a', 'ca78f'], 'b09c1D': ['027b3', '28bbe', '7e5b4', '808cb', 'd729a'], 'b09c1E': ['2cdf6', '49f94', '95506', 'ae1b8', 'c0f80'], '4a15fB': ['1003a'], '4a15fC': ['02ed3', '3e725', '59b09'], '4a15fD': ['98075', 'ddcf1'], '4a15fE': ['239b0', 'a3004'], 'eb50dB': ['3b6af', '8b401', 'b31ec', 'dacea', 'f8117'], 'eb50dC': ['2a591', 'aae49'], 'eb50dD': ['48133', '58c1e'], 'eb50dE': ['09ee0', 'fbda7'], 'be328B': ['2c684', 'ede24'], 'be328C': ['3e878'], 'be328D': ['fc95d'], 'be328E': ['b5a51'], '7f7c0B': ['0fa51', '27f54'], '7f7c0C': ['62de3', '79052'], '7f7c0D': ['f2d45'], '7f7c0E': ['3f9ea'], '02088B': ['45293', '52881', '99fdf', 'ec344'], '02088C': ['0aa44', '4b771', '4c684', 'dc9e1', 'f5e99'], '02088D': ['100c3', '2e912', '48253', 'aeb8e', 'f3d21'], '02088E': ['08e18', '09e60', 'a3a06', 'e7903', 'fdb53'], '20ef0B': ['cb944', 'e2f32'], '20ef0C': ['174fe', '30225', '712d2', '7301f'], 'acaecB': ['5485c', '6ace2', 'da8fa'], 'acaecC': ['05b07', '6aff8', 'ff8ac'], 'bd1f8B': ['3882e', '5d597', 'c1783', 'c7939', 'd61b1'], 'bd1f8C': ['202e8', '725e9', '99ba4', 'c35e4', 'fa523'], '6c0f1B': ['3c948', '4f711', '6fd10', 'f0c14', 'f61b2'], 'f10d5B': ['0d24a', '2684a', '4b146', 'a9fbb', 'd51a0'], 'a23d9B': ['44114', '626e6', '6f08d', 'd225d', 'fbfa2'], '697f1B': ['10cde', '7fd17', '86b6e', 'e1376', 'fccf2'], 'f0a5eB': ['b6861', 'd8c36', 'e4d94', 'e6564', 'eaac3']}

# %% [markdown]
# ### Reconstruct teams (3/4 approx-algorithm)

# %%
teams_round34 = dict()
for l in lambdasToString:    
    teams_round34[l] = construct_teams(x_round34[l])
    l_val = l.replace('p', '.')
    print(f'\n======== lambda {l_val} ==========')
    print(teams_round34[l])
# Out:
# ======== lambda 10 ==========
# {'b09c1A': ['0e191', '371ec', '49f94', '7e5b4', 'aefc9'], '6c0f1A': ['09e60', '3c948', '4437f', '4f711', 'f61b2'], 'f10d5A': ['0d24a', '34706', '4b146', '8d841', 'f73ff'], 'f0a5eA': ['b6861', 'd8c36', 'e4d94', 'ff084'], 'a23d9A': ['0fa99', '6f08d', '79052', 'f0e0b', 'fbfa2'], '4a15fA': ['01653', '59b09'], 'eb50dA': ['aae49', 'fbda7'], 'be328A': ['3e878'], '7f7c0A': ['0fa51'], '20ef0A': ['15a0f', '7301f'], 'acaecA': ['7e05a'], 'bd1f8A': ['3882e', 'c1783', 'c35e4', 'f65f7', 'fa523'], '697f1A': ['0ac0b', '10cde', '86b6e', 'e1376', 'fccf2'], '02088A': ['48253', '6024e', '626e6', 'dc9e1', 'fdb53'], 'b09c1B': ['95506', 'a31f8', 'cba6a', 'cd65d', 'd729a'], 'b09c1C': ['027b3', '4bb9b', '808cb', 'ae1b8', 'dbeb4'], 'b09c1D': ['05dc1', '2cdf6', '36bf2', '90c36', 'ad98a'], 'b09c1E': ['2137a', '28bbe', '89b1b', 'c0f80', 'ca78f'], '4a15fB': ['02ed3', '47d11'], '4a15fC': ['a3004', 'ddcf1'], '4a15fD': ['1003a', '3e725'], '4a15fE': ['239b0', '98075'], 'eb50dB': ['285b3', '8b401'], 'eb50dC': ['09ee0', '3b6af'], 'eb50dD': ['48133', 'b31ec'], 'eb50dE': ['58c1e', '6be1f'], 'be328B': ['72cc1'], 'be328C': ['b5a51'], 'be328D': [], 'be328E': ['2c684'], '7f7c0B': ['62de3'], '7f7c0C': ['fc95d'], '7f7c0D': ['6beb5'], '7f7c0E': ['f2d45'], '02088B': ['36fd2', '38b25', '69695', '99ba4', 'a3a06'], '02088C': ['45293', '4b771', '99fdf', 'aeb8e', 'f3d21'], '02088D': ['08e18', '0aa44', '4c684', 'e7903', 'f5e99'], '02088E': ['0e9fb', '100c3', '2e912', '5c7bb', 'ec344'], '20ef0B': ['30225', 'c3f2e'], '20ef0C': ['277e2', 'e2f32'], 'acaecB': ['6ace2', 'da8fa'], 'acaecC': ['1c2a8', '5485c'], 'bd1f8B': ['5d597', '725e9', '88177', 'd61b1', 'd8dc3'], 'bd1f8C': ['202e8', '38e2a', '4f9dd', '52881', 'c7939'], '6c0f1B': ['48726', '6fd10', 'c8292', 'e2a40', 'f0c14'], 'f10d5B': ['2684a', '5cf3a', '7fd51', 'a9fbb', 'd51a0'], 'a23d9B': ['44114', '9e1a4', 'c2def', 'd225d', 'fffe2'], '697f1B': ['07ba3', '0bb20', '10718', '7fd17', '8cc4a'], 'f0a5eB': ['3126f', '6aff8', 'f73c1', 'ff8ac']}

# %% [markdown]
# ### Compare $\lambda \sum_v \sum_t c_{vt}x_{vt}$ and $w(E)$
# If $\alpha = \lambda \sum_v \sum_t c_{vt}x_{vt} - w(E) \geq 0$, then we can apply the $3/4$-approximation algorithm.
# Otherwise, the guarantees of the algorithm do not hold.

# %%
print(f'w(E) = {wE}')
for l, lstr in zip(lambdas, lambdasToString):
    lambda_ = l * wE / n
    projectsVal = project_term(x_round34[lstr])
    print(f'\n===== lambda = {l} ======')
    print(f'projects term value = {projectsVal}')
    print(f'a = {projectsVal - wE}')
# Out:
# w(E) = 13952
#
# ===== lambda = 10 ======
# projects term value = 116368.35762876572
# a = 102416.35762876572

# %% [markdown]
# ### How many students got a project they like?

# %%
def calc_preference_stats(teams):
    res = 0
    students = []
    for t in teams:
        team = teams[t]
        for u in team:
            res += 1 if (u, t) in c else 0
            students.append(u)
    res /= n
    return res, students


for l in lambdasToString:
    print(f'\n====== lambda = {l_val} =======')
    
    teams = teams_opt[l]
    res, students = calc_preference_stats(teams)
    
    l_val = l.replace('p', '.')
    print(f'(Optimal teams) percentage of students that got a project they like = {res}')
    print(f'list of students that got a project they like: {students}')
    
    teams = teams_round12[l]
    res, students = calc_preference_stats(teams)
    
    l_val = l.replace('p', '.')
    print(f'(1/2 approx alg) percentage of students that got a project they like = {res}')
    print(f'list of students that got a project they like: {students}')
    
    teams = teams_round34[l]
    res, students = calc_preference_stats(teams)
    
    l_val = l.replace('p', '.')
    print(f'(3/4 approx alg) percentage of students that got a project they like = {res}')
    print(f'list of students that got a project they like: {students}')
# Out:
# ====== lambda = 10 =======
# (Optimal teams) percentage of students that got a project they like = 1.0
# list of students that got a project they like: ['28bbe', '7e5b4', '808cb', 'cba6a', 'd729a', '4437f', '4f711', 'c8292', 'e2a40', 'f0c14', '0d24a', '2684a', '34706', '4b146', 'd51a0', '6aff8', '995a5', 'b6861', 'd8c36', 'ff8ac', '0fa99', '79052', '9e1a4', 'd225d', 'fffe2', '01653', '47d11', '285b3', '2a591', '6be1f', 'cb944', 'ede24', '0fa51', '3f9ea', '174fe', '277e2', 'e2f32', '03dae', '7e05a', 'da8fa', '3882e', '38e2a', '88177', 'c1783', 'd61b1', '07ba3', '0ac0b', '0bb20', '10718', '8cc4a', '5c7bb', '6024e', '69695', '99fdf', 'ec344', '4bb9b', '90c36', 'a31f8', 'cd65d', 'dbeb4', '36bf2', '89b1b', '95506', 'ad98a', 'c0f80', '027b3', '2137a', '2cdf6', '371ec', '49f94', '05dc1', '0e191', 'ae1b8', 'aefc9', 'ca78f', '98075', '1003a', 'ddcf1', '239b0', 'a3004', '02ed3', '3e725', '59b09', '09ee0', 'f8117', 'fbda7', '48133', '58c1e', 'aae49', '3b6af', '8b401', 'dacea', '4576d', 'b31ec', 'b5a51', '2c684', '3e878', '72cc1', '27f54', 'f2d45', '62de3', '6beb5', 'eaac3', 'fc95d', '0e9fb', '100c3', '36fd2', '4c684', 'aeb8e', '08e18', '0aa44', 'a3a06', 'dc9e1', 'fdb53', '38b25', '45293', '4b771', '626e6', 'e7903', '2e912', '48253', '99ba4', 'f3d21', 'f5e99', '712d2', '7301f', '15a0f', '30225', 'c3f2e', '5485c', '6ace2', '05b07', '1c2a8', '202e8', '4f9dd', '5d597', 'c7939', 'd8dc3', '52881', '725e9', 'c35e4', 'f65f7', 'fa523', '09e60', '3c948', '48726', '6fd10', 'f61b2', '5cf3a', '7fd51', '8d841', 'a9fbb', 'f73ff', '44114', '6f08d', 'c2def', 'f0e0b', 'fbfa2', '10cde', '7fd17', '86b6e', 'e1376', 'fccf2', '3126f', 'e4d94', 'e6564', 'f73c1', 'ff084']
# (1/2 approx alg) percentage of students that got a project they like = 1.0
# list of students that got a project they like: ['4bb9b', '89b1b', 'a31f8', 'aefc9', 'cba6a', '38b25', '4437f', '48726', 'c8292', 'e2a40', '34706', '5cf3a', '7fd51', '8d841', 'f73ff', '3126f', '4576d', '995a5', 'f73c1', 'ff084', '0fa99', '9e1a4', 'c2def', 'f0e0b', 'fffe2', '01653', '47d11', '285b3', '6be1f', '72cc1', '6beb5', '15a0f', '277e2', 'c3f2e', '03dae', '1c2a8', '7e05a', '38e2a', '4f9dd', '88177', 'd8dc3', 'f65f7', '07ba3', '0ac0b', '0bb20', '10718', '8cc4a', '0e9fb', '36fd2', '5c7bb', '6024e', '69695', '0e191', '36bf2', '90c36', 'cd65d', 'dbeb4', '05dc1', '2137a', '371ec', 'ad98a', 'ca78f', '027b3', '28bbe', '7e5b4', '808cb', 'd729a', '2cdf6', '49f94', '95506', 'ae1b8', 'c0f80', '1003a', '02ed3', '3e725', '59b09', '98075', 'ddcf1', '239b0', 'a3004', '3b6af', '8b401', 'b31ec', 'dacea', 'f8117', '2a591', 'aae49', '48133', '58c1e', '09ee0', 'fbda7', '2c684', 'ede24', '3e878', 'fc95d', 'b5a51', '0fa51', '27f54', '62de3', '79052', 'f2d45', '3f9ea', '45293', '52881', '99fdf', 'ec344', '0aa44', '4b771', '4c684', 'dc9e1', 'f5e99', '100c3', '2e912', '48253', 'aeb8e', 'f3d21', '08e18', '09e60', 'a3a06', 'e7903', 'fdb53', 'cb944', 'e2f32', '174fe', '30225', '712d2', '7301f', '5485c', '6ace2', 'da8fa', '05b07', '6aff8', 'ff8ac', '3882e', '5d597', 'c1783', 'c7939', 'd61b1', '202e8', '725e9', '99ba4', 'c35e4', 'fa523', '3c948', '4f711', '6fd10', 'f0c14', 'f61b2', '0d24a', '2684a', '4b146', 'a9fbb', 'd51a0', '44114', '626e6', '6f08d', 'd225d', 'fbfa2', '10cde', '7fd17', '86b6e', 'e1376', 'fccf2', 'b6861', 'd8c36', 'e4d94', 'e6564', 'eaac3']
# (3/4 approx alg) percentage of students that got a project they like = 0.9107142857142857
# list of students that got a project they like: ['0e191', '371ec', '49f94', '7e5b4', 'aefc9', '09e60', '3c948', '4437f', '4f711', 'f61b2', '0d24a', '34706', '4b146', '8d841', 'f73ff', 'b6861', 'd8c36', 'e4d94', 'ff084', '0fa99', '6f08d', '79052', 'f0e0b', 'fbfa2', '01653', '59b09', 'aae49', 'fbda7', '3e878', '0fa51', '15a0f', '7301f', '7e05a', '3882e', 'c1783', 'c35e4', 'f65f7', 'fa523', '0ac0b', '10cde', '86b6e', 'e1376', 'fccf2', '48253', '6024e', '626e6', 'dc9e1', 'fdb53', '95506', 'a31f8', 'cba6a', 'cd65d', 'd729a', '027b3', '4bb9b', '808cb', 'ae1b8', 'dbeb4', '05dc1', '2cdf6', '36bf2', '90c36', 'ad98a', '2137a', '28bbe', '89b1b', 'c0f80', 'ca78f', '02ed3', '47d11', 'a3004', 'ddcf1', '1003a', '3e725', '239b0', '98075', '285b3', '8b401', '09ee0', '3b6af', '48133', 'b31ec', '58c1e', '6be1f', '72cc1', 'b5a51', '2c684', '62de3', 'fc95d', '6beb5', 'f2d45', '36fd2', '38b25', '69695', '99ba4', 'a3a06', '45293', '4b771', '99fdf', 'aeb8e', 'f3d21', '08e18', '0aa44', '4c684', 'e7903', 'f5e99', '0e9fb', '100c3', '2e912', '5c7bb', 'ec344', '30225', 'c3f2e', '277e2', 'e2f32', '6ace2', 'da8fa', '1c2a8', '5485c', '5d597', '725e9', '88177', 'd61b1', 'd8dc3', '202e8', '38e2a', '4f9dd', '52881', 'c7939', '48726', '6fd10', 'c8292', 'e2a40', 'f0c14', '2684a', '5cf3a', '7fd51', 'a9fbb', 'd51a0', '44114', '9e1a4', 'c2def', 'd225d', 'fffe2', '07ba3', '0bb20', '10718', '7fd17', '8cc4a', '3126f', '6aff8', 'f73c1', 'ff8ac']

# %% [markdown]
# ### How many teammate friends each student has? (lambda = fixed)

# %%
l = lambdasToString[0]
teams1 = teams_opt[l]
teams2 = teams_round12[l]

def count_friends(teams):
    friends = dict()
    for team in teams.values():
        for u in team:
            friends[u] = len([1 for v in team if u != v and (u, v) not in w and (v, u) not in w])
    return friends

friends_opt = count_friends(teams1)
friends_round = count_friends(teams2)

avgFriendsOpt = sum(friends_opt.values()) / n
avgFriendsRound = sum(friends_round.values()) / n

xs = [str(u) for u in nodes]
ys = friends_opt.values()

plt.bar(xs, ys)
plt.xlabel('Students')
plt.xticks(rotation=45)
plt.ylabel('# teammate friends')
plt.title(f'Number of teammate friends (optimal solution), (lambda = {l})')

plt.show()

xs = [str(u) for u in nodes]
ys = friends_round.values()

plt.bar(xs, ys)
plt.xlabel('Students')
plt.xticks(rotation=45)
plt.ylabel('# teammate friends')
plt.title(f'Number of teammate friends (1/2 approximation), (lambda = {l})')

plt.show()

print(f'avgFriendsOpt = {avgFriendsOpt}')
print(f'avgFriendsRound  (1/2 approximation) = {avgFriendsRound}')
# Out:
# avgFriendsOpt = 0.6547619047619048
# avgFriendsRound  (1/2 approximation) = 0.4880952380952381

# %% [markdown]
# ### Teams comparison (lambda = fixed)

# %%
l = lambdasToString[0]
tm = teams_round12[l]
tm_opt = teams_opt[l]
print(f'optimal team {tm_opt}')
print(f'pipage team {tm}')
sameTeamsAndProject = len([1 for p in projects if tm[p] == tm_opt[p]])
print(f'number of identical teams and projects = {sameTeamsAndProject}')
sameTeams = len([t for t in tm if t in tm_opt])
print(f'number of identical teams = {sameTeams}')
# Out:
# optimal team {'b09c1A': ['28bbe', '7e5b4', '808cb', 'cba6a', 'd729a'], '6c0f1A': ['4437f', '4f711', 'c8292', 'e2a40', 'f0c14'], 'f10d5A': ['0d24a', '2684a', '34706', '4b146', 'd51a0'], 'f0a5eA': ['6aff8', '995a5', 'b6861', 'd8c36', 'ff8ac'], 'a23d9A': ['0fa99', '79052', '9e1a4', 'd225d', 'fffe2'], '4a15fA': ['01653', '47d11'], 'eb50dA': ['285b3', '2a591', '6be1f'], 'be328A': ['cb944', 'ede24'], '7f7c0A': ['0fa51', '3f9ea'], '20ef0A': ['174fe', '277e2', 'e2f32'], 'acaecA': ['03dae', '7e05a', 'da8fa'], 'bd1f8A': ['3882e', '38e2a', '88177', 'c1783', 'd61b1'], '697f1A': ['07ba3', '0ac0b', '0bb20', '10718', '8cc4a'], '02088A': ['5c7bb', '6024e', '69695', '99fdf', 'ec344'], 'b09c1B': ['4bb9b', '90c36', 'a31f8', 'cd65d', 'dbeb4'], 'b09c1C': ['36bf2', '89b1b', '95506', 'ad98a', 'c0f80'], 'b09c1D': ['027b3', '2137a', '2cdf6', '371ec', '49f94'], 'b09c1E': ['05dc1', '0e191', 'ae1b8', 'aefc9', 'ca78f'], '4a15fB': ['98075'], '4a15fC': ['1003a', 'ddcf1'], '4a15fD': ['239b0', 'a3004'], '4a15fE': ['02ed3', '3e725', '59b09'], 'eb50dB': ['09ee0', 'f8117', 'fbda7'], 'eb50dC': ['48133', '58c1e', 'aae49'], 'eb50dD': ['3b6af', '8b401', 'dacea'], 'eb50dE': ['4576d', 'b31ec'], 'be328B': ['b5a51'], 'be328C': ['2c684'], 'be328D': ['3e878'], 'be328E': ['72cc1'], '7f7c0B': ['27f54', 'f2d45'], '7f7c0C': ['62de3', '6beb5'], '7f7c0D': ['eaac3'], '7f7c0E': ['fc95d'], '02088B': ['0e9fb', '100c3', '36fd2', '4c684', 'aeb8e'], '02088C': ['08e18', '0aa44', 'a3a06', 'dc9e1', 'fdb53'], '02088D': ['38b25', '45293', '4b771', '626e6', 'e7903'], '02088E': ['2e912', '48253', '99ba4', 'f3d21', 'f5e99'], '20ef0B': ['712d2', '7301f'], '20ef0C': ['15a0f', '30225', 'c3f2e'], 'acaecB': ['5485c', '6ace2'], 'acaecC': ['05b07', '1c2a8'], 'bd1f8B': ['202e8', '4f9dd', '5d597', 'c7939', 'd8dc3'], 'bd1f8C': ['52881', '725e9', 'c35e4', 'f65f7', 'fa523'], '6c0f1B': ['09e60', '3c948', '48726', '6fd10', 'f61b2'], 'f10d5B': ['5cf3a', '7fd51', '8d841', 'a9fbb', 'f73ff'], 'a23d9B': ['44114', '6f08d', 'c2def', 'f0e0b', 'fbfa2'], '697f1B': ['10cde', '7fd17', '86b6e', 'e1376', 'fccf2'], 'f0a5eB': ['3126f', 'e4d94', 'e6564', 'f73c1', 'ff084']}
# pipage team {'b09c1A': ['4bb9b', '89b1b', 'a31f8', 'aefc9', 'cba6a'], '6c0f1A': ['38b25', '4437f', '48726', 'c8292', 'e2a40'], 'f10d5A': ['34706', '5cf3a', '7fd51', '8d841', 'f73ff'], 'f0a5eA': ['3126f', '4576d', '995a5', 'f73c1', 'ff084'], 'a23d9A': ['0fa99', '9e1a4', 'c2def', 'f0e0b', 'fffe2'], '4a15fA': ['01653', '47d11'], 'eb50dA': ['285b3', '6be1f'], 'be328A': ['72cc1'], '7f7c0A': ['6beb5'], '20ef0A': ['15a0f', '277e2', 'c3f2e'], 'acaecA': ['03dae', '1c2a8', '7e05a'], 'bd1f8A': ['38e2a', '4f9dd', '88177', 'd8dc3', 'f65f7'], '697f1A': ['07ba3', '0ac0b', '0bb20', '10718', '8cc4a'], '02088A': ['0e9fb', '36fd2', '5c7bb', '6024e', '69695'], 'b09c1B': ['0e191', '36bf2', '90c36', 'cd65d', 'dbeb4'], 'b09c1C': ['05dc1', '2137a', '371ec', 'ad98a', 'ca78f'], 'b09c1D': ['027b3', '28bbe', '7e5b4', '808cb', 'd729a'], 'b09c1E': ['2cdf6', '49f94', '95506', 'ae1b8', 'c0f80'], '4a15fB': ['1003a'], '4a15fC': ['02ed3', '3e725', '59b09'], '4a15fD': ['98075', 'ddcf1'], '4a15fE': ['239b0', 'a3004'], 'eb50dB': ['3b6af', '8b401', 'b31ec', 'dacea', 'f8117'], 'eb50dC': ['2a591', 'aae49'], 'eb50dD': ['48133', '58c1e'], 'eb50dE': ['09ee0', 'fbda7'], 'be328B': ['2c684', 'ede24'], 'be328C': ['3e878'], 'be328D': ['fc95d'], 'be328E': ['b5a51'], '7f7c0B': ['0fa51', '27f54'], '7f7c0C': ['62de3', '79052'], '7f7c0D': ['f2d45'], '7f7c0E': ['3f9ea'], '02088B': ['45293', '52881', '99fdf', 'ec344'], '02088C': ['0aa44', '4b771', '4c684', 'dc9e1', 'f5e99'], '02088D': ['100c3', '2e912', '48253', 'aeb8e', 'f3d21'], '02088E': ['08e18', '09e60', 'a3a06', 'e7903', 'fdb53'], '20ef0B': ['cb944', 'e2f32'], '20ef0C': ['174fe', '30225', '712d2', '7301f'], 'acaecB': ['5485c', '6ace2', 'da8fa'], 'acaecC': ['05b07', '6aff8', 'ff8ac'], 'bd1f8B': ['3882e', '5d597', 'c1783', 'c7939', 'd61b1'], 'bd1f8C': ['202e8', '725e9', '99ba4', 'c35e4', 'fa523'], '6c0f1B': ['3c948', '4f711', '6fd10', 'f0c14', 'f61b2'], 'f10d5B': ['0d24a', '2684a', '4b146', 'a9fbb', 'd51a0'], 'a23d9B': ['44114', '626e6', '6f08d', 'd225d', 'fbfa2'], '697f1B': ['10cde', '7fd17', '86b6e', 'e1376', 'fccf2'], 'f0a5eB': ['b6861', 'd8c36', 'e4d94', 'e6564', 'eaac3']}
# number of identical teams and projects = 3
# number of identical teams = 49

# %% [markdown]
# ### Comparing solutions of different lambdas given a fixed objective function

# %% [markdown]
# #### Remark
# The optimal solution remains the same for different lambdas (?).\
# Can we think of a counter-example?
#
# The same is not true for the pipage algorithm solution.

# %% [markdown]
# ### In-team Conflicts

# %%
# conflicts for optimal teams
def calc_conflicts(teams):
    conflicts = dict()
    for t in teams:
        team = teams[t]
        conflicts[t] = 0
        if team:
            conflicts[t] = sum([1 for u in team for v in team if u < v and (u, v) in edges or (v, u) in edges])
        
    return conflicts

conflicts_opt = dict()
avgConflicts_opt = dict()
for l in lambdasToString:
    conflicts_opt[l] = calc_conflicts(teams_opt[l])
    nonEmptyTeams = [t for t in teams_opt[l] if t]
    avgConflicts_opt[l] = sum(conflicts_opt[l].values()) / len(nonEmptyTeams)

    xs = projects
    ys = conflicts_opt[l].values()

    plt.bar(xs, ys)
    plt.xlabel('Project')
    plt.xticks(rotation=60)
    plt.ylabel('Conflicts')
    plt.title(f'Conflicts per project (optimal rounding solution), (lambda = {l})')

    plt.show()

for l in lambdasToString:
    print(f'avg number of conflicts in a team = {avgConflicts_opt[l]}')
# Out:
# avg number of conflicts in a team = 6.755102040816326

# %%
# conflicts for pipage algorithm teams
conflicts = dict()
avgConflicts = dict()
for l in lambdasToString:
    conflicts[l] = calc_conflicts(teams_round12[l])
    nonEmptyTeams = [t for t in teams_round12[l] if t]
    avgConflicts[l] = sum(conflicts[l].values()) / len(nonEmptyTeams)

    xs = projects
    ys = conflicts[l].values()

    plt.bar(xs, ys)
    plt.xlabel('Project')
    plt.xticks(rotation=60)
    plt.ylabel('Conflicts')
    plt.title(f'Conflicts per project (1/2 approximation algorithm), (lambda = {l})')

    plt.show()

for l in lambdasToString:
    print(f'avg number of conflicts in a team = {avgConflicts[l]}')
# Out:
# avg number of conflicts in a team = 7.204081632653061

# %% [markdown]
# ### Time (seconds) for each step

# %%
for l in lambdasToString:
    #del times["1.5"]["conflict_only"]
    plt.pie(times[l].values(), labels=times[l].keys(), normalize=True)
    plt.legend(loc='upper left')
    plt.show()

# %% [markdown]
# ## Comparison with manual solution

# %%
def min_friends(teams):
    minFriends = n
    for team in teams.values():
        for u in team:
            friends = sum([1 for v in team if u != v and (u, v) not in w and (v, u) not in w])
            minFriends = min(friends, minFriends)
    return minFriends
            
def max_friends(teams):
    maxFriends = 0
    for team in teams.values():
        for u in team:
            friends = sum([1 for v in team if u != v and (u, v) not in w and (v, u) not in w])
            maxFriends = max(friends, maxFriends)
    return maxFriends

def avg_friends(teams):
    friends = 0
    for team in teams.values():
        friends += sum([1 for u in team for v in team if u != v and (u, v) not in w and (v, u) not in w])
    return friends / n
        
def min_preference(teams):
    ans = 1
    for t in teams:
        team = teams[t]
        for u in team:
            ans = min(ans, 1 / c[(u, t)])      
    return ans
            
def max_preference(teams):
    ans = -1
    for t in teams:
        team = teams[t]
        for u in team:
            ans = max(ans, 1 / c[(u, t)])      
    return ans

def avg_preference(teams):
    pref = 0
    for t in teams:
        team = teams[t]
        pref += sum([1 / c[(u, t)] for u in team])
    return pref / n

# %%
def group_keys_by_value(input_dict):
    grouped_dict = {}
    
    for key, value in input_dict.items():
        if value in grouped_dict:
            grouped_dict[value].append(key)
        else:
            grouped_dict[value] = [key]
    
    return grouped_dict
teams_manual = group_keys_by_value(assignment)

# %%
teams_manual
# Out:
# {'eb50dE': ['3e878', 'fc95d', '6be1f', 'cb944'],
#  '02088A': ['48253', 'e7903', '45293', 'f3d21'],
#  '20ef0C': ['cba6a', '7301f', '174fe', '2e912'],
#  'be328B': ['03dae', '89b1b', '36fd2', '0e9fb'],
#  '02088C': ['69695', '277e2', '626e6', 'f61b2'],
#  'f0a5eB': ['a9fbb', 'aefc9', '36bf2', 'da8fa'],
#  'acaecC': ['7e5b4', '6ace2', '5485c', 'c7939'],
#  '4a15fC': ['47d11', 'ddcf1', '48726', '01653'],
#  '697f1A': ['e2a40', '4437f', '8cc4a', '34706'],
#  'bd1f8A': ['3882e', '4b771', '38b25', '0bb20'],
#  '7f7c0B': ['f2d45', '3b6af', '2684a', 'eaac3'],
#  '7f7c0A': ['a3004', '239b0', '27f54', '0fa51'],
#  '6c0f1B': ['4f711', '6fd10', '10718', 'c8292'],
#  'f0a5eA': ['0fa99', 'c2def', 'a3a06', 'd225d'],
#  '20ef0B': ['4f9dd', '30225', 'e2f32', 'f8117'],
#  'b09c1A': ['ff8ac', 'ad98a', '05b07', '995a5'],
#  'be328D': ['09e60', '58c1e', '48133', 'ede24'],
#  'a23d9A': ['fffe2', '62de3', '3126f', '9e1a4', '79052'],
#  'eb50dD': ['8b401', '4576d', 'dacea', '027b3', '49f94'],
#  '6c0f1A': ['05dc1', 'ca78f', 'e4d94', 'e6564', '3c948'],
#  '02088D': ['99fdf', '1c2a8', '5c7bb', 'aeb8e'],
#  'a23d9B': ['8d841', 'f73c1', '2137a', '6f08d', 'ff084'],
#  '7f7c0D': ['d8dc3', '72cc1', 'b5a51', '3f9ea'],
#  'bd1f8B': ['5d597', '07ba3', '0ac0b', '202e8'],
#  '4a15fA': ['725e9', '02ed3', '88177', '38e2a'],
#  'f10d5A': ['0d24a', 'd51a0', 'f73ff', '4b146'],
#  '7f7c0C': ['ae1b8', 'f0c14', '6beb5', '712d2'],
#  'be328C': ['d61b1', '2c684', 'c1783', 'aae49'],
#  'acaecB': ['7fd17', '86b6e', '10cde', 'fccf2'],
#  'be328A': ['09ee0', '98075', 'fbda7', '2a591'],
#  '02088E': ['99ba4', '100c3', 'f5e99', '52881'],
#  '02088B': ['fdb53', '08e18', 'fbfa2', '44114'],
#  'eb50dB': ['f0e0b', '4bb9b', '285b3', 'a31f8'],
#  '20ef0A': ['15a0f', '0aa44', 'c3f2e', 'dc9e1'],
#  'eb50dC': ['b31ec', '95506', '6024e', 'ec344'],
#  'acaecA': ['b6861', 'd8c36', '6aff8', '4c684'],
#  '4a15fD': ['1003a', '7e05a', 'f65f7', '0e191'],
#  'b09c1B': ['371ec', '2cdf6', '5cf3a', 'c0f80'],
#  '697f1B': ['cd65d', 'dbeb4', 'e1376', '90c36'],
#  '4a15fB': ['c35e4', '59b09', 'fa523', '3e725'],
#  'eb50dA': ['28bbe', '7fd51', '808cb', 'd729a']}

# %%
teams_optimal = teams_opt['10']
teams_optimal
# Out:
# {'b09c1A': ['28bbe', '7e5b4', '808cb', 'cba6a', 'd729a'],
#  '6c0f1A': ['4437f', '4f711', 'c8292', 'e2a40', 'f0c14'],
#  'f10d5A': ['0d24a', '2684a', '34706', '4b146', 'd51a0'],
#  'f0a5eA': ['6aff8', '995a5', 'b6861', 'd8c36', 'ff8ac'],
#  'a23d9A': ['0fa99', '79052', '9e1a4', 'd225d', 'fffe2'],
#  '4a15fA': ['01653', '47d11'],
#  'eb50dA': ['285b3', '2a591', '6be1f'],
#  'be328A': ['cb944', 'ede24'],
#  '7f7c0A': ['0fa51', '3f9ea'],
#  '20ef0A': ['174fe', '277e2', 'e2f32'],
#  'acaecA': ['03dae', '7e05a', 'da8fa'],
#  'bd1f8A': ['3882e', '38e2a', '88177', 'c1783', 'd61b1'],
#  '697f1A': ['07ba3', '0ac0b', '0bb20', '10718', '8cc4a'],
#  '02088A': ['5c7bb', '6024e', '69695', '99fdf', 'ec344'],
#  'b09c1B': ['4bb9b', '90c36', 'a31f8', 'cd65d', 'dbeb4'],
#  'b09c1C': ['36bf2', '89b1b', '95506', 'ad98a', 'c0f80'],
#  'b09c1D': ['027b3', '2137a', '2cdf6', '371ec', '49f94'],
#  'b09c1E': ['05dc1', '0e191', 'ae1b8', 'aefc9', 'ca78f'],
#  '4a15fB': ['98075'],
#  '4a15fC': ['1003a', 'ddcf1'],
#  '4a15fD': ['239b0', 'a3004'],
#  '4a15fE': ['02ed3', '3e725', '59b09'],
#  'eb50dB': ['09ee0', 'f8117', 'fbda7'],
#  'eb50dC': ['48133', '58c1e', 'aae49'],
#  'eb50dD': ['3b6af', '8b401', 'dacea'],
#  'eb50dE': ['4576d', 'b31ec'],
#  'be328B': ['b5a51'],
#  'be328C': ['2c684'],
#  'be328D': ['3e878'],
#  'be328E': ['72cc1'],
#  '7f7c0B': ['27f54', 'f2d45'],
#  '7f7c0C': ['62de3', '6beb5'],
#  '7f7c0D': ['eaac3'],
#  '7f7c0E': ['fc95d'],
#  '02088B': ['0e9fb', '100c3', '36fd2', '4c684', 'aeb8e'],
#  '02088C': ['08e18', '0aa44', 'a3a06', 'dc9e1', 'fdb53'],
#  '02088D': ['38b25', '45293', '4b771', '626e6', 'e7903'],
#  '02088E': ['2e912', '48253', '99ba4', 'f3d21', 'f5e99'],
#  '20ef0B': ['712d2', '7301f'],
#  '20ef0C': ['15a0f', '30225', 'c3f2e'],
#  'acaecB': ['5485c', '6ace2'],
#  'acaecC': ['05b07', '1c2a8'],
#  'bd1f8B': ['202e8', '4f9dd', '5d597', 'c7939', 'd8dc3'],
#  'bd1f8C': ['52881', '725e9', 'c35e4', 'f65f7', 'fa523'],
#  '6c0f1B': ['09e60', '3c948', '48726', '6fd10', 'f61b2'],
#  'f10d5B': ['5cf3a', '7fd51', '8d841', 'a9fbb', 'f73ff'],
#  'a23d9B': ['44114', '6f08d', 'c2def', 'f0e0b', 'fbfa2'],
#  '697f1B': ['10cde', '7fd17', '86b6e', 'e1376', 'fccf2'],
#  'f0a5eB': ['3126f', 'e4d94', 'e6564', 'f73c1', 'ff084']}

# %% [markdown]
# ### Average, min, max number of (in-team) friends for each student

# %%
print(f'(manual assignment) avg number of friends {avg_friends(teams_manual)}')
print(f'(optimal assignment) avg number of friends {avg_friends(teams_optimal)}')
print(f'(manual assignment) min number of friends {min_friends(teams_manual)}')
print(f'(optimal assignment) min number of friends {min_friends(teams_optimal)}')
print(f'(manual assignment) max number of friends {max_friends(teams_manual)}')
print(f'(optimal assignment) max number of friends {max_friends(teams_optimal)}')
# Out:
# (manual assignment) avg number of friends 0.6309523809523809
# (optimal assignment) avg number of friends 0.6547619047619048
# (manual assignment) min number of friends 0
# (optimal assignment) min number of friends 0
# (manual assignment) max number of friends 3
# (optimal assignment) max number of friends 4

# %% [markdown]
# ### Average number of project preference for each student

# %%
print(f'(manual assignment) avg preference {avg_preference(teams_manual)}')
print(f'(optimal assignment) avg preference {avg_preference(teams_optimal)}')
print(f'(manual assignment) min preference {min_preference(teams_manual)}')
print(f'(optimal assignment) min preference {min_preference(teams_optimal)}')
print(f'(manual assignment) max preference {max_preference(teams_manual)}')
print(f'(optimal assignment) max preference {max_preference(teams_optimal)}')
# Out:
# (manual assignment) avg preference 4.035714285714286
# (optimal assignment) avg preference 3.0476190476190474
# (manual assignment) min preference 1
# (optimal assignment) min preference 1
# (manual assignment) max preference 49.00000000000001
# (optimal assignment) max preference 49.00000000000001

# %% [markdown]
# ### Distribution of number of (in team) friends

# %%
def friends_distribution(teams):
    dist = deque()
    for team in teams.values():
        for u in team:
            friends = sum([1 for v in team if u != v and (u, v) not in w and (v, u) not in w])
            dist.append(friends)
    return dist

# %%
bins = [0, 1, 2, 3, 4, 5]
optDist = friends_distribution(teams_optimal)
manualDist = friends_distribution(teams_manual)
plt.hist(manualDist, bins=bins)
plt.xlabel("# friends")
plt.ylabel("# students")
plt.title("Number of (in-team) friends (manual)")
plt.show()
plt.hist(optDist, bins=bins)
plt.xlabel("# friends")
plt.ylabel("# students")
plt.title("Number of (in-team) friends (optimal)")
plt.show()

# %% [markdown]
# ### Distribution of project preferences

# %%
def project_distribution(teams):
    dist = deque()
    for t in teams:
        team = teams[t]
        for u in team:
            dist.append(1 / c[(u, t)])
    return dist

# %%
bins = range(1, 11)
optDist = project_distribution(teams_optimal)
manualDist = project_distribution(teams_manual)
plt.hist(manualDist, bins=bins)
plt.xlabel("project preference")
plt.ylabel("# students")
plt.title("proejct preferences (manual)")
plt.show()
plt.hist(optDist, bins=bins)
plt.xlabel("project preference")
plt.ylabel("# students")
plt.title("project preferences (optimal)")
plt.show()

# %% [markdown]
# ### Per student analysis

# %%
def find_friends(student, teams):
    if student not in nodes:
        return "Not a valid student"
    friends = []
    for team in teams.values():
        for u in team:
            if u == student:
                friends = [v for v in team if u != v and (u, v) not in w and (v, u) not in w]
                return friends
    return []

def find_preference(student, teams):
    if student not in nodes:
        return "Not a valid student"
    for t in teams:
        team = teams[t]
        for u in team:
            if u == student:
                return 1 / c[(u, t)] 
    return -1

# %%
equal = 0
opt_better = 0
manual_better = 0
tradeOff = 0

for u in nodes:
    print(f"=== student: {u} ===")
    opt_pref = find_preference(u, teams_optimal)
    manual_pref = find_preference(u, teams_manual)
    opt_friends = find_friends(u, teams_optimal)
    manual_friends = find_friends(u, teams_manual)
    
    
    print(f"optimal: friends = {opt_friends}, preference = {opt_pref}")
    print(f"manual: friends = {manual_friends}, preference = {manual_pref}")
    
    if opt_pref == manual_pref and len(opt_friends) == len(manual_friends):
        print("equal")
        equal += 1
    elif opt_pref <= manual_pref and len(opt_friends) >= len(manual_friends):
        print("opt better")
        opt_better += 1
    elif opt_pref >= manual_pref and len(opt_friends) <= len(manual_friends):
        print("manual better")
        manual_better += 1
    else:
        print("trade-off")
        tradeOff += 1

        
print("=== Stats ===")
print(f'equal = {equal}')
print(f'opt better = {opt_better}')
print(f'manual better = {manual_better}')
print(f'trade-off = {tradeOff}')
# Out:
# === student: cba6a ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 2.0
# opt better
# === student: 69695 ===
# optimal: friends = [], preference = 1.0
# manual: friends = ['277e2', 'f61b2'], preference = 1.0
# manual better
# === student: f61b2 ===
# optimal: friends = [], preference = 1.0
# manual: friends = ['69695'], preference = 2.0
# trade-off
# === student: 277e2 ===
# optimal: friends = [], preference = 1.0
# manual: friends = ['69695'], preference = 2.0
# trade-off
# === student: 7e5b4 ===
# optimal: friends = ['28bbe', '808cb', 'd729a'], preference = 1.0
# manual: friends = [], preference = 2.0
# opt better
# === student: 808cb ===
# optimal: friends = ['28bbe', '7e5b4', 'd729a'], preference = 1.0
# manual: friends = ['28bbe', 'd729a'], preference = 4.0
# opt better
# === student: 47d11 ===
# optimal: friends = ['01653'], preference = 1.0
# manual: friends = ['01653'], preference = 1.0
# equal
# === student: 01653 ===
# optimal: friends = ['47d11'], preference = 1.0
# manual: friends = ['47d11'], preference = 1.0
# equal
# === student: e2a40 ===
# optimal: friends = ['4437f'], preference = 1.0
# manual: friends = ['4437f'], preference = 2.0
# opt better
# === student: 4437f ===
# optimal: friends = ['e2a40'], preference = 1.0
# manual: friends = ['e2a40'], preference = 2.0
# opt better
# === student: 3882e ===
# optimal: friends = [], preference = 1.0
# manual: friends = ['4b771'], preference = 1.0
# manual better
# === student: 4b771 ===
# optimal: friends = ['38b25'], preference = 1.0
# manual: friends = ['3882e', '38b25'], preference = 1.0
# manual better
# === student: a3004 ===
# optimal: friends = ['239b0'], preference = 1.0
# manual: friends = ['239b0'], preference = 4.0
# opt better
# === student: 239b0 ===
# optimal: friends = ['a3004'], preference = 1.0
# manual: friends = ['a3004'], preference = 4.0
# opt better
# === student: 0fa99 ===
# optimal: friends = ['79052', 'd225d'], preference = 1.0
# manual: friends = ['d225d'], preference = 2.0
# opt better
# === student: d225d ===
# optimal: friends = ['0fa99', '79052'], preference = 1.0
# manual: friends = ['0fa99'], preference = 2.0
# opt better
# === student: 79052 ===
# optimal: friends = ['0fa99', 'd225d'], preference = 1.0
# manual: friends = ['62de3'], preference = 1.0
# opt better
# === student: 62de3 ===
# optimal: friends = [], preference = 4.0
# manual: friends = ['79052'], preference = 1.0
# manual better
# === student: ff8ac ===
# optimal: friends = ['995a5'], preference = 1.0
# manual: friends = ['05b07', '995a5'], preference = 3.0
# trade-off
# === student: 05b07 ===
# optimal: friends = [], preference = 4.0
# manual: friends = ['ff8ac'], preference = 3.0
# manual better
# === student: 626e6 ===
# optimal: friends = ['e7903'], preference = 3.0
# manual: friends = [], preference = 3.0
# opt better
# === student: e7903 ===
# optimal: friends = ['45293', '626e6'], preference = 3.0
# manual: friends = ['45293'], preference = 3.0
# opt better
# === student: fffe2 ===
# optimal: friends = ['9e1a4'], preference = 1.0
# manual: friends = ['9e1a4'], preference = 1.0
# equal
# === student: 9e1a4 ===
# optimal: friends = ['fffe2'], preference = 1.0
# manual: friends = ['fffe2'], preference = 1.0
# equal
# === student: 05dc1 ===
# optimal: friends = ['ca78f'], preference = 1.0
# manual: friends = ['ca78f'], preference = 2.0
# opt better
# === student: ca78f ===
# optimal: friends = ['05dc1'], preference = 1.0
# manual: friends = ['05dc1'], preference = 2.0
# opt better
# === student: 99fdf ===
# optimal: friends = ['5c7bb'], preference = 2.0
# manual: friends = ['5c7bb'], preference = 2.0
# equal
# === student: 5c7bb ===
# optimal: friends = ['99fdf'], preference = 2.0
# manual: friends = ['99fdf'], preference = 2.0
# equal
# === student: 5d597 ===
# optimal: friends = ['202e8'], preference = 1.0
# manual: friends = ['202e8'], preference = 1.0
# equal
# === student: 202e8 ===
# optimal: friends = ['5d597'], preference = 1.0
# manual: friends = ['5d597'], preference = 1.0
# equal
# === student: 07ba3 ===
# optimal: friends = ['0ac0b'], preference = 1.0
# manual: friends = ['0ac0b'], preference = 2.0
# opt better
# === student: 0ac0b ===
# optimal: friends = ['07ba3'], preference = 1.0
# manual: friends = ['07ba3'], preference = 2.0
# opt better
# === student: 0d24a ===
# optimal: friends = ['d51a0'], preference = 1.0
# manual: friends = ['d51a0'], preference = 1.0
# equal
# === student: d51a0 ===
# optimal: friends = ['0d24a', '4b146'], preference = 1.0
# manual: friends = ['0d24a', '4b146'], preference = 1.0
# equal
# === student: d61b1 ===
# optimal: friends = ['c1783'], preference = 1.0
# manual: friends = ['c1783'], preference = 3.0
# opt better
# === student: c1783 ===
# optimal: friends = ['d61b1'], preference = 1.0
# manual: friends = ['d61b1'], preference = 3.0
# opt better
# === student: 7fd17 ===
# optimal: friends = ['86b6e'], preference = 1.0
# manual: friends = ['86b6e'], preference = 3.0
# opt better
# === student: 86b6e ===
# optimal: friends = ['10cde', '7fd17', 'fccf2'], preference = 1.0
# manual: friends = ['7fd17', '10cde', 'fccf2'], preference = 3.0
# opt better
# === student: 09ee0 ===
# optimal: friends = ['fbda7'], preference = 2.0
# manual: friends = ['fbda7'], preference = 3.0
# opt better
# === student: fbda7 ===
# optimal: friends = ['09ee0'], preference = 2.0
# manual: friends = ['09ee0'], preference = 3.0
# opt better
# === student: 99ba4 ===
# optimal: friends = [], preference = 3.0
# manual: friends = ['52881'], preference = 3.0
# manual better
# === student: 52881 ===
# optimal: friends = [], preference = 2.0
# manual: friends = ['99ba4'], preference = 3.0
# trade-off
# === student: fdb53 ===
# optimal: friends = ['08e18'], preference = 2.0
# manual: friends = ['08e18'], preference = 2.0
# equal
# === student: 08e18 ===
# optimal: friends = ['fdb53'], preference = 2.0
# manual: friends = ['fdb53'], preference = 2.0
# equal
# === student: 10cde ===
# optimal: friends = ['86b6e'], preference = 1.0
# manual: friends = ['86b6e'], preference = 3.0
# opt better
# === student: f0e0b ===
# optimal: friends = [], preference = 1.0
# manual: friends = ['285b3'], preference = 5.0
# trade-off
# === student: 285b3 ===
# optimal: friends = ['6be1f'], preference = 1.0
# manual: friends = ['f0e0b'], preference = 1.0
# equal
# === student: 45293 ===
# optimal: friends = ['e7903'], preference = 3.0
# manual: friends = ['e7903'], preference = 3.0
# equal
# === student: 15a0f ===
# optimal: friends = ['c3f2e'], preference = 1.0
# manual: friends = ['c3f2e'], preference = 1.0
# equal
# === student: c3f2e ===
# optimal: friends = ['15a0f'], preference = 1.0
# manual: friends = ['15a0f'], preference = 1.0
# equal
# === student: 38b25 ===
# optimal: friends = ['4b771'], preference = 2.0
# manual: friends = ['4b771'], preference = 3.0
# opt better
# === student: b31ec ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 1.0
# equal
# === student: 7e05a ===
# optimal: friends = [], preference = 2.0
# manual: friends = ['0e191'], preference = 4.0
# trade-off
# === student: 10718 ===
# optimal: friends = [], preference = 1.0
# manual: friends = ['6fd10'], preference = 2.0
# trade-off
# === student: 6fd10 ===
# optimal: friends = [], preference = 1.0
# manual: friends = ['10718'], preference = 1.0
# manual better
# === student: b6861 ===
# optimal: friends = ['6aff8', 'd8c36'], preference = 1.0
# manual: friends = ['d8c36', '6aff8'], preference = 4.0
# opt better
# === student: 6aff8 ===
# optimal: friends = ['b6861', 'd8c36'], preference = 1.0
# manual: friends = ['b6861', 'd8c36'], preference = 4.0
# opt better
# === student: d8c36 ===
# optimal: friends = ['6aff8', 'b6861'], preference = 1.0
# manual: friends = ['b6861', '6aff8'], preference = 4.0
# opt better
# === student: 4bb9b ===
# optimal: friends = ['a31f8'], preference = 1.0
# manual: friends = ['a31f8'], preference = 4.0
# opt better
# === student: a31f8 ===
# optimal: friends = ['4bb9b'], preference = 1.0
# manual: friends = ['4bb9b'], preference = 4.0
# opt better
# === student: 58c1e ===
# optimal: friends = ['48133'], preference = 1.0
# manual: friends = ['48133'], preference = 4.0
# opt better
# === student: 48133 ===
# optimal: friends = ['58c1e'], preference = 1.0
# manual: friends = ['58c1e'], preference = 4.0
# opt better
# === student: 02ed3 ===
# optimal: friends = ['3e725', '59b09'], preference = 1.0
# manual: friends = [], preference = 1.0
# opt better
# === student: 59b09 ===
# optimal: friends = ['02ed3', '3e725'], preference = 1.0
# manual: friends = ['3e725'], preference = 1.0
# opt better
# === student: 1c2a8 ===
# optimal: friends = [], preference = 2.0
# manual: friends = [], preference = 3.0
# opt better
# === student: 30225 ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 1.0
# equal
# === student: 2cdf6 ===
# optimal: friends = ['027b3', '2137a', '371ec', '49f94'], preference = 1.0
# manual: friends = ['371ec'], preference = 1.0
# opt better
# === student: 6be1f ===
# optimal: friends = ['285b3'], preference = 1.0
# manual: friends = [], preference = 1.0
# opt better
# === student: f73c1 ===
# optimal: friends = ['e4d94'], preference = 1.0
# manual: friends = [], preference = 2.0
# opt better
# === student: e4d94 ===
# optimal: friends = ['e6564', 'f73c1'], preference = 1.0
# manual: friends = ['e6564'], preference = 3.0
# opt better
# === student: e6564 ===
# optimal: friends = ['e4d94'], preference = 1.0
# manual: friends = ['e4d94'], preference = 3.0
# opt better
# === student: 88177 ===
# optimal: friends = ['38e2a'], preference = 1.0
# manual: friends = ['38e2a'], preference = 5.0
# opt better
# === student: 38e2a ===
# optimal: friends = ['88177'], preference = 1.0
# manual: friends = ['88177'], preference = 4.0
# opt better
# === student: 371ec ===
# optimal: friends = ['2cdf6'], preference = 1.0
# manual: friends = ['2cdf6'], preference = 1.0
# equal
# === student: 6ace2 ===
# optimal: friends = ['5485c'], preference = 2.0
# manual: friends = ['5485c'], preference = 2.0
# equal
# === student: 5485c ===
# optimal: friends = ['6ace2'], preference = 2.0
# manual: friends = ['6ace2'], preference = 2.0
# equal
# === student: cd65d ===
# optimal: friends = ['90c36', 'dbeb4'], preference = 1.0
# manual: friends = ['dbeb4', '90c36'], preference = 3.0
# opt better
# === student: dbeb4 ===
# optimal: friends = ['90c36', 'cd65d'], preference = 1.0
# manual: friends = ['cd65d', '90c36'], preference = 3.0
# opt better
# === student: 90c36 ===
# optimal: friends = ['cd65d', 'dbeb4'], preference = 1.0
# manual: friends = ['cd65d', 'dbeb4'], preference = 3.0
# opt better
# === student: fccf2 ===
# optimal: friends = ['86b6e'], preference = 1.0
# manual: friends = ['86b6e'], preference = 3.0
# opt better
# === student: c35e4 ===
# optimal: friends = ['fa523'], preference = 1.0
# manual: friends = ['fa523'], preference = 4.0
# opt better
# === student: fa523 ===
# optimal: friends = ['c35e4'], preference = 1.0
# manual: friends = ['c35e4'], preference = 4.0
# opt better
# === student: 4b146 ===
# optimal: friends = ['d51a0'], preference = 1.0
# manual: friends = ['d51a0'], preference = 1.0
# equal
# === student: 6024e ===
# optimal: friends = ['ec344'], preference = 2.0
# manual: friends = ['ec344'], preference = 4.0
# opt better
# === student: ec344 ===
# optimal: friends = ['6024e'], preference = 2.0
# manual: friends = ['6024e'], preference = 4.0
# opt better
# === student: 0e191 ===
# optimal: friends = [], preference = 2.0
# manual: friends = ['7e05a'], preference = 4.0
# trade-off
# === student: 0aa44 ===
# optimal: friends = ['dc9e1'], preference = 1.0
# manual: friends = ['dc9e1'], preference = 3.0
# opt better
# === student: dc9e1 ===
# optimal: friends = ['0aa44'], preference = 1.0
# manual: friends = ['0aa44'], preference = 3.0
# opt better
# === student: 3e725 ===
# optimal: friends = ['02ed3', '59b09'], preference = 1.0
# manual: friends = ['59b09'], preference = 1.0
# opt better
# === student: 28bbe ===
# optimal: friends = ['7e5b4', '808cb'], preference = 1.0
# manual: friends = ['808cb'], preference = 4.0
# opt better
# === student: 027b3 ===
# optimal: friends = ['2cdf6'], preference = 1.0
# manual: friends = [], preference = 4.0
# opt better
# === student: 36fd2 ===
# optimal: friends = ['0e9fb'], preference = 2.0
# manual: friends = ['0e9fb'], preference = 4.0
# opt better
# === student: 0e9fb ===
# optimal: friends = ['36fd2'], preference = 2.0
# manual: friends = ['36fd2'], preference = 4.0
# opt better
# === student: fbfa2 ===
# optimal: friends = ['44114'], preference = 1.0
# manual: friends = ['44114'], preference = 3.0
# opt better
# === student: 44114 ===
# optimal: friends = ['fbfa2'], preference = 1.0
# manual: friends = ['fbfa2'], preference = 3.0
# opt better
# === student: 2137a ===
# optimal: friends = ['2cdf6'], preference = 1.0
# manual: friends = ['ff084'], preference = 3.0
# opt better
# === student: 36bf2 ===
# optimal: friends = [], preference = 2.0
# manual: friends = ['da8fa'], preference = 1.0
# manual better
# === student: da8fa ===
# optimal: friends = [], preference = 3.0
# manual: friends = ['36bf2'], preference = 2.0
# manual better
# === student: 995a5 ===
# optimal: friends = ['ff8ac'], preference = 1.0
# manual: friends = ['ff8ac'], preference = 3.0
# opt better
# === student: 0fa51 ===
# optimal: friends = [], preference = 2.0
# manual: friends = [], preference = 2.0
# equal
# === student: d729a ===
# optimal: friends = ['7e5b4', '808cb'], preference = 1.0
# manual: friends = ['808cb'], preference = 4.0
# opt better
# === student: f3d21 ===
# optimal: friends = ['48253'], preference = 1.0
# manual: friends = ['48253'], preference = 1.0
# equal
# === student: 48253 ===
# optimal: friends = ['f3d21'], preference = 1.0
# manual: friends = ['f3d21'], preference = 1.0
# equal
# === student: ff084 ===
# optimal: friends = [], preference = 1.0
# manual: friends = ['2137a'], preference = 2.0
# trade-off
# === student: 49f94 ===
# optimal: friends = ['2cdf6'], preference = 1.0
# manual: friends = [], preference = 4.0
# opt better
# === student: aae49 ===
# optimal: friends = [], preference = 2.0
# manual: friends = [], preference = 4.0
# opt better
# === student: fc95d ===
# optimal: friends = [], preference = 49.00000000000001
# manual: friends = [], preference = 49.00000000000001
# equal
# === student: 3e878 ===
# optimal: friends = [], preference = 49.00000000000001
# manual: friends = [], preference = 49.00000000000001
# equal
# === student: 03dae ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 4.0
# opt better
# === student: a9fbb ===
# optimal: friends = [], preference = 2.0
# manual: friends = [], preference = 3.0
# opt better
# === student: f2d45 ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 1.0
# equal
# === student: 3b6af ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 2.0
# opt better
# === student: 4f9dd ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 4.0
# opt better
# === student: 09e60 ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 4.0
# opt better
# === student: 8b401 ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 1.0
# equal
# === student: 8d841 ===
# optimal: friends = [], preference = 2.0
# manual: friends = [], preference = 1.0
# manual better
# === student: d8dc3 ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 3.0
# opt better
# === student: c2def ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 2.0
# opt better
# === student: 725e9 ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 4.0
# opt better
# === student: 72cc1 ===
# optimal: friends = [], preference = 49.00000000000001
# manual: friends = [], preference = 49.00000000000001
# equal
# === student: ddcf1 ===
# optimal: friends = [], preference = 2.0
# manual: friends = [], preference = 2.0
# equal
# === student: 7301f ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 1.0
# equal
# === student: ae1b8 ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 3.0
# opt better
# === student: 4576d ===
# optimal: friends = [], preference = 3.0
# manual: friends = [], preference = 3.0
# equal
# === student: 48726 ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 3.0
# opt better
# === student: b5a51 ===
# optimal: friends = [], preference = 49.00000000000001
# manual: friends = [], preference = 49.00000000000001
# equal
# === student: 2684a ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 4.0
# opt better
# === student: 8cc4a ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 1.0
# equal
# === student: 100c3 ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 1.0
# equal
# === student: 98075 ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 3.0
# opt better
# === student: 34706 ===
# optimal: friends = [], preference = 3.0
# manual: friends = [], preference = 2.0
# manual better
# === student: 1003a ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 1.0
# equal
# === student: eaac3 ===
# optimal: friends = [], preference = 4.0
# manual: friends = [], preference = 4.0
# equal
# === student: 89b1b ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 3.0
# opt better
# === student: aefc9 ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 3.0
# opt better
# === student: a3a06 ===
# optimal: friends = [], preference = 3.0
# manual: friends = [], preference = 2.0
# manual better
# === student: 3f9ea ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 1.0
# equal
# === student: 27f54 ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 1.0
# equal
# === student: f0c14 ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 3.0
# opt better
# === student: f5e99 ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 1.0
# equal
# === student: 95506 ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 2.0
# opt better
# === student: dacea ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 1.0
# equal
# === student: 3126f ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 2.0
# opt better
# === student: 2c684 ===
# optimal: friends = [], preference = 49.00000000000001
# manual: friends = [], preference = 49.00000000000001
# equal
# === student: f65f7 ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 3.0
# opt better
# === student: 3c948 ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 1.0
# equal
# === student: e2f32 ===
# optimal: friends = [], preference = 3.0
# manual: friends = [], preference = 3.0
# equal
# === student: 0bb20 ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 2.0
# opt better
# === student: ad98a ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 1.0
# equal
# === student: f8117 ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 3.0
# opt better
# === student: cb944 ===
# optimal: friends = [], preference = 49.00000000000001
# manual: friends = [], preference = 49.00000000000001
# equal
# === student: e1376 ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 1.0
# equal
# === student: 7fd51 ===
# optimal: friends = [], preference = 2.0
# manual: friends = [], preference = 3.0
# opt better
# === student: c8292 ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 1.0
# equal
# === student: 2a591 ===
# optimal: friends = [], preference = 2.0
# manual: friends = [], preference = 3.0
# opt better
# === student: 5cf3a ===
# optimal: friends = [], preference = 2.0
# manual: friends = [], preference = 3.0
# opt better
# === student: 6f08d ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 1.0
# equal
# === student: ede24 ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 1.0
# equal
# === student: 6beb5 ===
# optimal: friends = [], preference = 4.0
# manual: friends = [], preference = 4.0
# equal
# === student: 4c684 ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 2.0
# opt better
# === student: 712d2 ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 2.0
# opt better
# === student: 174fe ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 1.0
# equal
# === student: c0f80 ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 1.0
# equal
# === student: aeb8e ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 1.0
# equal
# === student: f73ff ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 1.0
# equal
# === student: c7939 ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 2.0
# opt better
# === student: 2e912 ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 2.0
# opt better
# === student: 4f711 ===
# optimal: friends = [], preference = 1.0
# manual: friends = [], preference = 1.0
# equal
# === Stats ===
# equal = 57
# opt better = 90
# manual better = 12
# trade-off = 9

# %% [markdown]
# ### Friends graph colored based on team assignment

# %%
pos=nx.spring_layout(G_c, k=0.2, iterations=20)
def draw_graph_with_teams(teams, title):
#     colors = sns.color_palette("tab10", len(teams))
    colors = cm.rainbow(np.linspace(0, 1, len(teams)))

    colors_dict = dict(zip(sorted(teams.keys()), colors))

    color_map = []
    for node in G:
        for team in teams:
            if node in teams[team]:
                color_map.append(colors_dict[team])
                break
                
    nx.draw(G_c, node_color=color_map, pos=pos, with_labels=True)
    for node in G:
        if representatives[node]:
            x, y = pos[node]
            plt.text(x + 0.09, y + 0.01, '*', fontsize=12, color='black', ha='center', va='center')
            
    plt.title(title)
    legend_handles = [plt.Line2D([0], [0], marker='o', color='w', label=label, markersize=10, markerfacecolor=color, markeredgecolor=color) for color, label in zip(colors, colors_dict.keys())]
    plt.legend(handles=legend_handles)
    plt.show()

# %%
draw_graph_with_teams(teams_manual, "Friends graph and teams (manual assignemnt)")
draw_graph_with_teams(teams_optimal, "Friends graph and teams (optimal assignment)")

# %%
teams
# Out:
# {'b09c1A': ['0e191', '371ec', '49f94', '7e5b4', 'aefc9'],
#  '6c0f1A': ['09e60', '3c948', '4437f', '4f711', 'f61b2'],
#  'f10d5A': ['0d24a', '34706', '4b146', '8d841', 'f73ff'],
#  'f0a5eA': ['b6861', 'd8c36', 'e4d94', 'ff084'],
#  'a23d9A': ['0fa99', '6f08d', '79052', 'f0e0b', 'fbfa2'],
#  '4a15fA': ['01653', '59b09'],
#  'eb50dA': ['aae49', 'fbda7'],
#  'be328A': ['3e878'],
#  '7f7c0A': ['0fa51'],
#  '20ef0A': ['15a0f', '7301f'],
#  'acaecA': ['7e05a'],
#  'bd1f8A': ['3882e', 'c1783', 'c35e4', 'f65f7', 'fa523'],
#  '697f1A': ['0ac0b', '10cde', '86b6e', 'e1376', 'fccf2'],
#  '02088A': ['48253', '6024e', '626e6', 'dc9e1', 'fdb53'],
#  'b09c1B': ['95506', 'a31f8', 'cba6a', 'cd65d', 'd729a'],
#  'b09c1C': ['027b3', '4bb9b', '808cb', 'ae1b8', 'dbeb4'],
#  'b09c1D': ['05dc1', '2cdf6', '36bf2', '90c36', 'ad98a'],
#  'b09c1E': ['2137a', '28bbe', '89b1b', 'c0f80', 'ca78f'],
#  '4a15fB': ['02ed3', '47d11'],
#  '4a15fC': ['a3004', 'ddcf1'],
#  '4a15fD': ['1003a', '3e725'],
#  '4a15fE': ['239b0', '98075'],
#  'eb50dB': ['285b3', '8b401'],
#  'eb50dC': ['09ee0', '3b6af'],
#  'eb50dD': ['48133', 'b31ec'],
#  'eb50dE': ['58c1e', '6be1f'],
#  'be328B': ['72cc1'],
#  'be328C': ['b5a51'],
#  'be328D': [],
#  'be328E': ['2c684'],
#  '7f7c0B': ['62de3'],
#  '7f7c0C': ['fc95d'],
#  '7f7c0D': ['6beb5'],
#  '7f7c0E': ['f2d45'],
#  '02088B': ['36fd2', '38b25', '69695', '99ba4', 'a3a06'],
#  '02088C': ['45293', '4b771', '99fdf', 'aeb8e', 'f3d21'],
#  '02088D': ['08e18', '0aa44', '4c684', 'e7903', 'f5e99'],
#  '02088E': ['0e9fb', '100c3', '2e912', '5c7bb', 'ec344'],
#  '20ef0B': ['30225', 'c3f2e'],
#  '20ef0C': ['277e2', 'e2f32'],
#  'acaecB': ['6ace2', 'da8fa'],
#  'acaecC': ['1c2a8', '5485c'],
#  'bd1f8B': ['5d597', '725e9', '88177', 'd61b1', 'd8dc3'],
#  'bd1f8C': ['202e8', '38e2a', '4f9dd', '52881', 'c7939'],
#  '6c0f1B': ['48726', '6fd10', 'c8292', 'e2a40', 'f0c14'],
#  'f10d5B': ['2684a', '5cf3a', '7fd51', 'a9fbb', 'd51a0'],
#  'a23d9B': ['44114', '9e1a4', 'c2def', 'd225d', 'fffe2'],
#  '697f1B': ['07ba3', '0bb20', '10718', '7fd17', '8cc4a'],
#  'f0a5eB': ['3126f', '6aff8', 'f73c1', 'ff8ac']}
