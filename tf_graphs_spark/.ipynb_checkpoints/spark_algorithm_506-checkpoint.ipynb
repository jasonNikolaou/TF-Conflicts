# %%
import gurobipy as gp
from gurobipy import GRB
import networkx as nx
from networkx.algorithms import bipartite
import numpy as np
from collections import deque
from math import isclose
import random
import pickle
from time import time
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
import seaborn as sns

# %% [markdown]
# ## Problem definition
# The objective function is the following: \
# $$
# \max F(\mathbf{x}) =
#     \lambda \sum_{v \in V} \sum_{t=1}^k c_{vt} x_{vt}
#     + \sum_{(u, v) \in E} w_{uv} (1 - \sum_{t=1}^k x_{ut}x_{vt})
# $$
# Constraints:
# - $\sum_{t=1}^k y_t x_{ut} = 1$, for all $u \in V$
# - $y_t q_t \leq y_t \sum_{u \in V} x_{ut} \leq p_t$, for all $t \in [k]$
# - $ \sum_{u \in V} z_u y_t x_{ut} \geq y_t$, for all $t \in [k]$
# - $ \sum_{t} y_t \leq P$
# - $x_{ut} \in \{0, 1\}$
# - $y_{t} \in \{0, 1\}$

# %% [markdown]
# ## Input paramters

# %%
def run_experiments(input_file, lambda_mul):
    lambda_ = lambda_mul * sum(w.values()) / n
    
    nx.draw(G_c, pos=nx.spring_layout(G_c, k=0.2, iterations=20), with_labels=True)
    plt.title(f'Friends graph')
    plt.show()

    print(f'number of students: {n}')
    print(f'number of conflict edges: {len(edges)}')
    print(f'number of friend edges: {len(G_c.edges)}')
    print(f'number of projects: {numOfProjects}')
    
    # Create a new model
    m = gp.Model("quadratic")
    m.Params.timeLimit = 120
    m.Params.NonConvex = 2

    # Create variables
    X = dict()
    Y = dict()
    Z = dict()
    for u in nodes:
        for p in projects:
            X[(u, p)] = m.addVar(vtype=GRB.BINARY, name=f"X({u},{p})")

    for p in projects:
        Y[p] = m.addVar(vtype=GRB.BINARY, name=f"Y_{p})")

    for u in nodes:
        Z[u] = m.addVar(vtype=GRB.BINARY, name=f"Z_{u})")


    # Linear (project preference) term
    F1 = gp.LinExpr()
    for u in nodes:
        for p in projects:
            if (u, p) in c:
                F1 += c[(u, p)] * X[(u, p)]
    F1 *= lambda_

    # max-cut term
    F3 = dict()
    F2 = gp.QuadExpr()
    for e in edges:
        u = e[0]; v = e[1]
        F3[e] = gp.QuadExpr()
        for p in projects:
            F3[e] -=  X[(u, p)] * X[(v, p)]
        F3[e] += 1
        F3[e] *= w[(u, v)]
    for e in edges:
        F2 += F3[e]

    F = gp.QuadExpr()
    F = F1 + F2
    m.setObjective(F, GRB.MAXIMIZE)

    # Add constraints

    # Each student assigned to exactly one project
    for u in nodes:
        expr = gp.QuadExpr()
        expr = sum([Y[p] * X[(u, p)] for p in projects])
        m.addConstr(expr == 1)

    # Project capacity constraints
    for p in projects:
        expr = gp.QuadExpr()
        expr = Y[p] * sum(X[(u, p)] for u in nodes)
        m.addConstr(expr <= capacities[p])
        m.addConstr(expr >= min_capacities[p] * Y[p])
        expr = sum(X[(u, p)] for u in nodes)
        m.addConstr(expr <= capacities[p])


    # Number of "active" projects
    expr = gp.LinExpr()
    expr = sum([Y[p] for p in projects])
    m.addConstr(expr <= P)

    # Each "active" project should have a representative
    expr = gp.QuadExpr()
    for p in projects:
        expr = sum([representatives[u] * Y[p] * X[(u, p)] for u in nodes])
        m.addConstr(expr >= Y[p])
    
    start = time()
    # Optimize model
    m.optimize()

    # Convert solution to dictionary format
    x = dict()
    for u in nodes:
        for p in projects:
            x[(u, p)] = X[(u, p)].X

    print(f'Obj quadratic: {m.ObjVal}')
    return x

# %% [markdown]
# ### Save results

# %%
# results = dict()
# results["quad_sol"] = x_opt
# results["quad_val"] = m.ObjVal

# settings = dict()
# settings["nodes"] = nodes
# settings["edges"] = edges
# settings["w"] = w
# settings["c"] = c
# settings["capacities"] = capacities
# settings["projects"] = projects
# settings["lambda_mul"] = lambda_mul
# settings["lambda_"] = lambda_

# %% [markdown]
# ## Analysis

# %%
def construct_teams(x):
    teams = dict()
    for p in projects:
        teams[p] = []

    for e in x:
        u, p = e
        if x[e] == 1:
            u, p = e
            teams[p].append(u)
            
    for p in projects:
        teams[p].sort()
        
    return teams
    
def min_friends(teams):
    minFriends = n
    for team in teams.values():
        for u in team:
            friends = sum([1 for v in team if u != v and (u, v) not in w and (v, u) not in w])
            minFriends = min(friends, minFriends)
    return minFriends
            
def max_friends(teams):
    maxFriends = 0
    for team in teams.values():
        for u in team:
            friends = sum([1 for v in team if u != v and (u, v) not in w and (v, u) not in w])
            maxFriends = max(friends, maxFriends)
    return maxFriends

def avg_friends(teams):
    friends = 0
    for team in teams.values():
        friends += sum([1 for u in team for v in team if u != v and (u, v) not in w and (v, u) not in w])
    return friends / n

def reverse_pref(pref):
    return numOfUniqueProjects -  pref + 1

def min_preference(teams):
    ans = 1
    for t in teams:
        team = teams[t]
        for u in team:
            ans = min(ans, reverse_pref(c[(u, t)]))      
    return ans
            
def max_preference(teams):
    ans = -1
    for t in teams:
        team = teams[t]
        for u in team:
            ans = max(ans, reverse_pref(c[(u, t)]))      
    return ans

def avg_preference(teams):
    pref = 0
    for t in teams:
        team = teams[t]
        pref += sum([reverse_pref(c[(u, t)]) for u in team])
    return pref / n

def friends_distribution(teams):
    dist = deque()
    for team in teams.values():
        for u in team:
            friends = sum([1 for v in team if u != v and (u, v) not in w and (v, u) not in w])
            dist.append(friends)
    return dist

def find_friends(student, teams):
    if student not in nodes:
        return "Not a valid student"
    friends = []
    for team in teams.values():
        for u in team:
            if u == student:
                friends = [v for v in team if u != v and (u, v) not in w and (v, u) not in w]
                return friends
    return []

def find_preference(student, teams):
    if student not in nodes:
        return "Not a valid student"
    for t in teams:
        team = teams[t]
        for u in team:
            if u == student:
                return reverse_pref(c[(u, t)])
    return -1

def project_distribution(teams):
    dist = deque()
    for t in teams:
        team = teams[t]
        for u in team:
            dist.append(reverse_pref(c[(u, t)]))
    return dist

def group_keys_by_value(input_dict):
    grouped_dict = {}
    
    for key, value in input_dict.items():
        if value in grouped_dict:
            grouped_dict[value].append(key)
        else:
            grouped_dict[value] = [key]
    
    return grouped_dict

def draw_graph_with_teams(teams, pos, title):
#     colors = sns.color_palette("tab10", len(teams))
    colors = cm.rainbow(np.linspace(0, 1, len(teams)))
    colors_dict = dict(zip(sorted(teams.keys()), colors))

    color_map = []
    for node in G:
        for team in teams:
            if node in teams[team]:
                color_map.append(colors_dict[team])
                break
                
    nx.draw(G_c, node_color=color_map, pos=pos, with_labels=True)
#     for node in G:
#         if representatives[node]:
#             x, y = pos[node]
#             plt.text(x + 0.09, y + 0.01, '*', fontsize=12, color='black', ha='center', va='center')
    plt.title(title)
    legend_handles = [plt.Line2D([0], [0], marker='o', color='w', label=label, markersize=10, markerfacecolor=color, markeredgecolor=color) for color, label in zip(colors, colors_dict.keys())]
#     plt.legend(handles=legend_handles)
    plt.show()

# %%
def analysis(x):
    # ==== Construct the team =====
    teams = construct_teams(x)
    print("Teams: ")
    print(teams)
    
    # ==== Solution statistics ====
    print(f'(optimal assignment) avg number of friends {avg_friends(teams)}')
    print(f'(optimal assignment) min number of friends {min_friends(teams)}')
    print(f'(optimal assignment) max number of friends {max_friends(teams)}')

    print(f'(optimal assignment) avg preference {avg_preference(teams)}')
    print(f'(optimal assignment) min preference {min_preference(teams)}')
    print(f'(optimal assignment) max preference {max_preference(teams)}')

    # ==== Per student analysis ====
    for u in nodes:
        print(f"--- student {u} ---")
        opt_pref = find_preference(u, teams)
        opt_friends = find_friends(u, teams)
        print(f"friends = {opt_friends}, preference = {opt_pref}")

    # ===== Draw graph =====
    pos=nx.spring_layout(G_c, k=0.2, iterations=20)
    draw_graph_with_teams(teams, pos, 'Friends and team assignment')

    teams_manual = group_keys_by_value(assignment)

    # ==== Project preference Distribution ====
    bins = range(1, 14)
    optDist = project_distribution(teams)
    manualDist = project_distribution(teams_manual)
    plt.hist(manualDist, bins=bins)
    plt.xlabel("project preference")
    plt.ylabel("# students")
    plt.title("project preferences (manual)")
    plt.show()
    plt.hist(optDist, bins=bins)
    plt.xlabel("project preference")
    plt.ylabel("# students")
    plt.title("project preferences (optimal)")
    plt.show()

    # ==== Per student comparison ====
    equal = 0
    opt_better = 0
    manual_better = 0
    tradeOff = 0

    for u in nodes:
    #     print(f"=== student: {u} ===")
        opt_pref = find_preference(u, teams)
        manual_pref = find_preference(u, teams_manual)
        opt_friends = find_friends(u, teams)
        manual_friends = find_friends(u, teams_manual)


    #     print(f"optimal: friends = {opt_friends}, preference = {opt_pref}")
    #     print(f"manual: friends = {manual_friends}, preference = {manual_pref}")

        if opt_pref == manual_pref and len(opt_friends) == len(manual_friends):
    #         print("equal")
            equal += 1
        elif opt_pref <= manual_pref and len(opt_friends) >= len(manual_friends):
    #         print("opt better")
            opt_better += 1
        elif opt_pref >= manual_pref and len(opt_friends) <= len(manual_friends):
    #         print("manual better")
            manual_better += 1
        else:
    #         print("trade-off")
            tradeOff += 1


    print("=== Stats ===")
    print(f'equal = {equal}')
    print(f'opt better = {opt_better}')
    print(f'manual better = {manual_better}')
    print(f'trade-off = {tradeOff}')

# %%
input_file = './bu_spark_2022/csDS506_Lin.pickle'
lambda_mul = 5
numOfUniqueProjects = 14 # num of unique projects

# Read graph
with open(input_file, 'rb') as file:
    projects = pickle.load(file)
    capacities = pickle.load(file)
    numOfProjects = len(capacities)
    c = pickle.load(file)
    w = pickle.load(file)
    edges = pickle.load(file)
    assignment = pickle.load(file)
    representatives = pickle.load(file)
    n = len(assignment)
    G = nx.Graph()
    G.add_edges_from(edges)
    G_c = nx.complement(G) # friends graph
    nodes = list(G.nodes)
    n = len(nodes)
    P = 100 # max number of "active" projects
    min_capacities = dict()
    for p in projects:
        min_capacities[p] = 4
    
x = run_experiments(input_file, lambda_mul)
analysis(x)
# Out:
# number of students: 168
# number of conflict edges: 13952
# number of friend edges: 76
# number of projects: 49
# Set parameter TimeLimit to value 120
# Set parameter NonConvex to value 2
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) Gold 6132 CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 28 physical cores, 28 logical processors, using up to 28 threads
#
# Optimize a model with 50 rows, 8449 columns and 8281 nonzeros
# Model fingerprint: 0x9e43bdee
# Model has 683648 quadratic objective terms
# Model has 315 quadratic constraints
# Variable types: 0 continuous, 8449 integer (8449 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 4e+00]
#   Objective range  [4e+02, 6e+03]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+00, 1e+02]
#   QRHS range       [1e+00, 5e+00]
# Presolve added 97 rows and 0 columns
# Presolve removed 0 rows and 119 columns
# Presolve time: 1.17s
# Presolved: 708659 rows, 700210 columns, 2130079 nonzeros
# Variable types: 0 continuous, 700210 integer (700161 binary)
# Found heuristic solution: objective 942842.85714
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Ordering time: 0.50s
#
# Barrier statistics:
#  Dense cols : 2058
#  AA' NZ     : 7.820e+05
#  Factor NZ  : 3.988e+06 (roughly 160 MB of memory)
#  Factor Ops : 3.292e+09 (less than 1 second per iteration)
#  Threads    : 26
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.27434215e+09  4.17134872e+09  1.10e+03 3.63e+03  1.43e+06    12s
#    1   1.12984095e+09  3.65816094e+09  1.01e+03 1.87e+04  1.20e+06    12s
#    2   5.92776581e+08  6.84305693e+09  5.42e+02 5.46e-07  6.17e+05    12s
#    3   1.24429667e+08  6.65488133e+09  1.14e+02 3.47e-07  1.36e+05    12s
#    4   9.29988157e+06  5.52002588e+09  9.15e+00 2.84e-07  2.00e+04    12s
#    5   2.69356363e+06  2.43530007e+09  2.90e+00 1.60e-07  6.44e+03    12s
#    6   1.54635071e+06  1.04807097e+09  1.56e+00 1.64e-07  2.54e+03    13s
#    7   9.47577964e+05  9.68581085e+08  8.96e-01 1.50e-07  2.21e+03    13s
#    8   7.35492069e+05  6.48599275e+08  6.65e-01 9.94e-08  1.46e+03    13s
#    9   4.68749165e+05  5.01579032e+08  2.96e-01 7.55e-08  1.09e+03    13s
#   10   3.59201402e+05  1.72275179e+08  4.32e-02 2.31e-08  3.63e+02    13s
#   11   4.71971531e+05  5.16320451e+07  4.34e-03 6.37e-09  1.08e+02    13s
#   12   5.94659595e+05  4.72751111e+07  2.25e-03 5.81e-09  9.82e+01    13s
#   13   7.31957664e+05  3.20118987e+07  1.32e-03 3.87e-09  6.58e+01    13s
#   14   8.29301466e+05  1.91901113e+07  8.70e-04 2.22e-09  3.86e+01    13s
#   15   9.14740061e+05  1.14830926e+07  4.99e-04 1.22e-09  2.22e+01    14s
#   16   1.00525381e+06  3.35968896e+06  1.91e-04 7.22e-10  4.95e+00    14s
#   17   1.08473539e+06  2.22549033e+06  1.00e-04 6.64e-10  2.40e+00    14s
#   18   1.28525541e+06  1.63738427e+06  1.20e-05 7.36e-10  7.40e-01    14s
#   19   1.36061993e+06  1.39091715e+06  4.52e-07 1.31e-09  6.37e-02    14s
#   20   1.36493276e+06  1.37778641e+06  1.91e-07 9.88e-08  2.70e-02    14s
#   21   1.36628122e+06  1.37319505e+06  1.10e-07 4.19e-08  1.45e-02    14s
#   22   1.36727107e+06  1.37240399e+06  5.75e-08 4.14e-08  1.08e-02    15s
#   23   1.36819985e+06  1.36904993e+06  7.35e-09 8.82e-09  1.79e-03    15s
#   24   1.36834653e+06  1.36836127e+06  4.89e-10 5.82e-09  3.10e-05    15s
#   25   1.36834916e+06  1.36834918e+06  1.41e-10 1.16e-10  3.10e-08    15s
#   26   1.36834916e+06  1.36834918e+06  1.41e-10 7.53e-06  3.10e-08    15s
#   27   1.36834916e+06  1.36834918e+06  3.36e-09 5.72e-06  3.37e-08    15s
#   28   1.36834916e+06  1.36834918e+06  3.36e-09 1.42e-05  3.37e-08    15s
#
# Barrier solved model in 28 iterations and 15.48 seconds (8.89 work units)
# Optimal objective 1.36834916e+06
#
#
# Root crossover log...
#
#     2698 DPushes remaining with DInf 0.0000000e+00                16s
#        0 DPushes remaining with DInf 0.0000000e+00                16s
#
#      117 PPushes remaining with PInf 0.0000000e+00                16s
#        0 PPushes remaining with PInf 0.0000000e+00                16s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 3.9563020e-11     16s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1391    1.3683492e+06   0.000000e+00   0.000000e+00     16s
# Concurrent spin time: 0.12s
#
# Solved with barrier
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                16s
#
#      895 PPushes remaining with PInf 0.0000000e+00                16s
#        0 PPushes remaining with PInf 0.0000000e+00                17s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.1197143e-10     17s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2289    1.3683492e+06   0.000000e+00   0.000000e+00     17s
#
# Root relaxation: objective 1.368349e+06, 2289 iterations, 8.44 seconds (5.42 work units)
# Total elapsed time = 16.86s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1368349.17    0 1412 942842.857 1368349.17  45.1%     -   22s
# H    0     0                    943268.09524 1368349.17  45.1%     -   23s
#      0     0 1366833.56    0 1335 943268.095 1366833.56  44.9%     -   41s
# H    0     0                    1052056.4762 1366833.56  29.9%     -   46s
#      0     0 1366753.78    0 1642 1052056.48 1366753.78  29.9%     -   57s
#      0     0 1366729.43    0 1775 1052056.48 1366729.43  29.9%     -   66s
#      0     0 1366725.15    0 1748 1052056.48 1366725.15  29.9%     -   70s
#      0     0 1366672.54    0 1902 1052056.48 1366672.54  29.9%     -   82s
# H    0     0                    1052057.4762 1366672.54  29.9%     -   84s
#      0     0 1366663.11    0 1781 1052057.48 1366663.11  29.9%     -   89s
#      0     0 1366653.12    0 1789 1052057.48 1366653.12  29.9%     -  102s
# H    0     0                    1305750.9524 1366653.12  4.66%     -  115s
# H    0     0                    1305754.9524 1366653.12  4.66%     -  120s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 46
#   Zero half: 114
#   RLT: 1021
#   BQP: 975
#
# Explored 1 nodes (66771 simplex iterations) in 120.14 seconds (111.77 work units)
# Thread count was 28 (of 28 available processors)
#
# Solution count 6: 1.30575e+06 1.30575e+06 1.05206e+06 ... 942843
#
# Time limit reached
# Best objective 1.305754952381e+06, best bound 1.366653124784e+06, gap 4.6638%
# Obj quadratic: 1305754.9523809524
# Teams:
# {'b09c1A': ['07ba3', '0e191', '371ec', '49f94', 'd729a'], '6c0f1A': ['09e60', '3c948', '4437f', 'c8292', 'e2a40'], 'f10d5A': ['34706', '5485c', '6ace2', '89b1b', 'c0f80'], 'f0a5eA': ['6aff8', 'd8c36', 'e4d94', 'e6564', 'f73c1'], 'a23d9A': ['0fa99', '626e6', '62de3', '79052', 'd225d'], '4a15fA': ['01653', '47d11', '98075', 'a3004', 'f73ff'], 'eb50dA': ['4576d', '8b401', 'aae49', 'b31ec', 'dacea'], 'be328A': ['09ee0', '239b0', 'd51a0', 'ede24', 'fc95d'], '7f7c0A': ['0fa51', '277e2', '27f54', 'eaac3', 'f2d45'], '20ef0A': ['15a0f', '174fe', '30225', '712d2', 'c3f2e'], 'acaecA': ['03dae', '1c2a8', '7e05a', 'c7939', 'da8fa'], 'bd1f8A': ['44114', '52881', '99ba4', 'fa523', 'fbfa2'], '697f1A': ['0ac0b', '0bb20', '10718', '8cc4a', 'e1376'], '02088A': ['0e9fb', '4c684', '5c7bb', '99fdf', 'f5e99'], 'b09c1B': ['05dc1', '7e5b4', '808cb', '90c36', 'ca78f'], 'b09c1C': ['027b3', '2137a', '28bbe', '95506', 'ff084'], 'b09c1D': ['4bb9b', 'a31f8', 'ad98a', 'cd65d', 'dbeb4'], 'b09c1E': ['2cdf6', '36bf2', 'ae1b8', 'aefc9', 'cba6a'], '4a15fB': ['01653', '02ed3', '3e725', '47d11', '59b09'], '4a15fC': ['02ed3', '239b0', '3e725', '59b09', 'a3004'], '4a15fD': ['01653', '02ed3', '3e725', '47d11', '59b09'], '4a15fE': ['02ed3', '1003a', '3e725', '59b09', 'ddcf1'], 'eb50dB': ['3b6af', '48253', 'dc9e1', 'f3d21'], 'eb50dC': ['285b3', '48133', '58c1e', '6be1f', '8b401'], 'eb50dD': ['285b3', '48133', '58c1e', '6be1f', 'f8117'], 'eb50dE': ['285b3', '3b6af', '48133', '58c1e', '6be1f'], 'be328B': ['09ee0', 'c1783', 'd61b1', 'ede24', 'fbda7'], 'be328C': ['09ee0', 'c1783', 'd61b1', 'ede24', 'fbda7'], 'be328D': ['2c684', '3e878', '72cc1', 'b5a51', 'fbda7'], 'be328E': ['2a591', '30225', 'c1783', 'cb944', 'd61b1'], '7f7c0B': ['27f54', '3b6af', '3f9ea', '712d2', 'f2d45'], '7f7c0C': ['27f54', '3b6af', '3f9ea', '712d2', 'f2d45'], '7f7c0D': ['27f54', '3b6af', '3f9ea', '712d2', 'f2d45'], '7f7c0E': ['27f54', '3b6af', '3f9ea', '712d2', 'f2d45'], '02088B': ['38b25', '4b771', '6024e', 'a3a06', 'ec344'], '02088C': ['08e18', '2e912', '36fd2', '7301f', 'fdb53'], '02088D': ['0d24a', '100c3', '45293', '4b146', 'e7903'], '02088E': ['3f9ea', '69695', 'aeb8e', 'f61b2'], '20ef0B': ['15a0f', '277e2', '712d2', '7301f', 'c3f2e'], '20ef0C': ['15a0f', '174fe', '712d2', 'c3f2e', 'e2f32'], 'acaecB': ['03dae', '1c2a8', '5485c', '69695', '6ace2'], 'acaecC': ['03dae', '5485c', '69695', '6ace2', '7e05a'], 'bd1f8B': ['4f9dd', '725e9', 'c35e4', 'd8dc3', 'f65f7'], 'bd1f8C': ['202e8', '3882e', '38e2a', '5d597', '88177'], '6c0f1B': ['48726', '4f711', '6beb5', '6fd10', 'f0c14'], 'f10d5B': ['2684a', '5cf3a', '7fd51', '8d841', 'a9fbb'], 'a23d9B': ['6f08d', '9e1a4', 'c2def', 'f0e0b', 'fffe2'], '697f1B': ['0aa44', '10cde', '7fd17', '86b6e', 'fccf2'], 'f0a5eB': ['05b07', '3126f', '995a5', 'b6861', 'ff8ac']}
# (optimal assignment) avg number of friends 0.7619047619047619
# (optimal assignment) min number of friends 0
# (optimal assignment) max number of friends 3
# (optimal assignment) avg preference 3.1726190476190474
# (optimal assignment) min preference 1
# (optimal assignment) max preference 14
# --- student cba6a ---
# friends = [], preference = 1
# --- student 69695 ---
# friends = ['f61b2'], preference = 1
# --- student f61b2 ---
# friends = ['69695'], preference = 2
# --- student 277e2 ---
# friends = [], preference = 6
# --- student 7e5b4 ---
# friends = ['808cb'], preference = 1
# --- student 808cb ---
# friends = ['7e5b4'], preference = 1
# --- student 47d11 ---
# friends = ['01653'], preference = 1
# --- student 01653 ---
# friends = ['47d11'], preference = 1
# --- student e2a40 ---
# friends = ['4437f'], preference = 1
# --- student 4437f ---
# friends = ['e2a40'], preference = 1
# --- student 3882e ---
# friends = [], preference = 1
# --- student 4b771 ---
# friends = ['38b25'], preference = 1
# --- student a3004 ---
# friends = [], preference = 1
# --- student 239b0 ---
# friends = [], preference = 11
# --- student 0fa99 ---
# friends = ['62de3', '79052', 'd225d'], preference = 1
# --- student d225d ---
# friends = ['0fa99', '79052'], preference = 1
# --- student 79052 ---
# friends = ['0fa99', '62de3', 'd225d'], preference = 1
# --- student 62de3 ---
# friends = ['0fa99', '79052'], preference = 1
# --- student ff8ac ---
# friends = ['05b07', '995a5'], preference = 1
# --- student 05b07 ---
# friends = ['ff8ac'], preference = 1
# --- student 626e6 ---
# friends = [], preference = 1
# --- student e7903 ---
# friends = ['45293'], preference = 3
# --- student fffe2 ---
# friends = ['9e1a4'], preference = 1
# --- student 9e1a4 ---
# friends = ['fffe2'], preference = 1
# --- student 05dc1 ---
# friends = ['ca78f'], preference = 1
# --- student ca78f ---
# friends = ['05dc1'], preference = 1
# --- student 99fdf ---
# friends = ['5c7bb'], preference = 2
# --- student 5c7bb ---
# friends = ['99fdf'], preference = 2
# --- student 5d597 ---
# friends = ['202e8'], preference = 1
# --- student 202e8 ---
# friends = ['5d597'], preference = 1
# --- student 07ba3 ---
# friends = [], preference = 13
# --- student 0ac0b ---
# friends = [], preference = 1
# --- student 0d24a ---
# friends = [], preference = 13
# --- student d51a0 ---
# friends = [], preference = 11
# --- student d61b1 ---
# friends = ['c1783'], preference = 3
# --- student c1783 ---
# friends = ['d61b1'], preference = 3
# --- student 7fd17 ---
# friends = ['86b6e'], preference = 1
# --- student 86b6e ---
# friends = ['10cde', '7fd17', 'fccf2'], preference = 1
# --- student 09ee0 ---
# friends = [], preference = 3
# --- student fbda7 ---
# friends = ['09ee0'], preference = 3
# --- student 99ba4 ---
# friends = ['52881'], preference = 2
# --- student 52881 ---
# friends = ['99ba4'], preference = 2
# --- student fdb53 ---
# friends = ['08e18'], preference = 2
# --- student 08e18 ---
# friends = ['fdb53'], preference = 2
# --- student 10cde ---
# friends = ['86b6e'], preference = 1
# --- student f0e0b ---
# friends = [], preference = 1
# --- student 285b3 ---
# friends = ['6be1f'], preference = 1
# --- student 45293 ---
# friends = ['e7903'], preference = 3
# --- student 15a0f ---
# friends = ['c3f2e'], preference = 1
# --- student c3f2e ---
# friends = ['15a0f'], preference = 1
# --- student 38b25 ---
# friends = ['4b771'], preference = 2
# --- student b31ec ---
# friends = [], preference = 1
# --- student 7e05a ---
# friends = [], preference = 2
# --- student 10718 ---
# friends = [], preference = 1
# --- student 6fd10 ---
# friends = [], preference = 1
# --- student b6861 ---
# friends = [], preference = 1
# --- student 6aff8 ---
# friends = ['d8c36'], preference = 1
# --- student d8c36 ---
# friends = ['6aff8'], preference = 1
# --- student 4bb9b ---
# friends = ['a31f8'], preference = 1
# --- student a31f8 ---
# friends = ['4bb9b'], preference = 1
# --- student 58c1e ---
# friends = ['48133'], preference = 1
# --- student 48133 ---
# friends = ['58c1e'], preference = 1
# --- student 02ed3 ---
# friends = ['3e725', '59b09'], preference = 1
# --- student 59b09 ---
# friends = ['02ed3', '3e725'], preference = 1
# --- student 1c2a8 ---
# friends = [], preference = 2
# --- student 30225 ---
# friends = [], preference = 1
# --- student 2cdf6 ---
# friends = [], preference = 1
# --- student 6be1f ---
# friends = ['285b3'], preference = 1
# --- student f73c1 ---
# friends = ['e4d94'], preference = 1
# --- student e4d94 ---
# friends = ['e6564', 'f73c1'], preference = 1
# --- student e6564 ---
# friends = ['e4d94'], preference = 1
# --- student 88177 ---
# friends = ['38e2a'], preference = 1
# --- student 38e2a ---
# friends = ['88177'], preference = 1
# --- student 371ec ---
# friends = [], preference = 1
# --- student 6ace2 ---
# friends = ['5485c'], preference = 12
# --- student 5485c ---
# friends = ['6ace2'], preference = 14
# --- student cd65d ---
# friends = ['dbeb4'], preference = 1
# --- student dbeb4 ---
# friends = ['cd65d'], preference = 1
# --- student 90c36 ---
# friends = [], preference = 1
# --- student fccf2 ---
# friends = ['86b6e'], preference = 1
# --- student c35e4 ---
# friends = [], preference = 1
# --- student fa523 ---
# friends = [], preference = 1
# --- student 4b146 ---
# friends = [], preference = 13
# --- student 6024e ---
# friends = ['ec344'], preference = 2
# --- student ec344 ---
# friends = ['6024e'], preference = 2
# --- student 0e191 ---
# friends = [], preference = 2
# --- student 0aa44 ---
# friends = [], preference = 4
# --- student dc9e1 ---
# friends = [], preference = 9
# --- student 3e725 ---
# friends = ['02ed3', '59b09'], preference = 1
# --- student 28bbe ---
# friends = [], preference = 1
# --- student 027b3 ---
# friends = [], preference = 1
# --- student 36fd2 ---
# friends = [], preference = 2
# --- student 0e9fb ---
# friends = [], preference = 2
# --- student fbfa2 ---
# friends = ['44114'], preference = 2
# --- student 44114 ---
# friends = ['fbfa2'], preference = 2
# --- student 2137a ---
# friends = ['ff084'], preference = 1
# --- student 36bf2 ---
# friends = [], preference = 2
# --- student da8fa ---
# friends = [], preference = 3
# --- student 995a5 ---
# friends = ['ff8ac'], preference = 1
# --- student 0fa51 ---
# friends = [], preference = 2
# --- student d729a ---
# friends = [], preference = 1
# --- student f3d21 ---
# friends = ['48253'], preference = 4
# --- student 48253 ---
# friends = ['f3d21'], preference = 4
# --- student ff084 ---
# friends = ['2137a'], preference = 3
# --- student 49f94 ---
# friends = [], preference = 1
# --- student aae49 ---
# friends = [], preference = 2
# --- student fc95d ---
# friends = [], preference = 14
# --- student 3e878 ---
# friends = [], preference = 14
# --- student 03dae ---
# friends = [], preference = 1
# --- student a9fbb ---
# friends = [], preference = 2
# --- student f2d45 ---
# friends = [], preference = 1
# --- student 3b6af ---
# friends = [], preference = 1
# --- student 4f9dd ---
# friends = [], preference = 1
# --- student 09e60 ---
# friends = [], preference = 1
# --- student 8b401 ---
# friends = [], preference = 1
# --- student 8d841 ---
# friends = [], preference = 2
# --- student d8dc3 ---
# friends = [], preference = 1
# --- student c2def ---
# friends = [], preference = 1
# --- student 725e9 ---
# friends = [], preference = 1
# --- student 72cc1 ---
# friends = [], preference = 14
# --- student ddcf1 ---
# friends = [], preference = 2
# --- student 7301f ---
# friends = [], preference = 2
# --- student ae1b8 ---
# friends = [], preference = 1
# --- student 4576d ---
# friends = [], preference = 3
# --- student 48726 ---
# friends = [], preference = 1
# --- student b5a51 ---
# friends = [], preference = 14
# --- student 2684a ---
# friends = [], preference = 1
# --- student 8cc4a ---
# friends = [], preference = 1
# --- student 100c3 ---
# friends = [], preference = 1
# --- student 98075 ---
# friends = [], preference = 1
# --- student 34706 ---
# friends = [], preference = 3
# --- student 1003a ---
# friends = [], preference = 1
# --- student eaac3 ---
# friends = [], preference = 4
# --- student 89b1b ---
# friends = [], preference = 4
# --- student aefc9 ---
# friends = [], preference = 1
# --- student a3a06 ---
# friends = [], preference = 3
# --- student 3f9ea ---
# friends = [], preference = 1
# --- student 27f54 ---
# friends = [], preference = 1
# --- student f0c14 ---
# friends = [], preference = 1
# --- student f5e99 ---
# friends = [], preference = 1
# --- student 95506 ---
# friends = [], preference = 1
# --- student dacea ---
# friends = [], preference = 1
# --- student 3126f ---
# friends = [], preference = 1
# --- student 2c684 ---
# friends = [], preference = 14
# --- student f65f7 ---
# friends = [], preference = 1
# --- student 3c948 ---
# friends = [], preference = 1
# --- student e2f32 ---
# friends = [], preference = 3
# --- student 0bb20 ---
# friends = [], preference = 1
# --- student ad98a ---
# friends = [], preference = 1
# --- student f8117 ---
# friends = [], preference = 1
# --- student cb944 ---
# friends = [], preference = 14
# --- student e1376 ---
# friends = [], preference = 1
# --- student 7fd51 ---
# friends = [], preference = 2
# --- student c8292 ---
# friends = [], preference = 1
# --- student 2a591 ---
# friends = [], preference = 3
# --- student 5cf3a ---
# friends = [], preference = 2
# --- student 6f08d ---
# friends = [], preference = 1
# --- student ede24 ---
# friends = [], preference = 1
# --- student 6beb5 ---
# friends = [], preference = 2
# --- student 4c684 ---
# friends = [], preference = 1
# --- student 712d2 ---
# friends = [], preference = 1
# --- student 174fe ---
# friends = [], preference = 1
# --- student c0f80 ---
# friends = [], preference = 11
# --- student aeb8e ---
# friends = [], preference = 1
# --- student f73ff ---
# friends = [], preference = 2
# --- student c7939 ---
# friends = [], preference = 2
# --- student 2e912 ---
# friends = [], preference = 1
# --- student 4f711 ---
# friends = [], preference = 1
# === Stats ===
# equal = 52
# opt better = 68
# manual better = 29
# trade-off = 19
