# %%
import networkx as nx
import numpy as np
import pickle
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
import scipy
from collections import deque
import seaborn as sns

# %%
lambdas = [1, 2, 5, 10]
lambdasToString = [str(l) for l in lambdas]
# conflictGraphType = "friends"
# mainProjectDist = "uniform"
# secondaryProjectDist = "trunc_gaussian"
# input_file = f'./inputs/graph_n{n}_{conflictGraphType}_{mainProjectDist}_{secondaryProjectDist}.pickle'
# results_file = f'./results/graph_n{n}_lambda{l}_{conflictGraphType}_{mainProjectDist}_{secondaryProjectDist}.pickle'
input_file = f'./csDS506.pickle'

# %% [markdown]
# ## Input analysis

# %%
def project_term(x):
    # Requires definition of lambda_
    res = 0
    # project preference term
    for u in nodes:
        for p in projects:
            if (u, p) in c:
                res += c[(u, p)] * x[(u, p)]
    res *= lambda_
    return res

def conflict_term(x):
    res = 0
    for e in edges:
        u, v = e
        inner_sum = 0
        for p in projects:
            inner_sum += x[(u, p)] * x[(v, p)]
        res += w[(u, v)] * (1 - inner_sum)
    return res
    
def f(x):
    # Requires definition of lambda_
    return project_term(x) + conflict_term(x)

# %%
with open(input_file, 'rb') as file:
    projects = pickle.load(file)
    capacities = pickle.load(file)
    numOfProjects = len(capacities)
    c = pickle.load(file)
    w = pickle.load(file)
    edges = pickle.load(file)
    wE = sum([w[e] for e in w])
    assignment = pickle.load(file)
    representatives = pickle.load(file)
    
G = nx.Graph()
G.add_edges_from(edges)
nodes = list(G.nodes)
n = len(nodes)
G_c = nx.complement(G)

# %%
proj_popularity = dict()
for p in projects:
    proj_popularity[p] = 0
    
for u in nodes:
    for p in projects:
        if (u, p) in c:
            proj_popularity[p] += c[(u, p)]
            
xs = [p[1: 20] for p in projects]
ys = proj_popularity.values()

plt.bar(xs, ys)
plt.xlabel('Project')
plt.xticks(rotation = 60)
plt.ylabel('Popularity')
plt.title(f'Project popularity')

plt.show()

# %%
G_c = nx.complement(G)
    
print(f'number of (conflict) edges = {len(edges)}')
nx.draw(G_c, pos=nx.spring_layout(G_c, k=0.2, iterations=20), with_labels=True)
plt.title(f'Friends graph')
plt.show()
# Out:
# number of (conflict) edges = 13952

# %% [markdown]
# ## Results analysis

# %%
settings = dict()
results = dict()
times = dict()

for l in lambdasToString:
#     results_file = f'./results/graph_n{n}_lambda{l}_{conflictGraphType}_{mainProjectDist}_{secondaryProjectDist}.pickle'
    results_file = f'./results/csDS506_lambda{l}.pickle'
    with open(results_file, 'rb') as file:
        settings[l] = pickle.load(file)
        edges = pickle.load(file)
        results[l] = pickle.load(file)
        times[l] = pickle.load(file)
        file.close()

# %%
obj_opt = dict()
obj_round12 = dict()
obj_round34 = dict()
obj_project = dict()
obj_conflict = dict()

x_frac12 = dict()
x_frac34 = dict()
x_round12 = dict()
x_round34 = dict()
x_opt = dict()
x_project = dict()
x_conflict = dict()

approx_ratio12 = dict()
approx_ratio34 = dict()

for i in range(len(lambdas)):
    l = lambdasToString[i]
    lambda_ = lambdas[i] * wE/ n
    res = results[l]
    obj_opt[l] = res["quad_val"]
    obj_round12[l] = res["rounded_val12"]
    obj_round34[l] = res["rounded_val34"]
    obj_project[l] = res["project_val"]
    obj_conflict[l] = res["conflict_val"]
    
    x_frac12[l] = res["frac_sol12"]
    x_frac34[l] = res["frac_sol34"]
    x_opt[l] = res["quad_sol"]
    x_round12[l] = res["rounded_sol12"]
    x_round34[l] = res["rounded_sol34"]
    x_project[l] = res["project_sol"]
    x_conflict[l] = res["conflict_sol"]
    
    approx_ratio12[l] = obj_round12[l] / obj_opt[l]
    approx_ratio34[l] = obj_round34[l] / obj_opt[l]
    

    print(f'\n======= lambda = {lambdas[i]} ==========')
    print(f'obj_round12 = {obj_round12[l]}, proj = {project_term(x_round12[l])}, conflict = {conflict_term(x_round12[l])}')
    print(f'obj_round34 = {obj_round34[l]}, proj = {project_term(x_round34[l])}, conflict = {conflict_term(x_round34[l])}')
    print(f'obj_opt = {obj_opt[l]}, proj = {project_term(x_opt[l])}, conflict = {conflict_term(x_opt[l])}')
    print(f'obj_project = {obj_project[l]}, proj = {project_term(x_project[l])}, conflict = {conflict_term(x_project[l])}')
    print(f'obj_conflict = {obj_conflict[l]}, proj = {project_term(x_conflict[l])}, conflict = {conflict_term(x_conflict[l])}')
    print(f'approx ratio (1/2 approx) = {obj_round12[l] / obj_opt[l]}')
    print(f'approx ratio (3/4 approx) = {obj_round34[l] / obj_opt[l]}')
    
    ind = ["obj_opt", "obj_round12", "obj_round34", "obj_project", "obj_conflict"]
    xs = [x_opt[l], x_round12[l], x_round34[l], x_project[l], x_conflict[l]]
    
    a = np.array([project_term(x) for x in xs])
    b = np.array([conflict_term(x) for x in xs])

    p1 = plt.bar(ind, a, color='green', label="project")
    p2 = plt.bar(ind, b, color='#FF0000', bottom=sum([a]), label="conflict")
    
    plt.legend()
    plt.show()
# Out:
# ======= lambda = 1 ==========
# obj_round12 = 25371.25850340136, proj = 184199.61904761905, conflict = 13709
# obj_round34 = 25359.427392290247, proj = 184199.61904761905, conflict = 13697.16888888888
# obj_opt = 25404.258503401357, proj = 184199.61904761905, conflict = 13742.0
# obj_project = 25329.258503401357, proj = 184199.61904761905, conflict = 13667.0
# obj_conflict = 17391.326988355562, proj = 102480.76190476191, conflict = 13806.0
# approx ratio (1/2 approx) = 0.998701005187946
# approx ratio (3/4 approx) = 0.998235291492365
# ======= lambda = 2 ==========
# obj_round12 = 37022.67573696144, proj = 368233.1428571429, conflict = 13712
# obj_round34 = 37018.76589569159, proj = 368399.23809523834, conflict = 13694.248888888875
# obj_opt = 37064.517006802715, proj = 368399.2380952381, conflict = 13740.0
# obj_project = 36991.517006802715, proj = 368399.2380952381, conflict = 13667.0
# obj_conflict = 20976.653976711124, proj = 204961.52380952382, conflict = 13806.0
# approx ratio (1/2 approx) = 0.9988711232947244
# approx ratio (3/4 approx) = 0.9987656358478184
# ======= lambda = 5 ==========
# obj_round12 = 72019.29251700678, proj = 920998.0952380953, conflict = 13708
# obj_round34 = 72005.3814058957, proj = 920998.0952380953, conflict = 13694.08888888888
# obj_opt = 72053.29251700678, proj = 920998.0952380953, conflict = 13742.0
# obj_project = 71965.29251700678, proj = 920998.0952380953, conflict = 13654.0
# obj_conflict = 31732.63494177781, proj = 512403.8095238095, conflict = 13806.0
# approx ratio (1/2 approx) = 0.9995281270457977
# approx ratio (3/4 approx) = 0.9993350600723796
# ======= lambda = 10 ==========
# obj_round12 = 130211.17233560089, proj = 1840335.238095238, conflict = 13727
# obj_round34 = 130319.34058956915, proj = 1841996.1904761905, conflict = 13696.75555555555
# obj_opt = 130364.58503401357, proj = 1841996.1904761905, conflict = 13742.0
# obj_project = 130275.58503401357, proj = 1841996.1904761905, conflict = 13653.0
# obj_conflict = 49659.26988355562, proj = 1024807.619047619, conflict = 13806.0
# approx ratio (1/2 approx) = 0.998823202648383
# approx ratio (3/4 approx) = 0.9996529391442269

# %% [markdown]
# ### Reconstruct optimal teams

# %%
def construct_teams(x):
    teams = dict()
    for p in projects:
        teams[p] = []

    for e in x:
        u, p = e
        if x[e] == 1:
            u, p = e
            teams[p].append(u)
            
    for p in projects:
        teams[p].sort()
        
    return teams
            
teams_opt = dict()
for l in lambdasToString:    
    teams_opt[l] = construct_teams(x_opt[l])
    l_val = l.replace('p', '.')
    print(f'\n======== lambda {l_val} ==========')
    print(teams_opt[l])
# Out:
# ======== lambda 1 ==========
# {'b09c1A': ['027b3', '2137a', '2cdf6', '371ec', '49f94'], '6c0f1A': ['09e60', '3c948', '4f711', 'c8292', 'f0c14'], 'f10d5A': ['2684a', '34706', '5cf3a', '8d841', 'a9fbb'], 'f0a5eA': ['05b07', '3126f', '995a5', 'f73c1', 'ff8ac'], 'a23d9A': ['52881', '99ba4', '9e1a4', 'c2def', 'fffe2'], '4a15fA': ['239b0', 'a3004'], 'eb50dA': ['3b6af', 'aae49'], 'be328A': ['72cc1'], '7f7c0A': ['62de3'], '20ef0A': ['174fe', '277e2', 'e2f32'], 'acaecA': ['03dae', '7e05a'], 'bd1f8A': ['202e8', '3882e', '5d597', 'd8dc3', 'f65f7'], '697f1A': ['07ba3', '0ac0b', '0bb20', '8cc4a', 'e1376'], '02088A': ['2e912', '38b25', '4b771', '6024e', 'ec344'], 'b09c1B': ['0e191', '28bbe', '7e5b4', '808cb', 'd729a'], 'b09c1C': ['90c36', 'ad98a', 'c0f80', 'cd65d', 'dbeb4'], 'b09c1D': ['05dc1', '89b1b', '95506', 'ca78f', 'cba6a'], 'b09c1E': ['36bf2', '4bb9b', 'a31f8', 'ae1b8', 'aefc9'], '4a15fB': ['02ed3', '3e725', '59b09'], '4a15fC': ['1003a', '98075'], '4a15fD': ['ddcf1'], '4a15fE': ['01653', '47d11'], 'eb50dB': ['4576d', '8b401', 'b31ec'], 'eb50dC': ['48133', '58c1e', 'dacea'], 'eb50dD': ['285b3', '2a591', '6be1f'], 'eb50dE': ['09ee0', 'f8117', 'fbda7'], 'be328B': ['3e878', 'ede24'], 'be328C': ['b5a51', 'fc95d'], 'be328D': ['2c684'], 'be328E': ['cb944'], '7f7c0B': ['6beb5', 'f2d45'], '7f7c0C': ['0fa51'], '7f7c0D': ['27f54'], '7f7c0E': ['3f9ea', 'eaac3'], '02088B': ['0aa44', '0e9fb', '36fd2', 'aeb8e', 'dc9e1'], '02088C': ['08e18', '100c3', '69695', 'f5e99', 'fdb53'], '02088D': ['48253', '4c684', '5c7bb', '99fdf', 'f3d21'], '02088E': ['44114', '45293', '626e6', 'a3a06', 'e7903'], '20ef0B': ['30225', '712d2', '7301f'], '20ef0C': ['15a0f', 'c3f2e'], 'acaecB': ['5485c', '6ace2', 'ff084'], 'acaecC': ['1c2a8', 'da8fa'], 'bd1f8B': ['38e2a', '88177', 'c35e4', 'c7939', 'fa523'], 'bd1f8C': ['4f9dd', '725e9', 'c1783', 'd61b1', 'fbfa2'], '6c0f1B': ['4437f', '48726', '6fd10', 'e2a40', 'f61b2'], 'f10d5B': ['0d24a', '4b146', '7fd51', 'd51a0', 'f73ff'], 'a23d9B': ['0fa99', '6f08d', '79052', 'd225d', 'f0e0b'], '697f1B': ['10718', '10cde', '7fd17', '86b6e', 'fccf2'], 'f0a5eB': ['6aff8', 'b6861', 'd8c36', 'e4d94', 'e6564']}
#
# ======== lambda 2 ==========
# {'b09c1A': ['28bbe', '36bf2', '7e5b4', '808cb', 'd729a'], '6c0f1A': ['09e60', '4437f', 'c8292', 'e2a40', 'f0c14'], 'f10d5A': ['34706', '7fd51', '8d841', 'a9fbb', 'f73ff'], 'f0a5eA': ['6aff8', 'b6861', 'd8c36', 'e4d94', 'e6
], '4a15fA': ['01653', '47d11'], 'eb50dA': ['285b3', '2a591', '6be1f'], 'be328A': ['ede24'], '7f7c0A': ['27f54', 'f2d45'], '20ef0A': ['277e2', '7301f', 'e2f32'], 'acaecA': ['5485c', '6ace2', 'ff084'], 'bd1f8A': ['3882e', 'c35e4', 'f65f7', 'fa523', 'fbfa2'], '697f1A': ['0bb20', '10cde', '7fd17', '86b6e', 'fccf2'], '02088A': ['100c3', '44114', '4c684', '69695', 'f61b2'], 'b09c1B': ['0e191', '90c36', 'ad98a', 'cd65d', 'dbeb4'], 'b09c1C': ['027b3', '2137a', '2cdf6', '371ec', '49f94'], 'b09c1D': ['28bbe', '7e5b4', '808cb', 'ae1b8', 'd729a'], 'b09c1E': ['05dc1', '4bb9b', '89b1b', 'a31f8', 'ca78f'], '4a15fB': ['1003a', '98075'], '4a15fC': ['ddcf1'], '4a15fD': ['02ed3', '3e725', '59b09'], '4a15fE': ['239b0', 'a3004'], 'eb50dB': ['3b6af', '8b401', 'dacea'], 'eb50dC': ['4576d', '48133', '58c1e'], 'eb50dD': ['aae49', 'b31ec'], 'eb50dE': ['09ee0', 'f8117', 'fbda7'], 'be328B': ['3e878'], 'be328C': ['b5a51'], 'be328D': ['2c684'], 'be328E': ['fc95d'], '7f7c0B': ['62de3', 'eaac3'], '7f7c0C': ['6beb5', 'cb944'], '7f7c0D': ['3f9ea', '72cc1'], '7f7c0E': ['0fa51'], '02088B': ['45293', '4b771', '626e6', 'aeb8e', 'e7903'], '02088C': ['0aa44', '48253', 'a3a06', 'dc9e1', 'f3d21'], '02088D': ['08e18', '0e9fb', '2e912', '36fd2', 'fdb53'], '02088E': ['5c7bb', '6024e', '99fdf', 'ec344', 'f5e99'], '20ef0B': ['174fe', '30225'], '20ef0C': ['15a0f', '712d2', 'c3f2e'], 'acaecB': ['03dae', '1c2a8'], 'acaecC': ['7e05a', 'da8fa'], 'bd1f8B': ['4f9dd', '725e9', 'c1783', 'd61b1', 'd8dc3'], 'bd1f8C': ['202e8', '38e2a', '5d597', '88177', 'c7939'], '6c0f1B': ['09e60', '38b25', '48726', '6fd10', 'c8292'], 'f10d5B': ['2684a', '34706', '5cf3a', '7fd51', 'a9fbb'], 'a23d9B': ['6f08d', '9e1a4', 'c2def', 'f0e0b', 'fffe2'], '697f1B': ['07ba3', '0ac0b', '10718', '8cc4a', 'e1376'], 'f0a5eB': ['05b07', '995a5', 'e4d94', 'e6564', 'ff8ac']}
#
# ======== lambda 10 ==========
# {'b09c1A': ['28bbe', '7e5b4', '808cb', 'cba6a', 'd729a'], '6c0f1A': ['4437f', '4f711', 'c8292', 'e2a40', 'f0c14'], 'f10d5A': ['0d24a', '2684a', '34706', '4b146', 'd51a0'], 'f0a5eA': ['6aff8', '995a5', 'b6861', 'd8c36', 'ff8ac'], 'a23d9A': ['0fa99', '79052', '9e1a4', 'd225d', 'fffe2'], '4a15fA': ['01653', '47d11'], 'eb50dA': ['285b3', '2a591', '6be1f'], 'be328A': ['cb944', 'ede24'], '7f7c0A': ['0fa51', '3f9ea'], '20ef0A': ['174fe', '277e2', 'e2f32'], 'acaecA': ['03dae', '7e05a', 'da8fa'], 'bd1f8A': ['3882e', '38e2a', '88177', 'c1783', 'd61b1'], '697f1A': ['07ba3', '0ac0b', '0bb20', '10718', '8cc4a'], '02088A': ['5c7bb', '6024e', '69695', '99fdf', 'ec344'], 'b09c1B': ['4bb9b', '90c36', 'a31f8', 'cd65d', 'dbeb4'], 'b09c1C': ['36bf2', '89b1b', '95506', 'ad98a', 'c0f80'], 'b09c1D': ['027b3', '2137a', '2cdf6', '371ec', '49f94'], 'b09c1E': ['05dc1', '0e191', 'ae1b8', 'aefc9', 'ca78f'], '4a15fB': ['98075'], '4a15fC': ['1003a', 'ddcf1'], '4a15fD': ['239b0', 'a3004'], '4a15fE': ['02ed3', '3e725', '59b09'], 'eb50dB': ['09ee0', 'f8117', 'fbda7'], 'eb50dC': ['48133', '58c1e', 'aae49'], 'eb50dD': ['3b6af', '8b401', 'dacea'], 'eb50dE': ['4576d', 'b31ec'], 'be328B': ['b5a51'], 'be328C': ['2c684'], 'be328D': ['3e878'], 'be328E': ['72cc1'], '7f7c0B': ['27f54', 'f2d45'], '7f7c0C': ['62de3', '6beb5'], '7f7c0D': ['eaac3'], '7f7c0E': ['fc95d'], '02088B': ['0e9fb', '100c3', '36fd2', '4c684', 'aeb8e'], '02088C': ['08e18', '0aa44', 'a3a06', 'dc9e1', 'fdb53'], '02088D': ['38b25', '45293', '4b771', '626e6', 'e7903'], '02088E': ['2e912', '48253', '99ba4', 'f3d21', 'f5e99'], '20ef0B': ['712d2', '7301f'], '20ef0C': ['15a0f', '30225', 'c3f2e'], 'acaecB': ['5485c', '6ace2'], 'acaecC': ['05b07', '1c2a8'], 'bd1f8B': ['202e8', '4f9dd', '5d597', 'c7939', 'd8dc3'], 'bd1f8C': ['52881', '725e9', 'c35e4', 'f65f7', 'fa523'], '6c0f1B': ['09e60', '3c948', '48726', '6fd10', 'f61b2'], 'f10d5B': ['5cf3a', '7fd51', '8d841', 'a9fbb', 'f73ff'], 'a23d9B': ['44114', '6f08d', 'c2def', 'f0e0b', 'fbfa2'], '697f1B': ['10cde', '7fd17', '86b6e', 'e1376', 'fccf2'], 'f0a5eB': ['3126f', 'e4d94', 'e6564', 'f73c1', 'ff084']}

# %% [markdown]
# ### Reconstruct teams (1/2 approx-algorithm)

# %%
teams_round12 = dict()
for l in lambdasToString:    
    teams_round12[l] = construct_teams(x_round12[l])
    l_val = l.replace('p', '.')
    print(f'\n======== lambda {l_val} ==========')
    print(teams_round12[l])
# Out:
# ======== lambda 1 ==========
# {'b09c1A': ['4bb9b', 'a31f8', 'cba6a', 'cd65d', 'dbeb4'], '6c0f1A': ['38b25', '4437f', '48726', 'c8292', 'e2a40'], 'f10d5A': ['0d24a', '2684a', '4b146', '6beb5', 'd51a0'], 'f0a5eA': ['6aff8', 'b6861', 'd8c36', 'e4d94', 'e6564'], 'a23d9A': ['34706', '52881', '9e1a4', 'a3a06', 'c2def'], '4a15fA': ['239b0', '98075', 'a3004'], 'eb50dA': ['3b6af', 'b31ec', 'dacea'], 'be328A': ['3e878'], '7f7c0A': ['3f9ea', 'fc95d'], '20ef0A': ['15a0f', '277e2', '712d2', '7301f'], 'acaecA': ['5485c', '6ace2'], 'bd1f8A': ['44114', 'c35e4', 'c7939', 'd8dc3', 'fa523'], '697f1A': ['07ba3', '0ac0b', '10718', '10cde', 'e1376'], '02088A': ['08e18', '4b771', '5c7bb', '69695', 'fdb53'], 'b09c1B': ['371ec', '90c36', '95506', 'ad98a', 'c0f80'], 'b09c1C': ['05dc1', '28bbe', '2cdf6', '7e5b4', '89b1b'], 'b09c1D': ['0e191', '2137a', 'ae1b8', 'ca78f', 'd729a'], 'b09c1E': ['027b3', '36bf2', '49f94', '808cb', 'aefc9'], '4a15fB': ['02ed3', '3e725', '59b09'], '4a15fC': ['ddcf1'], '4a15fD': ['1003a'], '4a15fE': ['01653', '47d11'], 'eb50dB': ['2c684', '4576d', '48133', '58c1e', '6be1f'], 'eb50dC': ['285b3', '8b401', 'aae49', 'f8117'], 'eb50dD': ['2a591'], 'eb50dE': ['09ee0', 'fbda7'], 'be328B': ['ede24'], 'be328C': ['72cc1'], 'be328D': ['b5a51'], 'be328E': ['cb944'], '7f7c0B': ['62de3', '79052'], '7f7c0C': ['27f54'], '7f7c0D': ['0fa51'], '7f7c0E': ['f2d45'], '02088B': ['09e60', '36fd2', '4c684', 
], '697f1B': ['10cde', '7fd17', '86b6e', 'e1376', 'fccf2'], 'f0a5eB': ['05b07', '995a5', 'e4d94', 'e6564', 'ff8ac']}
#
# ======== lambda 10 ==========
# {'b09c1A': ['4bb9b', '89b1b', 'a31f8', 'aefc9', 'cba6a'], '6c0f1A': ['38b25', '48726', '6fd10', 'f0c14', 'f61b2'], 'f10d5A': ['0d24a', '4b146', '8d841', 'a9fbb', 'd51a0'], 'f0a5eA': ['3126f', '4576d', '995a5', 'f73c1', 'ff084'], 'a23d9A': ['44114', '626e6', '6f08d', 'c2def', 'fbfa2'], '4a15fA': ['01653', '47d11'], 'eb50dA': ['285b3', '6be1f'], 'be328A': ['2c684', 'ede24'], '7f7c0A': ['f2d45'], '20ef0A': ['277e2', '30225', '712d2', '7301f'], 'acaecA': ['03dae', '1c2a8', '7e05a'], 'bd1f8A': ['3882e', '5d597', 'c1783', 'c7939', 'd61b1'], '697f1A': ['10cde', '7fd17', '86b6e', 'e1376', 'fccf2'], '02088A': ['100c3', '2e912', '48253', '69695', 'aeb8e'], 'b09c1B': ['2cdf6', '49f94', '95506', 'ae1b8', 'c0f80'], 'b09c1C': ['027b3', '28bbe', '7e5b4', '808cb', 'd729a'], 'b09c1D': ['05dc1', '2137a', '371ec', 'ad98a', 'ca78f'], 'b09c1E': ['0e191', '36bf2', '90c36', 'cd65d', 'dbeb4'], '4a15fB': ['239b0', 'a3004'], '4a15fC': ['1003a', '98075'], '4a15fD': ['02ed3', '3e725', '59b09'], '4a15fE': ['ddcf1'], 'eb50dB': ['48133', '58c1e'], 'eb50dC': ['09ee0', 'fbda7'], 'eb50dD': ['3b6af', '8b401', 'b31ec', 'dacea', 'f8117'], 'eb50dE': ['2a591', 'aae49'], 'be328B': ['3e878'], 'be328C': ['b5a51'], 'be328D': ['fc95d'], 'be328E': ['72cc1'], '7f7c0B': ['62de3', '79052', 'eaac3'], '7f7c0C': ['3f9ea'], '7f7c0D': ['6beb5'], '7f7c0E': ['0fa51', '27f54'], '02088B': ['0aa44', '4b771', '4c684', 'dc9e1', 'f5e99'], '02088C': ['0e9fb', '36fd2', '5c7bb', '6024e', 'f3d21'], '02088D': ['08e18', '09e60', 'a3a06', 'e7903', 'fdb53'], '02088E': ['45293', '52881', '99fdf', 'ec344'], '20ef0B': ['cb944', 'e2f32'], '20ef0C': ['15a0f', '174fe', 'c3f2e'], 'acaecB': ['05b07', 'da8fa', 'ff8ac'], 'acaecC': ['5485c', '6ace2'], 'bd1f8B': ['38e2a', '4f9dd', '88177', 'd8dc3', 'f65f7'], 'bd1f8C': ['202e8', '725e9', '99ba4', 'c35e4', 'fa523'], '6c0f1B': ['3c948', '4437f', '4f711', 'c8292', 'e2a40'], 'f10d5B': ['2684a', '34706', '5cf3a', '7fd51', 'f73ff'], 'a23d9B': ['0fa99', '9e1a4', 'd225d', 'f0e0b', 'fffe2'], '697f1B': ['07ba3', '0ac0b', '0bb20', '10718', '8cc4a'], 'f0a5eB': ['6aff8', 'b6861', 'd8c36', 'e4d94', 'e6564']}

# %% [markdown]
# ### Reconstruct teams (3/4 approx-algorithm)

# %%
teams_round34 = dict()
for l in lambdasToString:    
    teams_round34[l] = construct_teams(x_round34[l])
    l_val = l.replace('p', '.')
    print(f'\n======== lambda {l_val} ==========')
    print(teams
 'd8dc3', 'f65f7'], '697f1A': ['07ba3', '0bb20', '10718', '7fd17', 'fccf2'], '02088A': ['0e9fb', '45293', '626e6', '99fdf', 'a3a06'], 'b09c1B': ['36bf2', '7e5b4', 'a31f8', 'ae1b8', 'cd65d'], 'b09c1C': ['0e191', '49f94', '4bb9b', '89b1b', 'dbeb4'], 'b09c1D': ['027b3', '2137a', '2cdf6', '95506', 'cba6a'], 'b09c1E': ['05dc1', '28bbe', '371ec', 'aefc9', 'c0f80'], '4a15fB': ['47d11', '59b09'], '4a15fC': ['239b0', 'a3004'], '4a15fD': ['02ed3', '3e725'], '4a15fE': ['1003a', 'ddcf1'], 'eb50dB': ['09ee0', '58c1e'], 'eb50dC': ['285b3', '48133'], 'eb50dD': ['3b6af', '4576d'], 'eb50dE': ['8b401', 'b31ec'], 'be328B': ['3e878'], 'be328C': ['b5a51'], 'be328D': ['2c684'], 'be328E': ['72cc1'], '7f7c0B': ['6beb5'], '7f7c0C': ['fc95d'], '7f7c0D': ['f2d45'], '7f7c0E': [], '02088B': ['36fd2', '38b25', '69695', 'aeb8e', 'ec344'], '02088C': ['0aa44', '2e912', '48253', '4b771', '5c7bb'], '02088D': ['100c3', '6024e', '99ba4', 'e7903', 'f5e99'], '02088E': ['08e18', '4c684', 'dc9e1', 'f3d21', 'fdb53'], '20ef0B': ['277e2', '30225'], '20ef0C': ['c3f2e', 'e2f32'], 'acaecB': ['1c2a8', 'da8fa'], 'acaecC': ['5485c'], 'bd1f8B': ['52881', '5d597', '88177', 'c7939', 'fa523'], 'bd1f8C': ['202e8', '4f9dd', '725e9', 'c35e4', 'd61b1'], '6c0f1B': ['09e60', '4437f', 'c8292', 'f0c14', 'f61b2'], 'f10d5B': ['0d24a', '2684a', '5cf3a', '7fd51', 'a9fbb'], 'a23d9B': ['c2def', 'd225d', 'f0e0b', 'fbfa2', 'fffe2'], '697f1B': ['0ac0b', '10cde', '86b6e', '8cc4a', 'e1376'], 'f0a5eB': ['3126f', 'b6861', 'e6564', 'f73c1']}

# %% [markdown]
# ### Compare $\lambda \sum_v \sum_t c_{vt}x_{vt}$ and $w(E)$
# If $\alpha = \lambda \sum_v \sum_t c_{vt}x_{vt} - w(E) \geq 0$, then we can apply the $3/4$-approximation algorithm.
# Otherwise, the guarantees of the algorithm do not hold.

# %%
print(f'w(E) = {wE}')
for l, lstr in zip(lambdas, lambdasToString):
    lambda_ = l * wE / n
    projectsVal = project_term(x_round34[lstr])
    print(f'\n===== lambda = {l} ======')
    print(f'projects term value = {projectsVal}')
    print(f'a = {projectsVal - wE}')
# Out:
# w(E) = 13952
#
# ===== lambda = 1 ======
# projects term value = 184199.61904761905
# a = 170247.61904761905
#
# ===== lambda = 2 ======
# projects term value = 368399.23809523834
# a = 354447.23809523834
#
# ===== lambda = 5 ======
# projects term value = 920998.0952380953
# a = 907046.0952380953
#
# ===== lambda = 10 ======
# projects term value = 1841996.1904761905
# a = 1828044.1904761905

# %% [markdown]
# ### How many students got a project they like?

# %%
def calc_preference_stats(teams):
    res = 0
    students = []
    for t in teams:
        team = teams[t]
        for u in team:
            res += 1 if (u, t) in c else 0
            students.append(u)
    res /= n
    return res, students


for l in lambdasToString:
    print(f'\n====== lambda = {l_val} =======')
    
    teams = teams_opt[l]
    res, students = calc_preference_stats(teams)
    
    l_val = l.replace('p', '.')
    print(f'(Optimal teams) percentage of students that got a project they like = {res}')
    print(f'list of students that got a project they like: {students}')
    
    teams = teams_round12[l]
    res, students = calc_preference_stats(teams)
    
    l_val = l.replace('p', '.')
    print(f'(1/2 approx alg) percentage of students that got a project they like = {res}')
    print(f'list of students that got a project they like: {students}')
    
    teams = teams_round34[l]
    res, students = calc_preference_stats(teams)
    
    l_val = l.replace('p', '.')
    print(f'(3/4 approx alg) percentage of students that got a project they like = {res}')
    print(f'list of students that got a project they like: {students}')
# Out:
# ====== lambda = 10 =======
# (Optimal teams) percentage of students that got a project they like = 1.0
# list of students that got a project they like: 
aff8', 'b6861', 'd8c36', 'e4d94', 'e6564']
# (3/4 approx alg) percentage of students that got a project they like = 0.9107142857142857
# list of students that got a project they like: ['808cb', '90c36', 'ad98a', 'ca78f', 'd729a', '3c948', '48726', '4f711', '6fd10', 'e2a40', '34706', '4b146', '8d841', 'd51a0', 'f73ff', '6aff8', 'd8c36', 'e4d94', 'ff084', 'ff8ac', '0fa99', '44114', '6f08d', '79052', '9e1a4', '01653', '98075', '6be1f', 'fbda7', '62de3', '15a0f', '7301f', '03dae', '6ace2', '3882e', '38e2a', 'c1783', 'd8dc3', 'f65f7', '07ba3', '0bb20', '10718', '7fd17', 'fccf2', '0e9fb', '45293', '626e6', '99fdf', 'a3a06', '36bf2', '7e5b4', 'a31f8', 'ae1b8', 'cd65d', '0e191', '49f94', '4bb9b', '89b1b', 'dbeb4', '027b3', '2137a', '2cdf6', '95506', 'cba6a', '05dc1', '28bbe', '371ec', 'aefc9', 'c0f80', '47d11', '59b09', '239b0', 'a3004', '02ed3', '3e725', '1003a', 'ddcf1', '09ee0', '58c1e', '285b3', '48133', '3b6af', '4576d', '8b401', 'b31ec', '3e878', 'b5a51', '2c684', '72cc1', '6beb5', 'fc95d', 'f2d45', '36fd2', '38b25', '69695', 'aeb8e', 'ec344', '0aa44', '2e912', '48253', '4b771', '5c7bb', '100c3', '6024e', '99ba4', 'e7903', 'f5e99', '08e18', '4c684', 'dc9e1', 'f3d21', 'fdb53', '277e2', '30225', 'c3f2e', 'e2f32', '1c2a8', 'da8fa', '5485c', '52881', '5d597', '88177', 'c7939', 'fa523', '202e8', '4f9dd', '725e9', 'c35e4', 'd61b1', '09e60', '4437f', 'c8292', 'f0c14', 'f61b2', '0d24a', '2684a', '5cf3a', '7fd51', 'a9fbb', 'c2def', 'd225d', 'f0e0b', 'fbfa2', 'fffe2', '0ac0b', '10cde', '86b6e', '8cc4a', 'e1376', '3126f', 'b6861', 'e6564', 'f73c1']

# %% [markdown]
# ### How many teammate friends each student has? (lambda = fixed)

# %%
l = lambdasToString[0]
teams1 = teams_opt[l]
teams2 = teams_round12[l]

def count_friends(teams):
    friends = dict()
    for team in teams.values():
        for u in team:
            friends[u] = len([1 for v in team if u != v and (u, v) not in w and (v, u) not in w])
    return friends

friends_opt = count_friends(teams1)
friends_round = count_friends(teams2)

avgFriendsOpt = sum(friends_opt.values()) / n
avgFriendsRound = sum(friends_round.values()) / n

xs = [str(u) for u in nodes]
ys = friends_opt.values()

plt.bar(xs, ys)
plt.xlabel('Students')
plt.xticks(rotation=45)
plt.ylabel('# teammate friends')
plt.title(f'Number of teammate friends (optimal solution), (lambda = {l})')

plt.show()

xs = [str(u) for u in nodes]
ys = friends_round.values()

plt.bar(xs, ys)
plt.xlabel('Students')
plt.xticks(rotation=45)
plt.ylabel('# teammate friends')
plt.title(f'Number of teammate friends (1/2 approximation), (lambda = {l})')

plt.show()

print(f'avgFriendsOpt = {avgFriendsOpt}')
print(f'avgFriendsRound  (1/2 approximation) = {avgFriendsRound}')
# Out:
# avgFriendsOpt = 0.6547619047619048
# avgFriendsRound  (1/2 approximation) = 0.38095238095238093

# %% [markdown]
# ### Teams comparison (lambda = fixed)

# %%
l = lambdasToString[0]
tm = teams_round12[l]
tm_opt = teams_opt[l]
print(f'optimal team {tm_opt}')
print(f'pipage team {tm}')
sameTeamsAndProject = len([1 for p in projects if tm[p] == tm_opt[p]])
print(f'number of identical teams and projects = {sameTeamsAndProject}')
sameTeams = len([t for t in tm if t in tm_opt])
print(f'number of identical teams = {sameTeams}')
# Out:
# optimal team {'b09c1A': ['027b3', '2137a', '2cdf6', '371ec', '49f94'
['6aff8', 'b6861', 'd8c36', 'e4d94', 'e6564']}
# pipage team {'b09c1A': ['4bb9b', 'a31f8', 'cba6a', 'cd65d', 'dbeb4'], '6c0f1A': ['38b25', '4437f', '48726', 'c8292', 'e2a40'], 'f10d5A': ['0d24a', '2684a', '4b146', '6beb5', 'd51a0'], 'f0a5eA': ['6aff8', 'b6861', 'd8c36', 'e4d94', 'e6564'], 'a23d9A': ['34706', '52881', '9e1a4', 'a3a06', 'c2def'], '4a15fA': ['239b0', '98075', 'a3004'], 'eb50dA': ['3b6af', 'b31ec', 'dacea'], 'be328A': ['3e878'], '7f7c0A': ['3f9ea', 'fc95d'], '20ef0A': ['15a0f', '277e2', '712d2', '7301f'], 'acaecA': ['5485c', '6ace2'], 'bd1f8A': ['44114', 'c35e4', 'c7939', 'd8dc3', 'fa523'], '697f1A': ['07ba3', '0ac0b', '10718', '10cde', 'e1376'], '02088A': ['08e18', '4b771', '5c7bb', '69695', 'fdb53'], 'b09c1B': ['371ec', '90c36', '95506', 'ad98a', 'c0f80'], 'b09c1C': ['05dc1', '28bbe', '2cdf6', '7e5b4', '89b1b'], 'b09c1D': ['0e191', '2137a', 'ae1b8', 'ca78f', 'd729a'], 'b09c1E': ['027b3', '36bf2', '49f94', '808cb', 'aefc9'], '4a15fB': ['02ed3', '3e725', '59b09'], '4a15fC': ['ddcf1'], '4a15fD': ['1003a'], '4a15fE': ['01653', '47d11'], 'eb50dB': ['2c684', '4576d', '48133', '58c1e', '6be1f'], 'eb50dC': ['285b3', '8b401', 'aae49', 'f8117'], 'eb50dD': ['2a591'], 'eb50dE': ['09ee0', 'fbda7'], 'be328B': ['ede24'], 'be328C': ['72cc1'], 'be328D': ['b5a51'], 'be328E': ['cb944'], '7f7c0B': ['62de3', '79052'], '7f7c0C': ['27f54'], '7f7c0D': ['0fa51'], '7f7c0E': ['f2d45'], '02088B': ['09e60', '36fd2', '4c684', 'e7903', 'fbfa2'], '02088C': ['0aa44', '2e912', '626e6', 'dc9e1', 'f3d21'], '02088D': ['0e9fb', '100c3', '99fdf', 'aeb8e', 'f5e99'], '02088E': ['45293', '48253', '6024e', '99ba4', 'ec344'], '20ef0B': ['174fe', 'e2f32'], '20ef0C': ['30225', 'c3f2e'], 'acaecB': ['f73c1', 'ff084'], 'acaecC': ['03dae', '1c2a8', '7e05a', 'da8fa'], 'bd1f8B': ['3882e', '38e2a', '725e9', '88177', 'f65f7'], 'bd1f8C': ['202e8', '4f9dd', '5d597', 'c1783', 'd61b1'], '6c0f1B': ['3c948', '4f711', '6fd10', 'f0c14', 'f61b2'], 'f10d5B': ['5cf3a', '7fd51', '8d841', 'a9fbb', 'f73ff'], 'a23d9B': ['0fa99', '6f08d', 'd225d', 'f0e0b', 'fffe2'], '697f1B': ['0bb20', '7fd17', '86b6e', '8cc4a', 'fccf2'], 'f0a5eB': ['05b07', '3126f', '995a5', 'eaac3', 'ff8ac']}
# number of identical teams and projects = 3
# number of identical teams = 49

# %% [markdown]
# ### Comparing solutions of different lambdas given a fixed objective function

# %% [markdown]
# #### Remark
# The optimal solution remains the same for different lambdas (?).\
# Can we think of a counter-example?
#
# The same is not true for the pipage algorithm solution.

# %% [markdown]
# ### In-team Conflicts

# %%
# conflicts for optimal teams
def calc_conflicts(teams):
    conflicts = dict()
    for t in teams:
        team = teams[t]
        conflicts[t] = 0
        if team:
            conflicts[t] = sum([1 for u in team for v in team if u < v and (u, v) in edges or (v, u) in edges])
        
    return conflicts

conflicts_opt = dict()
avgConflicts_opt = dict()
for l in lambdasToString:
    conflicts_opt[l] = calc_conflicts(teams_opt[l])
    nonEmptyTeams = [t for t in teams_opt[l] if t]
    avgConflicts_opt[l] = sum(conflicts_opt[l].values()) / len(nonEmptyTeams)

    xs = projects
    ys = conflicts_opt[l].values()

    plt.bar(xs, ys)
    plt.xlabel('Project')
    plt.xticks(rotation=60)
    plt.ylabel('Conflicts')
    plt.title(f'Conflicts per project (optimal rounding solution), (lambda = {l})')

    plt.show()

for l in lambdasToString:
    print(f'avg number of conflicts in a team = {avgConflicts_opt[l]}')
# Out:
# avg number of conflicts in a team = 6.612244897959184
# avg number of conflicts in a team = 6.63265306122449
# avg number of conflicts in a team = 6.6938775510204085
# avg number of conflicts in a team = 6.755102040816326

# %%
# conflicts for pipage algorithm teams
conflicts = dict()
avgConflicts = dict()
for l in lambdasToString:
    conflicts[l] = calc_conflicts(teams_round12[l])
    nonEmptyTeams = [t for t in teams_round12[l] if t]
    avgConflicts[l] = sum(conflicts[l].values()) / len(nonEmptyTeams)

    xs = projects
    ys = conflicts[l].values()

    plt.bar(xs, ys)
    plt.xlabel('Project')
    plt.xticks(rotation=60)
    plt.ylabel('Conflicts')
    plt.title(f'Conflicts per project (1/2 approximation algorithm), (lambda = {l})')

    plt.show()

for l in lambdasToString:
    print(f'avg number of conflicts in a team = {avgConflicts[l]}')
# Out:
# avg number of conflicts in a team = 7.857142857142857
# avg number of conflicts in a team = 7.551020408163265
# avg number of conflicts in a team = 7.551020408163265
# avg number of conflicts in a team = 7.387755102040816

# %% [markdown]
# ### Time (seconds) for each step

# %%
for l in lambdasToString:
    #del times["1.5"]["conflict_only"]
    plt.pie(times[l].values(), labels=times[l].keys(), normalize=True)
    plt.legend(loc='upper left')
    plt.show()

# %% [markdown]
# ## Comparison with manual solution

# %%
def min_friends(teams):
    minFriends = n
    for team in teams.values():
        for u in team:
            friends = sum([1 for v in team if u != v and (u, v) not in w and (v, u) not in w])
            minFriends = min(friends, minFriends)
    return minFriends
            
def max_friends(teams):
    maxFriends = 0
    for team in teams.values():
        for u in team:
            friends = sum([1 for v in team if u != v and (u, v) not in w and (v, u) not in w])
            maxFriends = max(friends, maxFriends)
    return maxFriends

def avg_friends(teams):
    friends = 0
    for team in teams.values():
        friends += sum([1 for u in team for v in team if u != v and (u, v) not in w and (v, u) not in w])
    return friends / n
        
def min_preference(teams):
    ans = 1
    for t in teams:
        team = teams[t]
        for u in team:
            ans = min(ans, 1 / c[(u, t)])      
    return ans
            
def max_preference(teams):
    ans = -1
    for t in teams:
        team = teams[t]
        for u in team:
            ans = max(ans, 1 / c[(u, t)])      
    return ans

def avg_preference(teams):
    pref = 0
    for t in teams:
        team = teams[t]
        pref += sum([1 / c[(u, t)] for u in team])
    return pref / n

# %%
def group_keys_by_value(input_dict):
    grouped_dict = {}
    
    for key, value in input_dict.items():
        if value in grouped_dict:
            grouped_dict[value].append(key)
        else:
            grouped_dict[value] = [key]
    
    return grouped_dict
teams_manual = group_keys_by_value(assignment)

# %%
teams_manual
# Out:
# {'eb50dE': ['3e878', 'fc95d', '6be1f', 'cb944'],
#  '02088A': ['48253', 'e7903', '45293', 'f3d21'],
#  '20ef0C': ['cba6a', '7301f', '174fe', '2e912'],
#  'be328B': ['03dae', '89b1b', '36fd2', '0e9fb'],
#  '02088C': ['69695', '277e2', '626e6', 'f61b2'],
#  'f0a5eB': ['a9fbb', 'aefc9', '36bf2', 'da8fa'],
#  'acaecC': ['7e5b4', '6ace2', '5485c', 'c7939'],
#  '4a15fC': ['47d11', 'ddcf1', '48726', '01653'],
#  '697f1A': ['e2a40', '4437f', '8cc4a', '34706'],
#  'bd1f8A': ['3882e', '4b771', '38b25', '0bb20'],
#  '7f7c0B': ['f2d45', '3b6af', '2684a', 'eaac3'],
#  '7f7c0A': ['a3004', '239b0', '27f54', '0fa51'],
#  '6c0f1B': ['4f711', '6fd10', '10718', 'c8292'],
#  'f0a5eA': ['0fa99', 'c2def', 'a3a06', 'd225d'],
#  '20ef0B': ['4f9dd', '30225', 'e2f32', 'f8117'],
#  'b09c1A': ['ff8ac', 'ad98a', '05b07', '995a5'],
#  'be328D': ['09e60', '58c1e', '48133', 'ede24'],
#  'a23d9A': ['fffe2', '62de3', '3126f', '9e1a4', '79052'],
#  'eb50dD': ['8b401', '4576d', 'dacea', '027b3', '49f94'],
#  '6c0f1A': ['05dc1', 'ca78f', 'e4d94', 'e6564', '3c948'],
#  '02088D': ['99fdf', '1c2a8', '5c7bb', 'aeb8e'],
#  'a23d9B': ['8d841', 'f73c1', '2137a', '6f08d', 'ff084'],
#  '7f7c0D': ['d8dc3', '72cc1', 'b5a51', '3f9ea'],
#  'bd1f8B': ['5d597', '07ba3', '0ac0b', '202e8'],
#  '4a15fA': ['725e9', '02ed3', '88177', '38e2a'],
#  'f10d5A': ['0d24a', 'd51a0', 'f73ff', '4b146'],
#  '7f7c0C': ['ae1b8', 'f0c14', '6beb5', '712d2'],
#  'be328C': ['d61b1', '2c684', 'c1783', 'aae49'],
#  'acaecB': ['7fd17', '86b6e', '10cde', 'fccf2'],
#  'be328A': ['09ee0', '98075', 'fbda7', '2a591'],
#  '02088E': ['99ba4', '100c3', 'f5e99', '52881'],
#  '02088B': ['fdb53', '08e18', 'fbfa2', '44114'],
#  'eb50dB': ['f0e0b', '4bb9b', '285b3', 'a31f8'],
#  '20ef0A': ['15a0f', '0aa44', 'c3f2e', 'dc9e1'],
#  'eb50dC': ['b31ec', '95506', '6024e', 'ec344'],
#  'acaecA': ['b6861', 'd8c36', '6aff8', '4c684'],
#  '4a15fD': ['1003a', '7e05a', 'f65f7', '0e191'],
#  'b09c1B': ['371ec', '2cdf6', '5cf3a', 'c0f80'],
#  '697f1B': ['cd65d', 'dbeb4', 'e1376', '90c36'],
#  '4a15fB': ['c35e4', '59b09', 'fa523', '3e725'],
#  'eb50dA': ['28bbe', '7fd51', '808cb', 'd729a']}

# %%
teams_optimal = teams_opt['10']
teams_optimal
# Out:
# {'b09c1A': ['28bbe', '7e5b4', '808cb', 'cba6a', 'd729a'],
#  '6c0f1A': ['4437f', '4f711', 'c8292', 'e2a40', 'f0c14'],
#  'f10d5A': ['0d24a', '2684a', '34706', '4b146', 'd51a0'],
#  'f0a5eA': ['6aff8', '995a5', 'b6861', 'd8c36', 'ff8ac'],
#  'a23d9A': ['0fa99', '79052', '9e1a4', 'd225d', 'fffe2'],
#  '4a15fA': ['01653', '47d11'],
#  'eb50dA': ['285b3', '2a591', '6be1f'],
#  'be328A': ['cb944', 'ede24'],
#  '7f7c0A': ['0fa51', '3f9ea'],
#  '20ef0A': ['174fe', '277e2', 'e2f32'],
#  'acaecA': ['03dae', '7e05a', 'da8fa'],
#  'bd1f8A': ['3882e', '38e2a', '88177', 'c1783', 'd61b1'],
#  '697f1A': ['07ba3', '0ac0b', '0bb20', '10718', '8cc4a'],
#  '02088A': ['5c7bb', '6024e', '69695', '99fdf', 'ec344'],
#  'b09c1B': ['4bb9b', '90c36', 'a31f8', 'cd65d', 'dbeb4'],
#  'b09c1C': ['36bf2', '89b1b', '95506', 'ad98a', 'c0f80'],
#  'b09c1D': ['027b3', '2137a', '2cdf6', '371ec', '49f94'],
#  'b09c1E': ['05dc1', '0e191', 'ae1b8', 'aefc9', 'ca78f'],
#  '4a15fB': ['98075'],
#  '4a15fC': ['1003a', 'ddcf1'],
#  '4a15fD': ['239b0', 'a3004'],
#  '4a15fE': ['02ed3', '3e725', '59b09'],
#  'eb50dB': ['09ee0', 'f8117', 'fbda7'],
#  'eb50dC': ['48133', '58c1e', 'aae49'],
#  'eb50dD': ['3b6af', '8b401', 'dacea'],
#  'eb50dE': ['4576d', 'b31ec'],
#  'be328B': ['b5a51'],
#  'be328C': ['2c684'],
#  'be328D': ['3e878'],
#  'be328E': ['72cc1'],
#  '7f7c0B': ['27f54', 'f2d45'],
#  '7f7c0C': ['62de3', '6beb5'],
#  '7f7c0D': ['eaac3'],
#  '7f7c0E': ['fc95d'],
#  '02088B': ['0e9fb', '100c3', '36fd2', '4c684', 'aeb8e'],
#  '02088C': ['08e18', '0aa44', 'a3a06', 'dc9e1', 'fdb53'],
#  '02088D': ['38b25', '45293', '4b771', '626e6', 'e7903'],
#  '02088E': ['2e912', '48253', '99ba4', 'f3d21', 'f5e99'],
#  '20ef0B': ['712d2', '7301f'],
#  '20ef0C': ['15a0f', '30225', 'c3f2e'],
#  'acaecB': ['5485c', '6ace2'],
#  'acaecC': ['05b07', '1c2a8'],
#  'bd1f8B': ['202e8', '4f9dd', '5d597', 'c7939', 'd8dc3'],
#  'bd1f8C': ['52881', '725e9', 'c35e4', 'f65f7', 'fa523'],
#  '6c0f1B': ['09e60', '3c948', '48726', '6fd10', 'f61b2'],
#  'f10d5B': ['5cf3a', '7fd51', '8d841', 'a9fbb', 'f73ff'],
#  'a23d9B': ['44114', '6f08d', 'c2def', 'f0e0b', 'fbfa2'],
#  '697f1B': ['10cde', '7fd17', '86b6e', 'e1376', 'fccf2'],
#  'f0a5eB': ['3126f', 'e4d94', 'e6564', 'f73c1', 'ff084']}

# %% [markdown]
# ### Average, min, max number of (in-team) friends for each student

# %%
print(f'(manual assignment) avg number of friends {avg_friends(teams_manual)}')
print(f'(optimal assignment) avg number of friends {avg_friends(teams_optimal)}')
print(f'(manual assignment) min number of friends {min_friends(teams_manual)}')
print(f'(optimal assignment) min number of friends {min_friends(teams_optimal)}')
print(f'(manual assignment) max number of friends {max_friends(teams_manual)}')
print(f'(optimal assignment) max number of friends {max_friends(teams_optimal)}')
# Out:
# (manual assignment) avg number of friends 0.6309523809523809
# (optimal assignment) avg number of friends 0.6547619047619048
# (manual assignment) min number of friends 0
# (optimal assignment) min number of friends 0
# (manual assignment) max number of friends 3
# (optimal assignment) max number of friends 4

# %% [markdown]
# ### Average number of project preference for each student

# %%
print(f'(manual assignment) avg preference {avg_preference(teams_manual)}')
print(f'(optimal assignment) avg preference {avg_preference(teams_optimal)}')
print(f'(manual assignment) min preference {min_preference(teams_manual)}')
print(f'(optimal assignment) min preference {min_preference(teams_optimal)}')
print(f'(manual assignment) max preference {max_preference(teams_manual)}')
print(f'(optimal assignment) max preference {max_preference(teams_optimal)}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 print(f'(manual assignment) avg preference {avg_preference(teams_manual)}')
#       2 print(f'(optimal assignment) avg preference {avg_preference(teams_optimal)}')
#       3 print(f'(manual assignment) min preference {min_preference(teams_manual)}')
#
# Cell In[19], line 43, in avg_preference(teams)
#      41 for t in teams:
#      42     team = teams[t]
# ---> 43     pref += sum([m - c[(u,t)] + 1 for u in team])
#      44 return pref / n
#
# Cell In[19], line 43, in <listcomp>(.0)
#      41 for t in teams:
#      42     team = teams[t]
# ---> 43     pref += sum([m - c[(u,t)] + 1 for u in team])
#      44 return pref / n
#
# NameError: name 'm' is not defined

# %% [markdown]
# ### Distribution of number of (in team) friends

# %%
def friends_distribution(teams):
    dist = deque()
    for team in teams.values():
        for u in team:
            friends = sum([1 for v in team if u != v and (u, v) not in w and (v, u) not in w])
            dist.append(friends)
    return dist

# %%
bins = [0, 1, 2, 3, 4, 5]
optDist = friends_distribution(teams_optimal)
manualDist = friends_distribution(teams_manual)
plt.hist(manualDist, bins=bins)
plt.xlabel("# friends")
plt.ylabel("# students")
plt.title("Number of (in-team) friends (manual)")
plt.show()
plt.hist(optDist, bins=bins)
plt.xlabel("# friends")
plt.ylabel("# students")
plt.title("Number of (in-team) friends (optimal)")
plt.show()

# %% [markdown]
# ### Distribution of project preferences

# %%
def project_distribution(teams):
    dist = deque()
    for t in teams:
        team = teams[t]
        for u in team:
            dist.append(1 / c[(u, t)])
    return dist

# %%
bins = range(1, 11)
optDist = project_distribution(teams_optimal)
manualDist = project_distribution(teams_manual)
plt.hist(manualDist, bins=bins)
plt.xlabel("project preference")
plt.ylabel("# students")
plt.title("proejct preferences (manual)")
plt.show()
plt.hist(optDist, bins=bins)
plt.xlabel("project preference")
plt.ylabel("# students")
plt.title("project preferences (optimal)")
plt.show()

# %% [markdown]
# ### Per student analysis

# %%
def find_friends(student, teams):
    if student not in nodes:
        return "Not a valid student"
    friends = []
    for team in teams.values():
        for u in team:
            if u == student:
                friends = [v for v in team if u != v and (u, v) not in w and (v, u) not in w]
                return friends
    return []

def find_preference(student, teams):
    if student not in nodes:
        return "Not a valid student"
    for t in teams:
        team = teams[t]
        for u in team:
            if u == student:
                return 1 / c[(u, t)] 
    return -1

# %%
equal = 0
opt_better = 0
manual_better = 0
tradeOff = 0

for u in nodes:
    print(f"=== student: {u} ===")
    opt_pref = find_preference(u, teams_optimal)
    manual_pref = find_preference(u, teams_manual)
    opt_friends = find_friends(u, teams_optimal)
    manual_friends = find_friends(u, teams_manual)
    
    
    print(f"optimal: friends = {opt_friends}, preference = {opt_pref}")
    print(f"manual: friends = {manual_friends}, preference = {manual_pref}")
    
    if opt_pref == manual_pref and len(opt_friends) == len(manual_friends):
        print("equal")
        equal += 1
    elif opt_pref <= manual_pref and len(opt_friends) >= len(manual_friends):
        print("opt better")
        opt_better += 1
    elif opt_pref >= manual_pref and len(opt_friends) <= len(manual_friends):
        print("manual better")
        manual_better += 1
    else:
        print("trade-off")
        tradeOff += 1

        
print("=== Stats ===")
print(f'equal = {equal}')
print(f'opt better = {opt_better}')
print(f'manual better = {manual_better}')
print(f'trade-off = {tradeOff}')

# %% [markdown]
# ### Friends graph colored based on team assignment

# %%
pos=nx.spring_layout(G_c, k=0.2, iterations=20)
def draw_graph_with_teams(teams, title):
#     colors = sns.color_palette("tab10", len(teams))
    colors = cm.rainbow(np.linspace(0, 1, len(teams)))

    colors_dict = dict(zip(sorted(teams.keys()), colors))

    color_map = []
    for node in G:
        for team in teams:
            if node in teams[team]:
                color_map.append(colors_dict[team])
                break
                
    nx.draw(G_c, node_color=color_map, pos=pos, with_labels=True)
    for node in G:
        if representatives[node]:
            x, y = pos[node]
            plt.text(x + 0.09, y + 0.01, '*', fontsize=12, color='black', ha='center', va='center')
            
    plt.title(title)
    legend_handles = [plt.Line2D([0], [0], marker='o', color='w', label=label, markersize=10, markerfacecolor=color, markeredgecolor=color) for color, label in zip(colors, colors_dict.keys())]
    plt.legend(handles=legend_handles)
    plt.show()

# %%
draw_graph_with_teams(teams_manual, "Friends graph and teams (manual assignemnt)")
draw_graph_with_teams(teams_optimal, "Friends graph and teams (optimal assignment)")

# %%
teams
