# %%
import pandas as pd
import networkx as nx
import numpy as np
import pickle

# %%
file_path = '549_anon_fall2023.csv'
df = pd.read_csv(file_path)
cols = len(df.columns)
print(df.columns)
# Out:
# Index(['aaa87f36b7ec556c2bb28276450ba647', '952a63c3c04ff1f1dfaef5275c2d076d',
#        '43c8d82d21e76d47d0a40eafe413a6e2', 'b11c340bacaa7dcfdfec9d56f00fd62f',
#        '1c59bd8bac16df4b2a3e78129363d01b', '899cff5b6d165bbbd46db51c0186ed33',
#        '2f69412091650d9c399b76adc16cfa1d', 'id name', 'email anonymized',
#        'anonymized group preference'],
#       dtype='object')

# %%
numOfProjects = 8
columns_to_drop = ['id name']
df_dropped_multiple = df.drop(columns=columns_to_drop)

# If you want to modify the DataFrame in place, use inplace=True
df.drop(columns=columns_to_drop, inplace=True)

column_name_mapping = {
    df.columns[-2]: 'id',
    df.columns[-1]: 'friends',
}

for i in range(0, numOfProjects):
    column_name_mapping[df.columns[i]] = df.columns[i][-5:]
    
df.rename(columns=column_name_mapping, inplace=True)

# %%
df
# Out:
#    ba647 d076d 3a6e2 fd62f 3d01b 6ed33 cfa1d  \
# 0    4th   5th   7th   6th   3rd   2nd   1st
# 1    1st   3rd   7th   6th   2nd   5th   4th
# 2    4th   5th   7th   6th   3rd   2nd   1st
# 3    1st   7th   3rd   7th   2nd   7th   7th
# 4    3rd   7th   5th   6th   4th   1st   2nd
# 5    2nd   1st   3rd   7th   4th   5th   6th
# 6    2nd   1st   3rd   5th   4th   6th   7th
# 7    2nd   7th   1st   6th   5th   4th   3rd
# 8    2nd   7th   1st   6th   5th   4th   3rd
# 9    1st   5th   3rd   7th   4th   6th   2nd
# 10   1st   7th   4th   6th   2nd   3rd   5th
# 11   7th   4th   3rd   6th   5th   2nd   1st
# 12   2nd   1st   3rd   5th   4th   6th   7th
# 13   1st   6th   4th   3rd   2nd   5th   7th
# 14   1st   5th   6th   7th   4th   3rd   2nd
# 15   7th   5th   4th   3rd   2nd   1st   6th
# 16   7th   5th   4th   3rd   2nd   1st   6th
# 17   5th   4th   1st   3rd   7th   6th   2nd
# 18   2nd   7th   5th   3rd   4th   1st   6th
# 19   1st   4th   6th   7th   5th   3rd   2nd
# 20   1st   5th   7th   2nd   6th   4th   3rd
#
#                                mized  \
# 0   1d9eff09e4d1b560c8467538fc077640
# 1   09a5425422227aaccb851607094b1292
# 2   06b43b675a983a61fb8c5df8a6112e49
# 3   0fc4b6477eec633f4ce8f5020d2752e4
# 4   1eb333c893c50462624c3c77e110337a
# 5   c409c9f22f324697b2b01d8452d47587
# 6   bdf1326f1bcbb05c9a80dd8e78f33c10
# 7   bde83e4bc84c1d84c4d5e72c27657514
# 8   28a141a5a1b7431578dfd61c9ba9b140
# 9   753184bfd49f4cdf83f45ca2a085d51f
# 10  9b58f86366fbf77b95d27371240e1015
# 11  bba072ea758218689068a9f947fb4122
# 12  8c1b928d6b1abbe42a55d06ceccf13e4
# 13  0f4774ca1de9a7d34921105347b95bb9
# 14  9406bb167d5efe3550e4eeabfedf495b
# 15  a055354e23ed9552d005e2150d605f6c
# 16  41c172dfc59764e4ed7eaae6740623f3
# 17  1bdf318771dc7b8da7ea27c4820a61a9
# 18  41a947f542aeedea5277fa986a5f13d2
# 19  ed8b98d7ade1b986d0179adf846cc7d7
# 20  ce839c0ed5043db3ee998c7208f8870e
#
#                                               friends
# 0                ['06b43b675a983a61fb8c5df8a6112e49']
# 1                ['9b58f86366fbf77b95d27371240e1015']
# 2                ['1d9eff09e4d1b560c8467538fc077640']
# 3   ['9406bb167d5efe3550e4eeabfedf495b', '753184bf...
# 4                                                  []
# 5   ['8c1b928d6b1abbe42a55d06ceccf13e4', 'bdf1326f...
# 6   ['8c1b928d6b1abbe42a55d06ceccf13e4', 'c409c9f2...
# 7                ['28a141a5a1b7431578dfd61c9ba9b140']
# 8                ['bde83e4bc84c1d84c4d5e72c27657514']
# 9   ['ed8b98d7ade1b986d0179adf846cc7d7', '0fc4b647...
# 10               ['09a5425422227aaccb851607094b1292']
# 11                                                 []
# 12  ['bdf1326f1bcbb05c9a80dd8e78f33c10', 'c409c9f2...
# 13               ['41a947f542aeedea5277fa986a5f13d2']
# 14  ['753184bfd49f4cdf83f45ca2a085d51f', 'ed8b98d7...
# 15               ['41c172dfc59764e4ed7eaae6740623f3']
# 16               ['a055354e23ed9552d005e2150d605f6c']
# 17                                                 []
# 18               ['0f4774ca1de9a7d34921105347b95bb9']
# 19  ['753184bfd49f4cdf83f45ca2a085d51f', '0fc4b647...
# 20                                                 []

# %%
projects = [p for p in list(df.columns[0:numOfProjects])]

# %%
c = dict()
G = nx.Graph()
nodes = []
for index, row in df.iterrows():
    id = row['id'][-5:]
    nodes.append(id)
    preferences = [int(row[p][:-2]) for p in projects]
    for p, pref in zip(projects, preferences):
        c[(id, p)] = 1 / pref
    
    # friends
    friends = row['friends'].strip("[]").replace("'", "").split(",")
    for f in friends:
        if f:
            G.add_edge(id, f[-5:])
            
G.add_nodes_from(nodes)
G_c = nx.complement(G)
w = dict()
for e in G_c.edges:
    w[e] = 1
edges = list(G_c.edges)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /share/pkg.8/python3/3.10.12/install/lib/python3.10/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File /share/pkg.8/python3/3.10.12/install/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /share/pkg.8/python3/3.10.12/install/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 5
#       3 nodes = []
#       4 for index, row in df.iterrows():
# ----> 5     id = row['id'][-5:]
#       6     nodes.append(id)
#       7     preferences = [int(row[p][:-2]) for p in projects]
#
# File /share/pkg.8/python3/3.10.12/install/lib/python3.10/site-packages/pandas/core/series.py:1007, in Series.__getitem__(self, key)
#    1004     return self._values[key]
#    1006 elif key_is_scalar:
# -> 1007     return self._get_value(key)
#    1009 if is_hashable(key):
#    1010     # Otherwise index.get_value will raise InvalidIndexError
#    1011     try:
#    1012         # For labels that don't resolve as scalars like tuples and frozensets
#
# File /share/pkg.8/python3/3.10.12/install/lib/python3.10/site-packages/pandas/core/series.py:1116, in Series._get_value(self, label, takeable)
#    1113     return self._values[label]
#    1115 # Similar to Index.get_value, but we do not fall back to positional
# -> 1116 loc = self.index.get_loc(label)
#    1118 if is_integer(loc):
#    1119     return self._values[loc]
#
# File /share/pkg.8/python3/3.10.12/install/lib/python3.10/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'id'

# %%
print(f'Num of students = {len(nodes)}')
print(f'Num of (friend) edges = {len(G.edges)}')

nx.draw(G, pos=nx.spring_layout(G, k=0.2, iterations=20), with_labels=True)
# Out:
# Num of students = 27
# Num of (friend) edges = 9

# %%
max_capacities = dict()
for p in projects:
    max_capacities[p] = 4

# %%
with open(f'./cs519.pickle', 'wb') as file:
    pickle.dump(projects, file) # project names
    pickle.dump(max_capacities, file) # max capacity for each project
    pickle.dump(c, file) # project preferences
    pickle.dump(w, file) # weights of conflict edges
    pickle.dump(edges, file) # conflict edges
    file.close()
